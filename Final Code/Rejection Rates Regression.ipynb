# %%
import pandas as pd
import plotly.express as px
pd.set_option("display.max_columns", None)
import seaborn as sns
import matplotlib.pyplot as mp
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
pwd
# Out:
# 'C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan'

# %%
cd C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Final Code
# Out:
# C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Final Code

# %%
df = pd.read_csv('merged_df.csv')
df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135484               910          0.671666
# 1       Bergen        476733              5986          1.255629
# 2   Burlington        253339              1911          0.754325
# 3       Camden        246440               703          0.285262
# 4     Cape May         56565               367          0.648811
# 5   Cumberland         60047               761          1.267341
# 6        Essex        307537              2184          0.710158
# 7   Gloucester        170985               100          0.058485
# 8       Hudson        224243              5605          2.499521
# 9    Hunterdon         84247               618          0.733557
# 10      Mercer        169955              1314          0.773146
# 11   Middlesex        355993              6837          1.920543
# 12    Monmouth        377148              5403          1.432594
# 13      Morris        293123              1122          0.382774
# 14       Ocean        338676              3727          1.100462
# 15     Passaic        210776              1797          0.852564
# 16       Salem         33022               572          1.732179
# 17    Somerset        183143              2369          1.293525
# 18      Sussex         87304               992          1.136260
# 19       Union        243523              6284          2.580454
# 20      Warren         60053               970          1.615240
#
#     Percent_Ballots_Cast_Dem  Percent_Ballots_Cast_Repub  \
# 0                  38.171297                   31.508518
# 1                  40.954790                   23.590563
# 2                  42.231555                   27.698459
# 3                  52.869258                   17.708570
# 4                  26.306020                   45.342526
# 5                  39.633953                   27.545090
# 6                  57.282213                   11.854834
# 7                  42.053981                   26.179489
# 8                  61.905165                   10.421284
# 9                  28.574311                   41.551628
# 10                 47.604954                   16.915654
# 11                 46.086580                   17.443882
# 12                 30.591439                   30.918101
# 13                 30.459909                   36.895433
# 14                 24.230533                   39.618101
# 15                 42.123392                   23.975690
# 16                 33.671492                   32.015020
# 17                 37.081406                   27.613941
# 18                 24.167278                   45.194951
# 19                 51.267437                   17.382342
# 20                 27.092735                   42.783874
#
#     Percent_Ballots_Cast_Unaff  Percent_Ballots_Cast_Other  Dem_Ballots_Cast  \
# 0                    29.313424                    1.006761             51716
# 1                    34.724049                    0.730598            195245
# 2                    29.278556                    0.791430            106989
# 3                    28.477926                    0.944246            130291
# 4                    27.642535                    0.708919             14880
# 5                    31.488667                    1.332290             23799
# 6                    30.258148                    0.604805            176164
# 7                    30.837793                    0.928736             71906
# 8                    26.567607                    1.105943            138818
# 9                    29.239023                    0.635037             24073
# 10                   34.468536                    1.010856             80907
# 11                   35.498170                    0.971367            164065
# 12                   37.574374                    0.916086            115375
# 13                   31.884908                    0.759749             89285
# 14                   35.125016                    1.026350             82063
# 15                   32.785042                    1.115877             88786
# 16                   33.280843                    1.032645             11119
# 17                   34.557695                    0.746957             67912
# 18                   29.428205                    1.209567             21099
# 19                   30.497735                    0.852486            124848
# 20                   29.157577                    0.965814             16270
#
#     Other_Ballots_Cast  Repub_Ballots_Cast  Unaff_Ballots_Cast  \
# 0                 1364               42689               39715
# 1                 3483              112464              165541
# 2                 2005               70171               74174
# 3                 2327               43641               70181
# 4                  401               25648               15636
# 5                  800               16540               18908
# 6                 1860               36458               93055
# 7                 1588               44763               52728
# 8                 2480               23369               59576
# 9                  535               35006               24633
# 10                1718               28749               58581
# 11                3458               62099              126371
# 12                3455              116607              141711
# 13                2227              108149               93462
# 14                3476              134177              118960
# 15                2352               50535               69103
# 16                 341               10572               10990
# 17                1368               50573               63290
# 18                1056               39457               25692
# 19                2076               42330               74269
# 20                 580               25693               17510
#
#     Dem_Ballots_Rejected  Other_Ballots_Rejected  Repub_Ballots_Rejected  \
# 0                  280.0                    32.0                   178.0
# 1                 2118.0                   111.0                  1272.0
# 2                  673.0                    32.0                   389.0
# 3                  309.0                     5.0                    81.0
# 4                   59.0                     4.0                   141.0
# 5                  241.0                    19.0                   141.0
# 6                 1115.0                    23.0                   188.0
# 7                   35.0                     0.0                    26.0
# 8                 3033.0                   142.0                   628.0
# 9                   99.0                    12.0                   232.0
# 10                 558.0                    32.0                   180.0
# 11                2534.0                   170.0                   918.0
# 12                1412.0                   107.0                  1530.0
# 13                 320.0                    41.0                   349.0
# 14                 615.0                    88.0                  1380.0
# 15                 609.0                    37.0                   279.0
# 16                 187.0                    11.0                   136.0
# 17                 835.0                    46.0                   527.0
# 18                 195.0                    25.0                   337.0
# 19                3011.0                    98.0                   929.0
# 20                 192.0                    17.0                   372.0
#
#     Unaff_Ballots_Rejected  Percent_Dem_Ballots_Rejected  \
# 0                    420.0                           0.5
# 1                   2485.0                           1.1
# 2                    817.0                           0.6
# 3                    328.0                           0.2
# 4                    164.0                           0.4
# 5                    361.0                           1.0
# 6                    858.0                           0.6
# 7                     39.0                           0.0
# 8                   1802.0                           2.2
# 9                    277.0                           0.4
# 10                   544.0                           0.7
# 11                  3217.0                           1.5
# 12                  2355.0                           1.2
# 13                   530.0                           0.4
# 14                  1644.0                           0.7
# 15                   872.0                           0.7
# 16                   238.0                           1.7
# 17                   961.0                           1.2
# 18                   441.0                           0.9
# 19                  2250.0                           2.4
# 20                   389.0                           1.2
#
#     Percent_Repub_Ballots_Rejected  Percent_Other_Ballots_Rejected  \
# 0                              0.4                             2.3
# 1                              1.1                             3.2
# 2                              0.6                             1.6
# 3                              0.2                             0.2
# 4                              0.5                             1.0
# 5                              0.9                             2.4
# 6                              0.5                             1.2
# 7                              0.1                             0.0
# 8                              2.7                             5.7
# 9                              0.7                             2.2
# 10                             0.6                             1.9
# 11                             1.5                             4.9
# 12                             1.3                             3.1
# 13                             0.3                             1.8
# 14                             1.0                             2.5
# 15                             0.6                             1.6
# 16                             1.3                             3.2
# 17                             1.0                             3.4
# 18                             0.9                             2.4
# 19                             2.2                             4.7
# 20                             1.4                             2.9
#
#     Percent_Unaff_Ballots_Rejected  Percent Hispanic or Latino  Percent White  \
# 0                              1.1                        19.4           55.9
# 1                              1.5                        21.0           55.0
# 2                              1.1                         8.5           66.4
# 3                              0.5                        17.6           55.6
# 4                              1.0                         8.1           85.0
# 5                              1.9                        31.8           45.4
# 6                              0.9                        23.8           29.8
# 7                              0.1                         6.7           77.7
# 8                              3.0                        42.7           28.8
# 9                              1.1                         7.0           84.3
# 10                             0.9                        18.5           48.2
# 11                             2.5                        22.1           41.6
# 12                             1.7                        11.1           74.9
# 13                             0.6                        13.9           70.3
# 14                             1.4                         9.5           84.1
# 15                             1.3                        42.9           40.3
# 16                             2.2                         9.8           73.2
# 17                             1.5                        15.2           53.6
# 18                             1.7                         9.2           84.9
# 19                             3.0                        32.8           37.8
# 20                             2.2                        10.2           80.2
#
#     Percent Black or African American  \
# 0                                13.7
# 1                                 5.1
# 2                                16.4
# 3                                18.4
# 4                                 4.2
# 5                                18.0
# 6                                38.4
# 7                                10.3
# 8                                10.3
# 9                                 2.4
# 10                               19.4
# 11                                9.2
# 12                                6.7
# 13                                3.3
# 14                                3.0
# 15                               10.4
# 16                               12.7
# 17                                9.5
# 18                                2.4
# 19                               19.9
# 20                                4.7
#
#     Percent American Indian and Alaska Native  Percent Asian  \
# 0                                         0.2            7.8
# 1                                         0.1           16.4
# 2                                         0.0            5.1
# 3                                         0.1            5.7
# 4                                         0.0            0.5
# 5                                         0.9            1.2
# 6                                         0.2            5.4
# 7                                         0.0            3.1
# 8                                         0.1           15.3
# 9                                         0.0            4.2
# 10                                        0.2           11.8
# 11                                        0.1           24.4
# 12                                        0.0            5.3
# 13                                        0.0           10.8
# 14                                        0.0            1.6
# 15                                        0.1            5.1
# 16                                        0.3            1.1
# 17                                        0.1           18.5
# 18                                        0.0            1.8
# 19                                        0.1            5.3
# 20                                        0.0            2.3
#
#     Percent Native Hawaiian and Other Pacific Islander  Percent Other Race  \
# 0                                                 0.2                  0.1
# 1                                                 0.1                  0.3
# 2                                                 0.0                  0.4
# 3                                                 0.0                  0.5
# 4                                                 0.0                  0.0
# 5                                                 0.0                  0.0
# 6                                                 0.0                  0.9
# 7                                                 0.0                  0.1
# 8                                                 0.0                  0.5
# 9                                                 0.0                  0.5
# 10                                                0.1                  0.1
# 11                                                0.1                  0.4
# 12                                                0.0                  0.3
# 13                                                0.0                  0.3
# 14                                                0.0                  0.2
# 15                                                0.0                  0.1
# 16                                                0.4                  0.2
# 17                                                0.0                  1.8
# 18                                                0.0                  0.1
# 19                                                0.0                  2.5
# 20                                                0.0                  0.3
#
#     Percent Two or more races  percent_english  percent_spanish  \
# 0                         2.7             79.4             11.1
# 1                         2.0             64.5             14.0
# 2                         3.2             88.4              3.9
# 3                         2.2             84.6              9.7
# 4                         2.2             95.5              2.4
# 5                         2.6             78.7             17.8
# 6                         1.5             70.6             15.8
# 7                         2.0             91.0              3.9
# 8                         2.2             50.9             32.8
# 9                         1.6             90.6              2.7
# 10                        1.8             77.0              9.7
# 11                        2.2             60.6             16.3
# 12                        1.6             85.0              5.3
# 13                        1.5             80.5              7.3
# 14                        1.5             90.4              3.7
# 15                        1.0             59.9             27.7
# 16                        2.3             93.7              4.6
# 17                        1.3             71.4              9.9
# 18                        1.5             90.3              4.3
# 19                        1.6             63.8             21.4
# 20                        2.3             90.8              4.7
#
#     percent_other  percent_english_very_well  percent_english_not_very_well  \
# 0             9.5                       92.6                            7.4
# 1            21.5                       89.0                           11.0
# 2             7.7                       96.6                            3.4
# 3             5.7                       94.4                            5.6
# 4             2.1                       99.0                            1.0
# 5             3.5                       92.0                            8.0
# 6            13.5                       90.1                            9.9
# 7             5.1                       97.9                            2.1
# 8            16.3                       81.7                           18.3
# 9             6.7                       98.1                            1.9
# 10           13.3                       92.5                            7.5
# 11           23.2                       88.7                           11.3
# 12            9.7                       95.9                            4.1
# 13           12.2                       94.3                            5.7
# 14            5.9                       98.1                            1.9
# 15           12.4                       83.5                           16.5
# 16            1.7                       97.5                            2.5
# 17           18.7                       93.4                            6.6
# 18            5.4                       97.6                            2.4
# 19           14.8                       87.5                           12.5
# 20            4.5                       98.1                            1.9
#
#     median_earnings  HS_and_less  more_than_HS  %HS_and_less  more_than_HS%  \
# 0             45935        32464        175711          15.6           84.4
# 1             72267        70554        665338           9.6           90.4
# 2             61748        35189        318001          10.0           90.0
# 3             51486        55085        337381          14.0           86.0
# 4             51483         7929         68160          10.4           89.6
# 5             34905        25602         88369          22.5           77.5
# 6             51029       103304        506293          16.9           83.1
# 7             64004        22770        205767          10.0           90.0
# 8             58372        87458        448406          16.3           83.7
# 9             80882         9679         90980           9.6           90.4
# 10            57023        40924        248444          14.1           85.9
# 11            65047        89880        556734          13.9           86.1
# 12            76140        40266        448926           8.2           91.8
# 13            81064        33089        356277           8.5           91.5
# 14            60454        45438        415058           9.9           90.1
# 15            48493        75045        307763          19.6           80.4
# 16            57340         7066         42190          14.3           85.7
# 17            81377        22156        236021           8.6           91.4
# 18            68713        10514        102728           9.3           90.7
# 19            52001        69459        356833          16.3           83.7
# 20            67667         8063         76852           9.5           90.5
#
#     Percent 15 to 19 years  Percent 20 to 24 years  Percent 25 to 34 years  \
# 0                      6.2                     6.7                    11.4
# 1                      6.1                     5.8                    11.6
# 2                      6.0                     6.1                    12.6
# 3                      6.4                     5.6                    14.0
# 4                      4.3                     5.3                    10.0
# 5                      6.5                     4.8                    14.7
# 6                      6.3                     6.2                    13.8
# 7                      6.4                     6.5                    12.0
# 8                      4.8                     5.8                    21.1
# 9                      6.4                     5.8                     9.7
# 10                     7.9                     7.1                    12.5
# 11                     6.7                     6.5                    13.2
# 12                     6.4                     5.8                    11.0
# 13                     6.6                     6.0                    11.0
# 14                     5.6                     5.4                    11.0
# 15                     6.8                     6.7                    13.5
# 16                     6.0                     6.2                    10.8
# 17                     6.7                     5.9                    10.9
# 18                     6.2                     5.8                    10.8
# 19                     6.3                     6.0                    12.7
# 20                     6.4                     5.6                    11.7
#
#     Percent 35 to 44 years  Percent 45 to 54 years  Percent 55 to 59 years  \
# 0                     11.9                    12.5                     7.4
# 1                     13.3                    14.2                     7.4
# 2                     12.4                    13.8                     7.8
# 3                     12.8                    13.0                     6.6
# 4                      9.6                    12.0                     7.5
# 5                     13.2                    12.6                     6.2
# 6                     13.9                    13.8                     6.2
# 7                     12.7                    14.0                     6.7
# 8                     16.0                    12.0                     5.5
# 9                     11.4                    15.1                     8.0
# 10                    12.6                    13.6                     6.3
# 11                    13.8                    13.4                     6.9
# 12                    11.5                    14.3                     8.1
# 13                    12.2                    14.9                     7.9
# 14                    10.1                    11.1                     6.3
# 15                    12.5                    12.9                     6.6
# 16                    12.2                    13.9                     6.2
# 17                    12.8                    15.1                     8.4
# 18                    12.0                    15.0                     8.5
# 19                    13.8                    13.9                     7.1
# 20                    10.9                    15.0                     8.0
#
#     Percent 60 to 64 years  Percent 65 to 74 years  Percent 75 to 84 years  \
# 0                      7.8                    11.0                     5.6
# 1                      6.9                     9.7                     5.5
# 2                      7.0                     9.8                     5.3
# 3                      6.9                     9.3                     4.7
# 4                      9.9                    15.5                     8.4
# 5                      6.2                     9.4                     4.3
# 6                      6.1                     7.9                     4.2
# 7                      7.8                     9.8                     4.7
# 8                      5.2                     7.0                     3.7
# 9                      9.2                    11.6                     6.4
# 10                     6.9                     8.8                     4.6
# 11                     6.2                     8.9                     4.4
# 12                     7.9                    10.5                     5.3
# 13                     7.1                     9.6                     5.4
# 14                     7.2                    12.1                     7.8
# 15                     6.2                     8.7                     4.2
# 16                     8.0                    11.2                     6.2
# 17                     6.6                     9.2                     4.4
# 18                     8.8                    10.8                     4.6
# 19                     6.0                     8.3                     4.3
# 20                     7.9                    10.7                     5.5
#
#     Percent 85 years and over  Percent Less than $10,000  \
# 0                         2.0                        6.5
# 1                         2.4                        3.4
# 2                         2.2                        2.5
# 3                         2.0                        6.2
# 4                         3.1                        4.2
# 5                         2.0                        7.5
# 6                         1.8                        8.4
# 7                         1.8                        3.8
# 8                         1.6                        6.2
# 9                         1.6                        1.8
# 10                        2.3                        8.2
# 11                        2.2                        4.2
# 12                        2.3                        4.4
# 13                        2.5                        2.5
# 14                        2.9                        3.1
# 15                        2.1                        4.9
# 16                        2.4                        2.9
# 17                        2.6                        2.6
# 18                        2.0                        2.9
# 19                        2.1                        4.1
# 20                        2.7                        3.8
#
#     Percent $10,000 to $14,999  Percent $15,000 to $24,999  \
# 0                          3.7                         8.9
# 1                          1.9                         4.5
# 2                          1.5                         5.6
# 3                          3.4                         7.5
# 4                          3.3                         6.8
# 5                          4.9                         9.4
# 6                          4.3                         7.8
# 7                          2.6                         6.5
# 8                          4.7                         7.3
# 9                          1.4                         3.5
# 10                         3.6                         6.0
# 11                         2.4                         5.5
# 12                         2.4                         4.8
# 13                         1.6                         4.7
# 14                         2.4                         8.0
# 15                         4.1                         7.2
# 16                         6.4                         9.9
# 17                         1.8                         3.0
# 18                         1.1                         4.2
# 19                         2.6                         6.8
# 20                         3.6                         4.9
#
#     Percent $25,000 to $34,999  Percent $35,000 to $49,999  \
# 0                          8.2                        13.0
# 1                          4.6                         8.1
# 2                          5.6                         9.3
# 3                          7.6                         9.8
# 4                          8.6                        13.2
# 5                          9.2                        10.6
# 6                          8.3                        10.3
# 7                          7.1                         8.0
# 8                          6.2                         9.4
# 9                          6.2                         5.7
# 10                         6.7                         7.8
# 11                         5.2                         9.0
# 12                         6.3                         6.7
# 13                         4.4                         7.1
# 14                         7.7                        10.2
# 15                         7.6                         8.9
# 16                         6.2                        12.3
# 17                         4.2                         7.1
# 18                         4.5                         6.4
# 19                         6.6                        10.7
# 20                         6.4                        10.2
#
#     Percent $50,000 to $74,999  Percent $75,000 to $99,999  \
# 0                         16.8                        12.0
# 1                         12.0                        11.4
# 2                         17.0                        14.8
# 3                         16.5                        11.8
# 4                         16.2                        12.1
# 5                         21.9                        10.8
# 6                         16.4                        10.6
# 7                         14.7                        14.0
# 8                         14.5                        12.1
# 9                         13.3                        10.8
# 10                        15.3                        11.4
# 11                        13.7                        12.8
# 12                        12.2                        11.4
# 13                        12.3                        10.6
# 14                        18.0                        13.8
# 15                        15.9                        13.2
# 16                        19.2                        11.0
# 17                        13.4                        12.7
# 18                        15.9                        14.1
# 19                        16.9                        12.0
# 20                        15.4                        16.7
#
#     Percent $100,000 to $149,999  Percent $150,000 to $199,999  \
# 0                           16.2                           7.5
# 1                           19.5                          12.7
# 2                           19.7                          11.3
# 3                           18.6                           8.4
# 4                           16.6                           8.5
# 5                           16.8                           4.5
# 6                           13.5                           7.3
# 7                           19.8                          11.7
# 8                           16.7                           8.8
# 9                           19.7                          13.3
# 10                          17.2                           9.0
# 11                          19.9                          12.1
# 12                          19.5                          11.7
# 13                          18.8                          12.9
# 14                          19.7                           8.8
# 15                          18.0                           9.7
# 16                          14.8                          10.0
# 17                          17.5                          12.5
# 18                          22.1                          13.3
# 19                          15.8                           9.5
# 20                          18.2                          10.8
#
#     Percent $200,000 or more  Percent below poverty level
# 0                        7.2                         11.1
# 1                       21.8                          5.6
# 2                       12.9                          5.5
# 3                       10.1                         10.7
# 4                       10.5                          8.8
# 5                        4.3                         13.2
# 6                       13.0                         13.9
# 7                       11.8                          7.7
# 8                       14.1                         13.9
# 9                       24.2                          3.6
# 10                      14.9                         12.8
# 11                      15.2                          8.8
# 12                      20.7                          6.0
# 13                      25.0                          5.5
# 14                       8.3                          9.0
# 15                      10.5                         13.4
# 16                       7.4                         12.4
# 17                      25.1                          5.7
# 18                      15.6                          4.7
# 19                      14.9                          9.1
# 20                      10.0                          6.8

# %%
df['County']
# Out:
# 0       Atlantic
# 1         Bergen
# 2     Burlington
# 3         Camden
# 4       Cape May
# 5     Cumberland
# 6          Essex
# 7     Gloucester
# 8         Hudson
# 9      Hunterdon
# 10        Mercer
# 11     Middlesex
# 12      Monmouth
# 13        Morris
# 14         Ocean
# 15       Passaic
# 16         Salem
# 17      Somerset
# 18        Sussex
# 19         Union
# 20        Warren
# Name: County, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 59 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   County                                              21 non-null     object
#  1   ballots_cast                                        21 non-null     int64
#  2   ballots_rejected                                    21 non-null     int64
#  3   percent_rejected                                    21 non-null     float64
#  4   Percent_Ballots_Cast_Dem                            21 non-null     float64
#  5   Percent_Ballots_Cast_Repub                          21 non-null     float64
#  6   Percent_Ballots_Cast_Unaff                          21 non-null     float64
#  7   Percent_Ballots_Cast_Other                          21 non-null     float64
#  8   Dem_Ballots_Cast                                    21 non-null     int64
#  9   Other_Ballots_Cast                                  21 non-null     int64
#  10  Repub_Ballots_Cast                                  21 non-null     int64
#  11  Unaff_Ballots_Cast                                  21 non-null     int64
#  12  Dem_Ballots_Rejected                                21 non-null     float64
#  13  Other_Ballots_Rejected                              21 non-null     float64
#  14  Repub_Ballots_Rejected                              21 non-null     float64
#  15  Unaff_Ballots_Rejected                              21 non-null     float64
#  16  Percent_Dem_Ballots_Rejected                        21 non-null     float64
#  17  Percent_Repub_Ballots_Rejected                      21 non-null     float64
#  18  Percent_Other_Ballots_Rejected                      21 non-null     float64
#  19  Percent_Unaff_Ballots_Rejected                      21 non-null     float64
#  20  Percent Hispanic or Latino                          21 non-null     float64
#  21  Percent White                                       21 non-null     float64
#  22  Percent Black or African American                   21 non-null     float64
#  23  Percent American Indian and Alaska Native           21 non-null     float64
#  24  Percent Asian                                       21 non-null     float64
#  25  Percent Native Hawaiian and Other Pacific Islander  21 non-null     float64
#  26  Percent Other Race                                  21 non-null     float64
#  27  Percent Two or more races                           21 non-null     float64
#  28  percent_english                                     21 non-null     float64
#  29  percent_spanish                                     21 non-null     float64
#  30  percent_other                                       21 non-null     float64
#  31  percent_english_very_well                           21 non-null     float64
#  32  percent_english_not_very_well                       21 non-null     float64
#  33  median_earnings                                     21 non-null     int64
#  34  HS_and_less                                         21 non-null     int64
#  35  more_than_HS                                        21 non-null     int64
#  36  %HS_and_less                                        21 non-null     float64
#  37  more_than_HS%                                       21 non-null     float64
#  38  Percent 15 to 19 years                              21 non-null     float64
#  39  Percent 20 to 24 years                              21 non-null     float64
#  40  Percent 25 to 34 years                              21 non-null     float64
#  41  Percent 35 to 44 years                              21 non-null     float64
#  42  Percent 45 to 54 years                              21 non-null     float64
#  43  Percent 55 to 59 years                              21 non-null     float64
#  44  Percent 60 to 64 years                              21 non-null     float64
#  45  Percent 65 to 74 years                              21 non-null     float64
#  46  Percent 75 to 84 years                              21 non-null     float64
#  47  Percent 85 years and over                           21 non-null     float64
#  48  Percent Less than $10,000                           21 non-null     float64
#  49  Percent $10,000 to $14,999                          21 non-null     float64
#  50  Percent $15,000 to $24,999                          21 non-null     float64
#  51  Percent $25,000 to $34,999                          21 non-null     float64
#  52  Percent $35,000 to $49,999                          21 non-null     float64
#  53  Percent $50,000 to $74,999                          21 non-null     float64
#  54  Percent $75,000 to $99,999                          21 non-null     float64
#  55  Percent $100,000 to $149,999                        21 non-null     float64
#  56  Percent $150,000 to $199,999                        21 non-null     float64
#  57  Percent $200,000 or more                            21 non-null     float64
#  58  Percent below poverty level                         21 non-null     float64
# dtypes: float64(49), int64(9), object(1)
# memory usage: 9.8+ KB

# %%
corr = df.corr()
corr
# Out:
#                                                     ballots_cast  \
# ballots_cast                                            1.000000
# ballots_rejected                                        0.729509
# percent_rejected                                        0.075110
# Percent_Ballots_Cast_Dem                                0.303183
# Percent_Ballots_Cast_Repub                             -0.443150
# Percent_Ballots_Cast_Unaff                              0.509541
# Percent_Ballots_Cast_Other                             -0.304064
# Dem_Ballots_Cast                                        0.891481
# Other_Ballots_Cast                                      0.941212
# Repub_Ballots_Cast                                      0.792562
# Unaff_Ballots_Cast                                      0.987798
# Dem_Ballots_Rejected                                    0.588460
# Other_Ballots_Rejected                                  0.677220
# Repub_Ballots_Rejected                                  0.729221
# Unaff_Ballots_Rejected                                  0.765655
# Percent_Dem_Ballots_Rejected                            0.084885
# Percent_Repub_Ballots_Rejected                          0.116460
# Percent_Other_Ballots_Rejected                          0.191470
# Percent_Unaff_Ballots_Rejected                         -0.014579
# Percent Hispanic or Latino                              0.174488
# Percent White                                          -0.311120
# Percent Black or African American                       0.074759
# Percent American Indian and Alaska Native              -0.286927
# Percent Asian                                           0.523302
# Percent Native Hawaiian and Other Pacific Islander     -0.195301
# Percent Other Race                                      0.169842
# Percent Two or more races                              -0.216700
# percent_english                                        -0.472450
# percent_spanish                                         0.229173
# percent_other                                           0.673943
# percent_english_very_well                              -0.374648
# percent_english_not_very_well                           0.374648
# median_earnings                                         0.270319
# HS_and_less                                             0.696827
# more_than_HS                                            0.964068
# %HS_and_less                                           -0.178884
# more_than_HS%                                           0.178884
# Percent 15 to 19 years                                  0.095824
# Percent 20 to 24 years                                  0.126875
# Percent 25 to 34 years                                  0.133348
# Percent 35 to 44 years                                  0.293091
# Percent 45 to 54 years                                 -0.062589
# Percent 55 to 59 years                                 -0.053995
# Percent 60 to 64 years                                 -0.466617
# Percent 65 to 74 years                                 -0.374294
# Percent 75 to 84 years                                 -0.155953
# Percent 85 years and over                               0.025826
# Percent Less than $10,000                              -0.006927
# Percent $10,000 to $14,999                             -0.362917
# Percent $15,000 to $24,999                             -0.221310
# Percent $25,000 to $34,999                             -0.294463
# Percent $35,000 to $49,999                             -0.285762
# Percent $50,000 to $74,999                             -0.499537
# Percent $75,000 to $99,999                             -0.149053
# Percent $100,000 to $149,999                            0.222536
# Percent $150,000 to $199,999                            0.231552
# Percent $200,000 or more                                0.394058
# Percent below poverty level                            -0.133184
#
#                                                     ballots_rejected  \
# ballots_cast                                                0.729509
# ballots_rejected                                            1.000000
# percent_rejected                                            0.699937
# Percent_Ballots_Cast_Dem                                    0.349369
# Percent_Ballots_Cast_Repub                                 -0.466872
# Percent_Ballots_Cast_Unaff                                  0.409585
# Percent_Ballots_Cast_Other                                 -0.056163
# Dem_Ballots_Cast                                            0.719951
# Other_Ballots_Cast                                          0.762142
# Repub_Ballots_Cast                                          0.445443
# Unaff_Ballots_Cast                                          0.736541
# Dem_Ballots_Rejected                                        0.934539
# Other_Ballots_Rejected                                      0.956871
# Repub_Ballots_Rejected                                      0.836044
# Unaff_Ballots_Rejected                                      0.982434
# Percent_Dem_Ballots_Rejected                                0.678970
# Percent_Repub_Ballots_Rejected                              0.714911
# Percent_Other_Ballots_Rejected                              0.756091
# Percent_Unaff_Ballots_Rejected                              0.630364
# Percent Hispanic or Latino                                  0.415155
# Percent White                                              -0.446389
# Percent Black or African American                          -0.018633
# Percent American Indian and Alaska Native                  -0.148309
# Percent Asian                                               0.591283
# Percent Native Hawaiian and Other Pacific Islander         -0.078014
# Percent Other Race                                          0.410579
# Percent Two or more races                                  -0.136202
# percent_english                                            -0.672782
# percent_spanish                                             0.489953
# percent_other                                               0.738342
# percent_english_very_well                                  -0.569766
# percent_english_not_very_well                               0.569766
# median_earnings                                             0.163276
# HS_and_less                                                 0.672693
# more_than_HS                                                0.788695
# %HS_and_less                                                0.016509
# more_than_HS%                                              -0.016509
# Percent 15 to 19 years                                     -0.087770
# Percent 20 to 24 years                                      0.020325
# Percent 25 to 34 years                                      0.335505
# Percent 35 to 44 years                                      0.465206
# Percent 45 to 54 years                                     -0.116317
# Percent 55 to 59 years                                     -0.111565
# Percent 60 to 64 years                                     -0.524146
# Percent 65 to 74 years                                     -0.400811
# Percent 75 to 84 years                                     -0.245205
# Percent 85 years and over                                  -0.022657
# Percent Less than $10,000                                  -0.029968
# Percent $10,000 to $14,999                                 -0.171838
# Percent $15,000 to $24,999                                 -0.167434
# Percent $25,000 to $34,999                                 -0.318457
# Percent $35,000 to $49,999                                 -0.124418
# Percent $50,000 to $74,999                                 -0.358075
# Percent $75,000 to $99,999                                 -0.075377
# Percent $100,000 to $149,999                                0.076661
# Percent $150,000 to $199,999                                0.164017
# Percent $200,000 or more                                    0.292059
# Percent below poverty level                                -0.029357
#
#                                                     percent_rejected  \
# ballots_cast                                                0.075110
# ballots_rejected                                            0.699937
# percent_rejected                                            1.000000
# Percent_Ballots_Cast_Dem                                    0.225124
# Percent_Ballots_Cast_Repub                                 -0.262407
# Percent_Ballots_Cast_Unaff                                  0.105781
# Percent_Ballots_Cast_Other                                  0.257960
# Dem_Ballots_Cast                                            0.170145
# Other_Ballots_Cast                                          0.161300
# Repub_Ballots_Cast                                         -0.124314
# Unaff_Ballots_Cast                                          0.087889
# Dem_Ballots_Rejected                                        0.753806
# Other_Ballots_Rejected                                      0.676958
# Repub_Ballots_Rejected                                      0.485793
# Unaff_Ballots_Rejected                                      0.625303
# Percent_Dem_Ballots_Rejected                                0.982926
# Percent_Repub_Ballots_Rejected                              0.973140
# Percent_Other_Ballots_Rejected                              0.935115
# Percent_Unaff_Ballots_Rejected                              0.985108
# Percent Hispanic or Latino                                  0.455597
# Percent White                                              -0.371413
# Percent Black or African American                          -0.029038
# Percent American Indian and Alaska Native                   0.127316
# Percent Asian                                               0.288592
# Percent Native Hawaiian and Other Pacific Islander          0.158026
# Percent Other Race                                          0.457867
# Percent Two or more races                                   0.012673
# percent_english                                            -0.503830
# percent_spanish                                             0.504456
# percent_other                                               0.366002
# percent_english_very_well                                  -0.465768
# percent_english_not_very_well                               0.465768
# median_earnings                                            -0.026136
# HS_and_less                                                 0.295527
# more_than_HS                                                0.199387
# %HS_and_less                                                0.227675
# more_than_HS%                                              -0.227675
# Percent 15 to 19 years                                     -0.188647
# Percent 20 to 24 years                                     -0.143750
# Percent 25 to 34 years                                      0.406391
# Percent 35 to 44 years                                      0.433374
# Percent 45 to 54 years                                     -0.049764
# Percent 55 to 59 years                                     -0.164999
# Percent 60 to 64 years                                     -0.407653
# Percent 65 to 74 years                                     -0.312496
# Percent 75 to 84 years                                     -0.254237
# Percent 85 years and over                                  -0.019379
# Percent Less than $10,000                                  -0.039880
# Percent $10,000 to $14,999                                  0.230279
# Percent $15,000 to $24,999                                  0.048395
# Percent $25,000 to $34,999                                 -0.224104
# Percent $35,000 to $49,999                                  0.132557
# Percent $50,000 to $74,999                                  0.056096
# Percent $75,000 to $99,999                                  0.048714
# Percent $100,000 to $149,999                               -0.206817
# Percent $150,000 to $199,999                               -0.023989
# Percent $200,000 or more                                   -0.002210
# Percent below poverty level                                 0.152575
#
#                                                     Percent_Ballots_Cast_Dem  \
# ballots_cast                                                        0.303183
# ballots_rejected                                                    0.349369
# percent_rejected                                                    0.225124
# Percent_Ballots_Cast_Dem                                            1.000000
# Percent_Ballots_Cast_Repub                                         -0.962426
# Percent_Ballots_Cast_Unaff                                         -0.193771
# Percent_Ballots_Cast_Other                                         -0.011051
# Dem_Ballots_Cast                                                    0.673953
# Other_Ballots_Cast                                                  0.289551
# Repub_Ballots_Cast                                                 -0.282780
# Unaff_Ballots_Cast                                                  0.203078
# Dem_Ballots_Rejected                                                0.584660
# Other_Ballots_Rejected                                              0.293279
# Repub_Ballots_Rejected                                             -0.113072
# Unaff_Ballots_Rejected                                              0.268670
# Percent_Dem_Ballots_Rejected                                        0.291590
# Percent_Repub_Ballots_Rejected                                      0.265355
# Percent_Other_Ballots_Rejected                                      0.188200
# Percent_Unaff_Ballots_Rejected                                      0.161363
# Percent Hispanic or Latino                                          0.672371
# Percent White                                                      -0.877863
# Percent Black or African American                                   0.724435
# Percent American Indian and Alaska Native                           0.217964
# Percent Asian                                                       0.413119
# Percent Native Hawaiian and Other Pacific Islander                 -0.035676
# Percent Other Race                                                  0.347199
# Percent Two or more races                                           0.122352
# percent_english                                                    -0.706634
# percent_spanish                                                     0.719896
# percent_other                                                       0.493616
# percent_english_very_well                                          -0.736874
# percent_english_not_very_well                                       0.736874
# median_earnings                                                    -0.397838
# HS_and_less                                                         0.766125
# more_than_HS                                                        0.490867
# %HS_and_less                                                        0.576319
# more_than_HS%                                                      -0.576319
# Percent 15 to 19 years                                              0.109497
# Percent 20 to 24 years                                              0.323119
# Percent 25 to 34 years                                              0.774471
# Percent 35 to 44 years                                              0.860231
# Percent 45 to 54 years                                             -0.222994
# Percent 55 to 59 years                                             -0.621149
# Percent 60 to 64 years                                             -0.770176
# Percent 65 to 74 years                                             -0.786950
# Percent 75 to 84 years                                             -0.689110
# Percent 85 years and over                                          -0.570329
# Percent Less than $10,000                                           0.619328
# Percent $10,000 to $14,999                                          0.350545
# Percent $15,000 to $24,999                                          0.291162
# Percent $25,000 to $34,999                                          0.154411
# Percent $35,000 to $49,999                                          0.122723
# Percent $50,000 to $74,999                                          0.040119
# Percent $75,000 to $99,999                                         -0.266933
# Percent $100,000 to $149,999                                       -0.449659
# Percent $150,000 to $199,999                                       -0.369441
# Percent $200,000 or more                                           -0.105821
# Percent below poverty level                                         0.600124
#
#                                                     Percent_Ballots_Cast_Repub  \
# ballots_cast                                                         -0.443150
# ballots_rejected                                                     -0.466872
# percent_rejected                                                     -0.262407
# Percent_Ballots_Cast_Dem                                             -0.962426
# Percent_Ballots_Cast_Repub                                            1.000000
# Percent_Ballots_Cast_Unaff                                           -0.079352
# Percent_Ballots_Cast_Other                                           -0.015956
# Dem_Ballots_Cast                                                     -0.748728
# Other_Ballots_Cast                                                   -0.440927
# Repub_Ballots_Cast                                                    0.132187
# Unaff_Ballots_Cast                                                   -0.373086
# Dem_Ballots_Rejected                                                 -0.635959
# Other_Ballots_Rejected                                               -0.411248
# Repub_Ballots_Rejected                                               -0.050994
# Unaff_Ballots_Rejected                                               -0.413667
# Percent_Dem_Ballots_Rejected                                         -0.333874
# Percent_Repub_Ballots_Rejected                                       -0.279832
# Percent_Other_Ballots_Rejected                                       -0.248633
# Percent_Unaff_Ballots_Rejected                                       -0.182237
# Percent Hispanic or Latino                                           -0.666104
# Percent White                                                         0.894940
# Percent Black or African American                                    -0.699980
# Percent American Indian and Alaska Native                            -0.244694
# Percent Asian                                                        -0.511025
# Percent Native Hawaiian and Other Pacific Islander                   -0.026688
# Percent Other Race                                                   -0.349595
# Percent Two or more races                                            -0.026578
# percent_english                                                       0.752463
# percent_spanish                                                      -0.710400
# percent_other                                                        -0.602529
# percent_english_very_well                                             0.755612
# percent_english_not_very_well                                        -0.755612
# median_earnings                                                       0.327013
# HS_and_less                                                          -0.812725
# more_than_HS                                                         -0.603844
# %HS_and_less                                                         -0.548336
# more_than_HS%                                                         0.548336
# Percent 15 to 19 years                                               -0.247468
# Percent 20 to 24 years                                               -0.384838
# Percent 25 to 34 years                                               -0.703232
# Percent 35 to 44 years                                               -0.850449
# Percent 45 to 54 years                                                0.197977
# Percent 55 to 59 years                                                0.621080
# Percent 60 to 64 years                                                0.831411
# Percent 65 to 74 years                                                0.825690
# Percent 75 to 84 years                                                0.705562
# Percent 85 years and over                                             0.491917
# Percent Less than $10,000                                            -0.601835
# Percent $10,000 to $14,999                                           -0.327124
# Percent $15,000 to $24,999                                           -0.256783
# Percent $25,000 to $34,999                                           -0.083972
# Percent $35,000 to $49,999                                           -0.038953
# Percent $50,000 to $74,999                                            0.017987
# Percent $75,000 to $99,999                                            0.312307
# Percent $100,000 to $149,999                                          0.403304
# Percent $150,000 to $199,999                                          0.313639
# Percent $200,000 or more                                              0.039960
# Percent below poverty level                                          -0.585649
#
#                                                     Percent_Ballots_Cast_Unaff  \
# ballots_cast                                                          0.509541
# ballots_rejected                                                      0.409585
# percent_rejected                                                      0.105781
# Percent_Ballots_Cast_Dem                                             -0.193771
# Percent_Ballots_Cast_Repub                                           -0.079352
# Percent_Ballots_Cast_Unaff                                            1.000000
# Percent_Ballots_Cast_Other                                            0.035044
# Dem_Ballots_Cast                                                      0.251328
# Other_Ballots_Cast                                                    0.534271
# Repub_Ballots_Cast                                                    0.577489
# Unaff_Ballots_Cast                                                    0.622506
# Dem_Ballots_Rejected                                                  0.155675
# Other_Ballots_Rejected                                                0.406623
# Repub_Ballots_Rejected                                                0.606014
# Unaff_Ballots_Rejected                                                0.513926
# Percent_Dem_Ballots_Rejected                                          0.121654
# Percent_Repub_Ballots_Rejected                                        0.022768
# Percent_Other_Ballots_Rejected                                        0.196319
# Percent_Unaff_Ballots_Rejected                                        0.044723
# Percent Hispanic or Latino                                           -0.084388
# Percent White                                                        -0.004233
# Percent Black or African American                                    -0.124595
# Percent American Indian and Alaska Native                             0.052848
# Percent Asian                                                         0.342048
# Percent Native Hawaiian and Other Pacific Islander                    0.218955
# Percent Other Race                                                    0.011943
# Percent Two or more races                                            -0.364368
# percent_english                                                      -0.120288
# percent_spanish                                                      -0.095387
# percent_other                                                         0.382088
# percent_english_very_well                                            -0.013505
# percent_english_not_very_well                                         0.013505
# median_earnings                                                       0.309994
# HS_and_less                                                           0.129549
# more_than_HS                                                          0.397872
# %HS_and_less                                                         -0.165932
# more_than_HS%                                                         0.165932
# Percent 15 to 19 years                                                0.487457
# Percent 20 to 24 years                                                0.209775
# Percent 25 to 34 years                                               -0.327238
# Percent 35 to 44 years                                               -0.094329
# Percent 45 to 54 years                                                0.126178
# Percent 55 to 59 years                                                0.058854
# Percent 60 to 64 years                                               -0.163640
# Percent 65 to 74 years                                               -0.084460
# Percent 75 to 84 years                                               -0.001142
# Percent 85 years and over                                             0.326709
# Percent Less than $10,000                                            -0.117476
# Percent $10,000 to $14,999                                           -0.130797
# Percent $15,000 to $24,999                                           -0.169933
# Percent $25,000 to $34,999                                           -0.278372
# Percent $35,000 to $49,999                                           -0.319540
# Percent $50,000 to $74,999                                           -0.246669
# Percent $75,000 to $99,999                                           -0.162479
# Percent $100,000 to $149,999                                          0.185974
# Percent $150,000 to $199,999                                          0.247504
# Percent $200,000 or more                                              0.281981
# Percent below poverty level                                          -0.114175
#
#                                                     Percent_Ballots_Cast_Other  \
# ballots_cast                                                         -0.304064
# ballots_rejected                                                     -0.056163
# percent_rejected                                                      0.257960
# Percent_Ballots_Cast_Dem                                             -0.011051
# Percent_Ballots_Cast_Repub                                           -0.015956
# Percent_Ballots_Cast_Unaff                                            0.035044
# Percent_Ballots_Cast_Other                                            1.000000
# Dem_Ballots_Cast                                                     -0.302181
# Other_Ballots_Cast                                                   -0.029544
# Repub_Ballots_Cast                                                   -0.230479
# Unaff_Ballots_Cast                                                   -0.274977
# Dem_Ballots_Rejected                                                 -0.055768
# Other_Ballots_Rejected                                                0.068340
# Repub_Ballots_Rejected                                               -0.065529
# Unaff_Ballots_Rejected                                               -0.054427
# Percent_Dem_Ballots_Rejected                                          0.232899
# Percent_Repub_Ballots_Rejected                                        0.225339
# Percent_Other_Ballots_Rejected                                        0.188786
# Percent_Unaff_Ballots_Rejected                                        0.340156
# Percent Hispanic or Latino                                            0.354700
# Percent White                                                        -0.105094
# Percent Black or African American                                    -0.098441
# Percent American Indian and Alaska Native                             0.494810
# Percent Asian                                                        -0.170493
# Percent Native Hawaiian and Other Pacific Islander                    0.147658
# Percent Other Race                                                   -0.368574
# Percent Two or more races                                             0.153533
# percent_english                                                      -0.077118
# percent_spanish                                                       0.300009
# percent_other                                                        -0.245761
# percent_english_very_well                                            -0.183030
# percent_english_not_very_well                                         0.183030
# median_earnings                                                      -0.470076
# HS_and_less                                                          -0.078964
# more_than_HS                                                         -0.259610
# %HS_and_less                                                          0.485836
# more_than_HS%                                                        -0.485836
# Percent 15 to 19 years                                                0.106487
# Percent 20 to 24 years                                               -0.072818
# Percent 25 to 34 years                                                0.373234
# Percent 35 to 44 years                                                0.138716
# Percent 45 to 54 years                                               -0.352943
# Percent 55 to 59 years                                               -0.353613
# Percent 60 to 64 years                                               -0.216286
# Percent 65 to 74 years                                               -0.162625
# Percent 75 to 84 years                                               -0.290698
# Percent 85 years and over                                            -0.142300
# Percent Less than $10,000                                             0.283072
# Percent $10,000 to $14,999                                            0.400084
# Percent $15,000 to $24,999                                            0.444553
# Percent $25,000 to $34,999                                            0.217425
# Percent $35,000 to $49,999                                            0.133144
# Percent $50,000 to $74,999                                            0.527043
# Percent $75,000 to $99,999                                            0.210314
# Percent $100,000 to $149,999                                          0.131426
# Percent $150,000 to $199,999                                         -0.370508
# Percent $200,000 or more                                             -0.579809
# Percent below poverty level                                           0.420915
#
#                                                     Dem_Ballots_Cast  \
# ballots_cast                                                0.891481
# ballots_rejected                                            0.719951
# percent_rejected                                            0.170145
# Percent_Ballots_Cast_Dem                                    0.673953
# Percent_Ballots_Cast_Repub                                 -0.748728
# Percent_Ballots_Cast_Unaff                                  0.251328
# Percent_Ballots_Cast_Other                                 -0.302181
# Dem_Ballots_Cast                                            1.000000
# Other_Ballots_Cast                                          0.813117
# Repub_Ballots_Cast                                          0.438355
# Unaff_Ballots_Cast                                          0.834044
# Dem_Ballots_Rejected                                        0.726396
# Other_Ballots_Rejected                                      0.643340
# Repub_Ballots_Rejected                                      0.486533
# Unaff_Ballots_Rejected                                      0.713970
# Percent_Dem_Ballots_Rejected                                0.201228
# Percent_Repub_Ballots_Rejected                              0.213786
# Percent_Other_Ballots_Rejected                              0.235593
# Percent_Unaff_Ballots_Rejected                              0.079603
# Percent Hispanic or Latino                                  0.410598
# Percent White                                              -0.622010
# Percent Black or African American                           0.383102
# Percent American Indian and Alaska Native                  -0.162365
# Percent Asian                                               0.598213
# Percent Native Hawaiian and Other Pacific Islander         -0.165305
# Percent Other Race                                          0.294614
# Percent Two or more races                                  -0.106790
# percent_english                                            -0.677323
# percent_spanish                                             0.482646
# percent_other                                               0.755914
# percent_english_very_well                                  -0.607537
# percent_english_not_very_well                               0.607537
# median_earnings                                             0.052341
# HS_and_less                                                 0.888721
# more_than_HS                                                0.961522
# %HS_and_less                                                0.093673
# more_than_HS%                                              -0.093673
# Percent 15 to 19 years                                      0.084759
# Percent 20 to 24 years                                      0.227820
# Percent 25 to 34 years                                      0.423316
# Percent 35 to 44 years                                      0.608809
# Percent 45 to 54 years                                     -0.091913
# Percent 55 to 59 years                                     -0.270835
# Percent 60 to 64 years                                     -0.654267
# Percent 65 to 74 years                                     -0.610698
# Percent 75 to 84 years                                     -0.416810
# Percent 85 years and over                                  -0.235206
# Percent Less than $10,000                                   0.248081
# Percent $10,000 to $14,999                                 -0.143887
# Percent $15,000 to $24,999                                 -0.087851
# Percent $25,000 to $34,999                                 -0.189344
# Percent $35,000 to $49,999                                 -0.156222
# Percent $50,000 to $74,999                                 -0.398970
# Percent $75,000 to $99,999                                 -0.214981
# Percent $100,000 to $149,999                               -0.029491
# Percent $150,000 to $199,999                                0.057737
# Percent $200,000 or more                                    0.278217
# Percent below poverty level                                 0.127499
#
#                                                     Other_Ballots_Cast  \
# ballots_cast                                                  0.941212
# ballots_rejected                                              0.762142
# percent_rejected                                              0.161300
# Percent_Ballots_Cast_Dem                                      0.289551
# Percent_Ballots_Cast_Repub                                   -0.440927
# Percent_Ballots_Cast_Unaff                                    0.534271
# Percent_Ballots_Cast_Other                                   -0.029544
# Dem_Ballots_Cast                                              0.813117
# Other_Ballots_Cast                                            1.000000
# Repub_Ballots_Cast                                            0.771567
# Unaff_Ballots_Cast                                            0.939691
# Dem_Ballots_Rejected                                          0.605200
# Other_Ballots_Rejected                                        0.764092
# Repub_Ballots_Rejected                                        0.766876
# Unaff_Ballots_Rejected                                        0.802417
# Percent_Dem_Ballots_Rejected                                  0.149366
# Percent_Repub_Ballots_Rejected                                0.210343
# Percent_Other_Ballots_Rejected                                0.271562
# Percent_Unaff_Ballots_Rejected                                0.089177
# Percent Hispanic or Latino                                    0.267569
# Percent White                                                -0.311393
# Percent Black or African American                            -0.027655
# Percent American Indian and Alaska Native                    -0.259242
# Percent Asian                                                 0.505924
# Percent Native Hawaiian and Other Pacific Islander           -0.193978
# Percent Other Race                                            0.068654
# Percent Two or more races                                    -0.210991
# percent_english                                              -0.501579
# percent_spanish                                               0.314936
# percent_other                                                 0.618931
# percent_english_very_well                                    -0.429916
# percent_english_not_very_well                                 0.429916
# median_earnings                                               0.170750
# HS_and_less                                                   0.693587
# more_than_HS                                                  0.913424
# %HS_and_less                                                 -0.085130
# more_than_HS%                                                 0.085130
# Percent 15 to 19 years                                        0.090657
# Percent 20 to 24 years                                        0.142841
# Percent 25 to 34 years                                        0.246356
# Percent 35 to 44 years                                        0.287363
# Percent 45 to 54 years                                       -0.236352
# Percent 55 to 59 years                                       -0.163025
# Percent 60 to 64 years                                       -0.510743
# Percent 65 to 74 years                                       -0.382926
# Percent 75 to 84 years                                       -0.182425
# Percent 85 years and over                                     0.012106
# Percent Less than $10,000                                     0.032067
# Percent $10,000 to $14,999                                   -0.289959
# Percent $15,000 to $24,999                                   -0.120550
# Percent $25,000 to $34,999                                   -0.224961
# Percent $35,000 to $49,999                                   -0.261898
# Percent $50,000 to $74,999                                   -0.407433
# Percent $75,000 to $99,999                                   -0.046373
# Percent $100,000 to $149,999                                  0.315121
# Percent $150,000 to $199,999                                  0.159328
# Percent $200,000 or more                                      0.243888
# Percent below poverty level                                  -0.027080
#
#                                                     Repub_Ballots_Cast  \
# ballots_cast                                                  0.792562
# ballots_rejected                                              0.445443
# percent_rejected                                             -0.124314
# Percent_Ballots_Cast_Dem                                     -0.282780
# Percent_Ballots_Cast_Repub                                    0.132187
# Percent_Ballots_Cast_Unaff                                    0.577489
# Percent_Ballots_Cast_Other                                   -0.230479
# Dem_Ballots_Cast                                              0.438355
# Other_Ballots_Cast                                            0.771567
# Repub_Ballots_Cast                                            1.000000
# Unaff_Ballots_Cast                                            0.826640
# Dem_Ballots_Rejected                                          0.175827
# Other_Ballots_Rejected                                        0.443691
# Repub_Ballots_Rejected                                        0.757255
# Unaff_Ballots_Rejected                                        0.513374
# Percent_Dem_Ballots_Rejected                                 -0.142952
# Percent_Repub_Ballots_Rejected                               -0.084413
# Percent_Other_Ballots_Rejected                                0.020196
# Percent_Unaff_Ballots_Rejected                               -0.180325
# Percent Hispanic or Latino                                   -0.207081
# Percent White                                                 0.225614
# Percent Black or African American                            -0.355504
# Percent American Indian and Alaska Native                    -0.393111
# Percent Asian                                                 0.201351
# Percent Native Hawaiian and Other Pacific Islander           -0.215888
# Percent Other Race                                           -0.046026
# Percent Two or more races                                    -0.264900
# percent_english                                              -0.014565
# percent_spanish                                              -0.193241
# percent_other                                                 0.293873
# percent_english_very_well                                     0.076379
# percent_english_not_very_well                                -0.076379
# median_earnings                                               0.462961
# HS_and_less                                                   0.195575
# more_than_HS                                                  0.626405
# %HS_and_less                                                 -0.496142
# more_than_HS%                                                 0.496142
# Percent 15 to 19 years                                        0.025352
# Percent 20 to 24 years                                       -0.076234
# Percent 25 to 34 years                                       -0.273587
# Percent 35 to 44 years                                       -0.226929
# Percent 45 to 54 years                                       -0.017010
# Percent 55 to 59 years                                        0.257563
# Percent 60 to 64 years                                       -0.057328
# Percent 65 to 74 years                                        0.067424
# Percent 75 to 84 years                                        0.258087
# Percent 85 years and over                                     0.341902
# Percent Less than $10,000                                    -0.365974
# Percent $10,000 to $14,999                                   -0.558409
# Percent $15,000 to $24,999                                   -0.313370
# Percent $25,000 to $34,999                                   -0.328471
# Percent $35,000 to $49,999                                   -0.347399
# Percent $50,000 to $74,999                                   -0.447795
# Percent $75,000 to $99,999                                    0.010399
# Percent $100,000 to $149,999                                  0.485309
# Percent $150,000 to $199,999                                  0.377015
# Percent $200,000 or more                                      0.407894
# Percent below poverty level                                  -0.450435
#
#                                                     Unaff_Ballots_Cast  \
# ballots_cast                                                  0.987798
# ballots_rejected                                              0.736541
# percent_rejected                                              0.087889
# Percent_Ballots_Cast_Dem                                      0.203078
# Percent_Ballots_Cast_Repub                                   -0.373086
# Percent_Ballots_Cast_Unaff                                    0.622506
# Percent_Ballots_Cast_Other                                   -0.274977
# Dem_Ballots_Cast                                              0.834044
# Other_Ballots_Cast                                            0.939691
# Repub_Ballots_Cast                                            0.826640
# Unaff_Ballots_Cast                                            1.000000
# Dem_Ballots_Rejected                                          0.555388
# Other_Ballots_Rejected                                        0.690168
# Repub_Ballots_Rejected                                        0.783761
# Unaff_Ballots_Rejected                                        0.789464
# Percent_Dem_Ballots_Rejected                                  0.090611
# Percent_Repub_Ballots_Rejected                                0.114032
# Percent_Other_Ballots_Rejected                                0.209783
# Percent_Unaff_Ballots_Rejected                                0.000433
# Percent Hispanic or Latino                                    0.121072
# Percent White                                                -0.245321
# Percent Black or African American                             0.004470
# Percent American Indian and Alaska Native                    -0.269937
# Percent Asian                                                 0.519679
# Percent Native Hawaiian and Other Pacific Islander           -0.154665
# Percent Other Race                                            0.131801
# Percent Two or more races                                    -0.249672
# percent_english                                              -0.426802
# percent_spanish                                               0.169076
# percent_other                                                 0.660788
# percent_english_very_well                                    -0.318197
# percent_english_not_very_well                                 0.318197
# median_earnings                                               0.310565
# HS_and_less                                                   0.631727
# more_than_HS                                                  0.932179
# %HS_and_less                                                 -0.217812
# more_than_HS%                                                 0.217812
# Percent 15 to 19 years                                        0.136336
# Percent 20 to 24 years                                        0.120121
# Percent 25 to 34 years                                        0.043935
# Percent 35 to 44 years                                        0.213520
# Percent 45 to 54 years                                       -0.037527
# Percent 55 to 59 years                                       -0.007052
# ...
# Percent 45 to 54 years                                                  0.256720
# Percent 55 to 59 years                                                  0.501000
# Percent 60 to 64 years                                                  0.294718
# Percent 65 to 74 years                                                  0.170258
# Percent 75 to 84 years                                                  0.088185
# Percent 85 years and over                                               0.031757
# Percent Less than $10,000                                              -0.552428
# Percent $10,000 to $14,999                                             -0.747358
# Percent $15,000 to $24,999                                             -0.601302
# Percent $25,000 to $34,999                                             -0.492266
# Percent $35,000 to $49,999                                             -0.646951
# Percent $50,000 to $74,999                                             -0.406287
# Percent $75,000 to $99,999                                              0.436032
# Percent $100,000 to $149,999                                            1.000000
# Percent $150,000 to $199,999                                            0.655763
# Percent $200,000 or more                                                0.340549
# Percent below poverty level                                            -0.704896
#
#                                                     Percent $150,000 to $199,999  \
# ballots_cast                                                            0.231552
# ballots_rejected                                                        0.164017
# percent_rejected                                                       -0.023989
# Percent_Ballots_Cast_Dem                                               -0.369441
# Percent_Ballots_Cast_Repub                                              0.313639
# Percent_Ballots_Cast_Unaff                                              0.247504
# Percent_Ballots_Cast_Other                                             -0.370508
# Dem_Ballots_Cast                                                        0.057737
# Other_Ballots_Cast                                                      0.159328
# Repub_Ballots_Cast                                                      0.377015
# Unaff_Ballots_Cast                                                      0.264923
# Dem_Ballots_Rejected                                                    0.055228
# Other_Ballots_Rejected                                                  0.178342
# Repub_Ballots_Rejected                                                  0.271713
# Unaff_Ballots_Rejected                                                  0.205478
# Percent_Dem_Ballots_Rejected                                           -0.018768
# Percent_Repub_Ballots_Rejected                                          0.010232
# Percent_Other_Ballots_Rejected                                          0.123223
# Percent_Unaff_Ballots_Rejected                                         -0.058555
# Percent Hispanic or Latino                                             -0.447596
# Percent White                                                           0.429912
# Percent Black or African American                                      -0.588324
# Percent American Indian and Alaska Native                              -0.683872
# Percent Asian                                                           0.320197
# Percent Native Hawaiian and Other Pacific Islander                     -0.066863
# Percent Other Race                                                      0.097579
# Percent Two or more races                                              -0.311359
# percent_english                                                         0.100197
# percent_spanish                                                        -0.357797
# percent_other                                                           0.279459
# percent_english_very_well                                               0.235229
# percent_english_not_very_well                                          -0.235229
# median_earnings                                                         0.904109
# HS_and_less                                                            -0.205213
# more_than_HS                                                            0.131333
# %HS_and_less                                                           -0.773779
# more_than_HS%                                                           0.773779
# Percent 15 to 19 years                                                  0.160860
# Percent 20 to 24 years                                                  0.202944
# Percent 25 to 34 years                                                 -0.428229
# Percent 35 to 44 years                                                 -0.114832
# Percent 45 to 54 years                                                  0.709031
# Percent 55 to 59 years                                                  0.671003
# Percent 60 to 64 years                                                  0.309392
# Percent 65 to 74 years                                                  0.064559
# Percent 75 to 84 years                                                  0.036179
# Percent 85 years and over                                               0.059296
# Percent Less than $10,000                                              -0.781825
# Percent $10,000 to $14,999                                             -0.712969
# Percent $15,000 to $24,999                                             -0.831170
# Percent $25,000 to $34,999                                             -0.866966
# Percent $35,000 to $49,999                                             -0.706395
# Percent $50,000 to $74,999                                             -0.757598
# Percent $75,000 to $99,999                                              0.235997
# Percent $100,000 to $149,999                                            0.655763
# Percent $150,000 to $199,999                                            1.000000
# Percent $200,000 or more                                                0.762330
# Percent below poverty level                                            -0.817359
#
#                                                     Percent $200,000 or more  \
# ballots_cast                                                        0.394058
# ballots_rejected                                                    0.292059
# percent_rejected                                                   -0.002210
# Percent_Ballots_Cast_Dem                                           -0.105821
# Percent_Ballots_Cast_Repub                                          0.039960
# Percent_Ballots_Cast_Unaff                                          0.281981
# Percent_Ballots_Cast_Other                                         -0.579809
# Dem_Ballots_Cast                                                    0.278217
# Other_Ballots_Cast                                                  0.243888
# Repub_Ballots_Cast                                                  0.407894
# Unaff_Ballots_Cast                                                  0.408990
# Dem_Ballots_Rejected                                                0.240000
# Other_Ballots_Rejected                                              0.269487
# Repub_Ballots_Rejected                                              0.326238
# Unaff_Ballots_Rejected                                              0.294138
# Percent_Dem_Ballots_Rejected                                        0.031782
# Percent_Repub_Ballots_Rejected                                      0.054072
# Percent_Other_Ballots_Rejected                                      0.197778
# Percent_Unaff_Ballots_Rejected                                     -0.081330
# Percent Hispanic or Latino                                         -0.174010
# Percent White                                                       0.077844
# Percent Black or African American                                  -0.315166
# Percent American Indian and Alaska Native                          -0.460480
# Percent Asian                                                       0.507772
# Percent Native Hawaiian and Other Pacific Islander                 -0.265832
# Percent Other Race                                                  0.349563
# Percent Two or more races                                          -0.477468
# percent_english                                                    -0.186265
# percent_spanish                                                    -0.104938
# percent_other                                                       0.531567
# percent_english_very_well                                          -0.029851
# percent_english_not_very_well                                       0.029851
# median_earnings                                                     0.861792
# HS_and_less                                                         0.029958
# more_than_HS                                                        0.329982
# %HS_and_less                                                       -0.590353
# more_than_HS%                                                       0.590353
# Percent 15 to 19 years                                              0.218595
# Percent 20 to 24 years                                              0.093333
# Percent 25 to 34 years                                             -0.246362
# Percent 35 to 44 years                                              0.103427
# Percent 45 to 54 years                                              0.655929
# Percent 55 to 59 years                                              0.570140
# Percent 60 to 64 years                                              0.053335
# Percent 65 to 74 years                                             -0.146636
# Percent 75 to 84 years                                             -0.105826
# Percent 85 years and over                                          -0.028095
# Percent Less than $10,000                                          -0.455313
# Percent $10,000 to $14,999                                         -0.673272
# Percent $15,000 to $24,999                                         -0.852403
# Percent $25,000 to $34,999                                         -0.749954
# Percent $35,000 to $49,999                                         -0.768447
# Percent $50,000 to $74,999                                         -0.847923
# Percent $75,000 to $99,999                                         -0.243687
# Percent $100,000 to $149,999                                        0.340549
# Percent $150,000 to $199,999                                        0.762330
# Percent $200,000 or more                                            1.000000
# Percent below poverty level                                        -0.652529
#
#                                                     Percent below poverty level
# ballots_cast                                                          -0.133184
# ballots_rejected                                                      -0.029357
# percent_rejected                                                       0.152575
# Percent_Ballots_Cast_Dem                                               0.600124
# Percent_Ballots_Cast_Repub                                            -0.585649
# Percent_Ballots_Cast_Unaff                                            -0.114175
# Percent_Ballots_Cast_Other                                             0.420915
# Dem_Ballots_Cast                                                       0.127499
# Other_Ballots_Cast                                                    -0.027080
# Repub_Ballots_Cast                                                    -0.450435
# Unaff_Ballots_Cast                                                    -0.171801
# Dem_Ballots_Rejected                                                   0.134833
# Other_Ballots_Rejected                                                -0.004393
# Repub_Ballots_Rejected                                                -0.295644
# Unaff_Ballots_Rejected                                                -0.075257
# Percent_Dem_Ballots_Rejected                                           0.189351
# Percent_Repub_Ballots_Rejected                                         0.129064
# Percent_Other_Ballots_Rejected                                         0.037067
# Percent_Unaff_Ballots_Rejected                                         0.159334
# Percent Hispanic or Latino                                             0.653168
# Percent White                                                         -0.652419
# Percent Black or African American                                      0.624640
# Percent American Indian and Alaska Native                              0.555528
# Percent Asian                                                         -0.051811
# Percent Native Hawaiian and Other Pacific Islander                     0.277339
# Percent Other Race                                                    -0.103445
# Percent Two or more races                                              0.091486
# percent_english                                                       -0.394528
# percent_spanish                                                        0.610393
# percent_other                                                         -0.008771
# percent_english_very_well                                             -0.534237
# percent_english_not_very_well                                          0.534237
# median_earnings                                                       -0.805254
# HS_and_less                                                            0.455242
# more_than_HS                                                           0.038020
# %HS_and_less                                                           0.852867
# more_than_HS%                                                         -0.852867
# Percent 15 to 19 years                                                -0.008686
# Percent 20 to 24 years                                                 0.199865
# Percent 25 to 34 years                                                 0.610796
# Percent 35 to 44 years                                                 0.404509
# Percent 45 to 54 years                                                -0.625996
# Percent 55 to 59 years                                                -0.870881
# Percent 60 to 64 years                                                -0.513319
# Percent 65 to 74 years                                                -0.356622
# Percent 75 to 84 years                                                -0.292948
# Percent 85 years and over                                             -0.220663
# Percent Less than $10,000                                              0.800941
# Percent $10,000 to $14,999                                             0.863541
# Percent $15,000 to $24,999                                             0.811141
# Percent $25,000 to $34,999                                             0.645735
# Percent $35,000 to $49,999                                             0.565146
# Percent $50,000 to $74,999                                             0.556651
# Percent $75,000 to $99,999                                            -0.289008
# Percent $100,000 to $149,999                                          -0.704896
# Percent $150,000 to $199,999                                          -0.817359
# Percent $200,000 or more                                              -0.652529
# Percent below poverty level                                            1.000000

# %%
y = df['percent_rejected']

# %%
model = LinearRegression()

# %%
features = ['Percent_Ballots_Cast_Other',
            '%HS_and_less',
            'Percent Hispanic or Latino',
            'Percent Black or African American',
            'Percent American Indian and Alaska Native',
            'Percent Asian',
            'Percent Native Hawaiian and Other Pacific Islander',
            'Percent Other Race',
            'percent_spanish',
            'percent_other']

X = df[features]

# %%
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 2.70
# R^2: 0.69692

# %%
#check multicollinearity among selected features

from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(X)
# Out:
#                                            variables         VIF
# 0                         Percent_Ballots_Cast_Other   36.304482
# 1                                       %HS_and_less  135.091747
# 2                         Percent Hispanic or Latino  397.995414
# 3                  Percent Black or African American    9.777665
# 4          Percent American Indian and Alaska Native    3.340204
# 5                                      Percent Asian   25.821020
# 6  Percent Native Hawaiian and Other Pacific Isla...    1.711732
# 7                                 Percent Other Race    2.492397
# 8                                    percent_spanish  210.315508
# 9                                      percent_other   49.346454

# %%
# Only include features w/ low multicollinearity

features = ['Percent_Ballots_Cast_Other',
            'Percent Black or African American',
            'Percent Native Hawaiian and Other Pacific Islander',
            'Percent Other Race',
            'percent_spanish']

X = df[features]
calc_vif(X)
# Out:
#                                            variables       VIF
# 0                         Percent_Ballots_Cast_Other  4.010286
# 1                  Percent Black or African American  3.347087
# 2  Percent Native Hawaiian and Other Pacific Isla...  1.304543
# 3                                 Percent Other Race  1.862095
# 4                                    percent_spanish  3.732140

# %%
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 3.39
# R^2: 0.61945

# %%
pd.Series(model.coef_, index=X.columns)
# Out:
# Percent_Ballots_Cast_Other                            1.026140
# Percent Black or African American                    -0.027437
# Percent Native Hawaiian and Other Pacific Islander    2.036379
# Percent Other Race                                    0.681579
# percent_spanish                                       0.031350
# dtype: float64

# %%
# Let's try a model that exclusively focuses on race
# Leave Percent White out to avoid multicollinearity

race_features = ['Percent Hispanic or Latino',
                 'Percent Black or African American',
                 'Percent American Indian and Alaska Native',
                 'Percent Asian',
                 'Percent Native Hawaiian and Other Pacific Islander',
                 'Percent Other Race',
                 'Percent Two or more races']

X = df[race_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 3.64
# R^2: 0.59089

# %%
pd.Series(model.coef_, index=X.columns)
# Out:
# Percent Hispanic or Latino                            0.033202
# Percent Black or African American                    -0.038045
# Percent American Indian and Alaska Native             0.089499
# Percent Asian                                        -0.004549
# Percent Native Hawaiian and Other Pacific Islander    1.987262
# Percent Other Race                                    0.677328
# Percent Two or more races                             0.302798
# dtype: float64

# %%
calc_vif(X)
# Out:
#                                            variables       VIF
# 0                         Percent Hispanic or Latino  5.451351
# 1                  Percent Black or African American  4.429003
# 2          Percent American Indian and Alaska Native  2.237216
# 3                                      Percent Asian  2.995101
# 4  Percent Native Hawaiian and Other Pacific Isla...  1.465120
# 5                                 Percent Other Race  2.172802
# 6                          Percent Two or more races  4.406550

# %%
# Take out Hispanic/Latino due to high multicollinearity

# %%
race_features = ['Percent Black or African American',
                 'Percent American Indian and Alaska Native',
                 'Percent Asian',
                 'Percent Native Hawaiian and Other Pacific Islander',
                 'Percent Other Race',
                 'Percent Two or more races']

X = df[race_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 5.21
# R^2: 0.41405

# %%
# Let's check VIF again.

calc_vif(X)
# Out:
#                                            variables       VIF
# 0                  Percent Black or African American  4.156398
# 1          Percent American Indian and Alaska Native  1.894527
# 2                                      Percent Asian  2.397500
# 3  Percent Native Hawaiian and Other Pacific Isla...  1.378170
# 4                                 Percent Other Race  2.122488
# 5                          Percent Two or more races  4.035775

# %%
# VIF Improved but R^2 dropped sharply. What if we take out Two+ instead?

# %%
race_features = ['Percent Hispanic or Latino',
                 'Percent Black or African American',
                 'Percent American Indian and Alaska Native',
                 'Percent Native Hawaiian and Other Pacific Islander',
                 'Percent Other Race']

X = df[race_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 4.02
# R^2: 0.54807

# %%
pd.Series(model.coef_, index=X.columns)
# Out:
# Percent Hispanic or Latino                            0.028659
# Percent Black or African American                    -0.034303
# Percent American Indian and Alaska Native             0.332514
# Percent Native Hawaiian and Other Pacific Islander    2.181314
# Percent Other Race                                    0.604835
# dtype: float64

# %%
calc_vif(X)
# Out:
#                                            variables       VIF
# 0                         Percent Hispanic or Latino  3.349526
# 1                  Percent Black or African American  3.717496
# 2          Percent American Indian and Alaska Native  2.092517
# 3  Percent Native Hawaiian and Other Pacific Isla...  1.235029
# 4                                 Percent Other Race  2.042037

# %%
# Performs better. Also, removing % Asian did not negatively impact R^2

# %%
# Language-only model

language_features = ['percent_spanish', 'percent_other']

X = df[language_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 6.53
# R^2: 0.26550

# %%
# Performs poorly

# %%
calc_vif(X)
# Out:
#          variables       VIF
# 0  percent_spanish  3.709282
# 1    percent_other  3.709282

# %%
#age-only

age_features = [
'Percent 20 to 24 years',
'Percent 25 to 34 years',
'Percent 35 to 44 years',
'Percent 45 to 54 years',
'Percent 55 to 59 years',
'Percent 60 to 64 years',
'Percent 65 to 74 years',
'Percent 75 to 84 years',
'Percent 85 years and over']

X = df[age_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 5.39
# R^2: 0.39415

# %%
calc_vif(X)
# Out:
#                    variables          VIF
# 0     Percent 20 to 24 years   174.217125
# 1     Percent 25 to 34 years   157.742404
# 2     Percent 35 to 44 years   881.347030
# 3     Percent 45 to 54 years  1324.721526
# 4     Percent 55 to 59 years   285.608899
# 5     Percent 60 to 64 years  1709.141125
# 6     Percent 65 to 74 years  2036.004473
# 7     Percent 75 to 84 years   210.416225
# 8  Percent 85 years and over   200.509332

# %%
# Performs poorly and high VIF

# %%
#income-only

income_features = ['Percent Less than $10,000',
'Percent $10,000 to $14,999',
'Percent $150,000 to $199,999']

X = df[income_features]

# %%
model = LinearRegression()
model.fit(X, y)
print("RSS: %.2f" % np.sum((model.predict(X) - y) ** 2))
print("R^2: %.5f" % model.score(X, y))
# Out:
# RSS: 7.97
# R^2: 0.10472

# %%
calc_vif(X)
# Out:
#                       variables       VIF
# 0     Percent Less than $10,000  8.442775
# 1    Percent $10,000 to $14,999  8.485597
# 2  Percent $150,000 to $199,999  3.524652

# %%
#Performs too poorly once multicollinearity is reduced

# %%
fig, ax = plt.subplots(figsize=(10,8))

sns.regplot(x='Percent_Ballots_Cast_Other',
           y='percent_rejected',
           data=df,
           ax=ax)
ax.set(xlabel='Percent of Ballots cast by 3rd Party Voters',
       ylabel='Rejected Absentee/Mail-in Ballots Rate (%)\n',
       title="Rejected Absentee/Mail-in Ballots vs 3rd Party Affiliation\n")

ax.set_xticklabels(['{:,.0f}'.format(x) for x in ax.get_xticks()])

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))

sns.regplot(x='Percent 60 to 64 years',
           y='percent_rejected',
           data=df,
           ax=ax)
ax.set(xlabel='Percent 60 to 64 years',
       ylabel='Rejected Absentee/Mail-in Ballots Rate (%)\n',
       title="Rejected Absentee/Mail-in Ballots vs 3rd Party Affiliation\n")

ax.set_xticklabels(['{:,.0f}'.format(x) for x in ax.get_xticks()])

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))

sns.regplot(x='Percent 35 to 44 years',
           y='percent_rejected',
           data=df,
           ax=ax)
ax.set(xlabel='Percent 35 to 44 years',
       ylabel='Rejected Absentee/Mail-in Ballots Rate (%)\n',
       title="Rejected Absentee/Mail-in Ballots vs 3rd Party Affiliation\n")

ax.set_xticklabels(['{:,.0f}'.format(x) for x in ax.get_xticks()])

plt.show()
