# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan'

# %%
cd C:\\Users\\aidan\\downloads\poverty_stats
# Out:
# C:\Users\aidan\downloads\poverty_stats

# %%
poverty = pd.read_csv('poverty.csv')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
poverty.head()
# Out:
#            GEO_ID                           NAME  \
# 0              id           Geographic Area Name
# 1  0500000US34001    Atlantic County, New Jersey
# 2  0500000US34003      Bergen County, New Jersey
# 3  0500000US34005  Burlington County, New Jersey
# 4  0500000US34007      Camden County, New Jersey
#
#                                       S1701_C01_001E  \
# 0  Estimate!!Total!!Population for whom poverty s...
# 1                                             258409
# 2                                             922214
# 3                                             433658
# 4                                             498864
#
#                                       S1701_C01_001M  \
# 0  Margin of Error!!Total!!Population for whom po...
# 1                                                815
# 2                                               1724
# 3                                               1817
# 4                                               1613
#
# ...

# %%
age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Columns: 358 entries, GEO_ID to DP05_0089PM
# dtypes: object(358)
# memory usage: 61.7+ KB

# %%
poverty = poverty[['S1701_C03_001E']]

# %%
new_header = poverty.iloc[0] #grab the first row for the header
poverty = poverty[1:] #take the data less the header row
poverty.columns = new_header #set the header row as the df header

poverty
# Out:
# 0  Estimate!!Percent below poverty level!!Population for whom poverty status is determined
# 1                                                11.1
# 2                                                 5.6
# 3                                                 5.5
# 4                                                10.7
# 5                                                 8.8
# 6                                                13.2
# 7                                                13.9
# 8                                                 7.7
# 9                                                13.9
# 10                                                3.6
# 11                                               12.8
# 12                                                8.8
# 13                                                6.0
# 14                                                5.5
# 15                                                9.0
# 16                                               13.4
# ...

# %%
poverty.columns = ['Percent below poverty level']

# %%
poverty
# Out:
#    Percent below poverty level
# 1                         11.1
# 2                          5.6
# 3                          5.5
# 4                         10.7
# 5                          8.8
# 6                         13.2
# 7                         13.9
# 8                          7.7
# 9                         13.9
# 10                         3.6
# 11                        12.8
# 12                         8.8
# 13                         6.0
# 14                         5.5
# 15                         9.0
# 16                        13.4
# 17                        12.4
# 18                         5.7
# 19                         4.7
# 20                         9.1
# 21                         6.8

# %%
cd C:\\Users\\aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan
# Out:
# C:\Users\aidan\Documents\GitHub\VBM_Rejection_Factors\Aidan

# %%
poverty.to_csv('poverty_clean.csv', index=False)
