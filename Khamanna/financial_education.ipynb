# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None) # display all the columns of a dataframe
pd.set_option('display.max_rows', 100)

# %%
education = pd.read_csv('./education/ACSST1Y2019.S1501_data_with_overlays_2020-12-09T112526.csv')#.transpose()

# %%
#education_metadata = pd.read_csv('./education/ACSST1Y2019.S1501_metadata_2020-12-09T112526.csv')
# education_metadata = pd.read_csv('./education/ACSST1Y2019.S1501_metadata_2020-12-09T112526.csv')
# education_metadata.id.unique()

# %%
financial_education=education[['NAME','S1501_C03_059E','S1501_C03_060E', 'S1501_C03_061E','S1501_C03_062E',\
'S1501_C03_063E', 'S1501_C03_064E']]

# %%
#financial_education

# %%
financial_education.columns = ['name','median_earnings', 'less_than_highschool','highschool','associate','bachelors','graduate']

# %%
financial_education=financial_education.drop(financial_education.index[0])
financial_education
# Out:
#                              name median_earnings less_than_highschool  \
# 1     Atlantic County, New Jersey           45935                30979
# 2       Bergen County, New Jersey           72267                31753
# 3   Burlington County, New Jersey           61748                28479
# 4       Camden County, New Jersey           51486                30276
# 5     Cape May County, New Jersey           51483                45524
# 6   Cumberland County, New Jersey           34905                25125
# 7        Essex County, New Jersey           51029                31652
# 8   Gloucester County, New Jersey           64004                38567
# 9       Hudson County, New Jersey           58372                35137
# 10   Hunterdon County, New Jersey           80882                30165
# 11      Mercer County, New Jersey           57023                32171
# 12   Middlesex County, New Jersey           65047                36941
# ...

# %%
financial_education.to_csv('financial_education.csv')

# %%
education_age=education[['NAME','S1501_C04_002E', 'S1501_C04_003E', 'S1501_C04_004E', 'S1501_C04_005E', \
                         'S1501_C04_007E','S1501_C04_008E', 'S1501_C04_009E', 'S1501_C04_010E', 'S1501_C04_011E', \
                         'S1501_C04_012E', 'S1501_C04_013E', 'S1501_C04_014E', 'S1501_C04_015E', 'S1501_C04_017E', \
                         'S1501_C04_018E', 'S1501_C04_020E', 'S1501_C04_021E', 'S1501_C04_023E', 'S1501_C04_024E', \
                         'S1501_C04_026E','S1501_C04_027E']]

# %%
education_age
# Out:
#                              NAME  \
# 0            Geographic Area Name
# 1     Atlantic County, New Jersey
# 2       Bergen County, New Jersey
# 3   Burlington County, New Jersey
# 4       Camden County, New Jersey
# 5     Cape May County, New Jersey
# 6   Cumberland County, New Jersey
# 7        Essex County, New Jersey
# 8   Gloucester County, New Jersey
# 9       Hudson County, New Jersey
# 10   Hunterdon County, New Jersey
# 11      Mercer County, New Jersey
# 12   Middlesex County, New Jersey
# 13    Monmouth County, New Jersey
# 14      Morris County, New Jersey
# 15       Ocean County, New Jersey
# 16     Passaic County, New Jersey
# 17       Salem County, New Jersey
# 18    Somerset County, New Jersey
# 19      Sussex County, New Jersey
# 20       Union County, New Jersey
# 21      Warren County, New Jersey
#
#                                        S1501_C04_002E  \
# 0   Estimate!!Percent Male!!AGE BY EDUCATIONAL ATT...
# ...

# %%
education_age.columns =['name','18_24_less_than_HS',
       '18_24_HS_grad',
       "18_24_associate",
       "18_24_bachelor",
       'over_25_less_9grade',
       'over_25_9_12th grade_no_diploma',
       'over_25_HS_grad',
       'over_25_some_college_no_degree',
       "over_25_associate",
       "over_25_bachelors",
       'over_25_graduate',
       'over_25_HS_grad_or_higher',
       "over_25_bachelors_or_higher",
       '25_34_HS_grad_or_higher',
       "25_34_bachelors_or_higher",
       '35_44_HS_grad_or_higher',
       "35_44_bachelors_or_higher",
       '45_64_HS_grad_or_higher',
       "45_64_bachelors_or_higher",
       'over_65_HS_grad_or_higher',
       "over_65_bachelors_or_higher"]

# %%
education_age=education_age.drop(education_age.index[0])

# %%
# education_metadata = pd.read_csv('./education/ACSST1Y2019.S1501_metadata_2020-12-09T112526.csv')
education_metadata.id.unique()
# Out:
# array(['Geographic Area Name',
#        'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#        'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#        'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#        'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#        'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#        "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
#        "Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
# ...

# %%
education_age_real_nums = education[['NAME', 'S1501_C01_001E', \
'S1501_C01_002E', 'S1501_C01_003E', 'S1501_C01_004E', 'S1501_C01_005E', 'S1501_C01_006E', 'S1501_C01_007E', 'S1501_C01_008E', \
'S1501_C01_009E', 'S1501_C01_010E', 'S1501_C01_011E', 'S1501_C01_012E', 'S1501_C01_013E', 'S1501_C01_014E', 'S1501_C01_015E', \
'S1501_C01_016E', 'S1501_C01_017E', \
'S1501_C01_018E', 'S1501_C01_019E', 'S1501_C01_020E', 'S1501_C01_021E', 'S1501_C01_022E', 'S1501_C01_023E', 'S1501_C01_024E', 
'S1501_C01_025E', 'S1501_C01_026E', 'S1501_C01_027E']]

# %%
education_age_real_nums.columns = ['name',
       'Pop18_24',
'18_24_less_than_HS',
'18_24_HS_grad',
"18_24_associate",
        "18_24_bachelor",   
       'Pop_over_25',
       'over_25_less_9grade',
       'over_25_9_12th grade_no_diploma',
       'over_25_HS_grad',
       'over_25_some_college_no_degree',
       "over_25_associate",
       "over_25_bachelors",
       'over_25_graduate',
       'over_25_HS_grad_or_higher',
       'over_25_bachelors_or_higher',
       'Pop25_34',
       '25_34_HS_grad_or_higher',
       "25_34_bachelors_or_higher",
       'Pop35_44',
       '35_44_HS_grad_or_higher',      
       "35_44_bachelors_or_higher",
       'Pop45_64',
       '45_64_HS_grad_or_higher',
       "45_64_bachelors_or_higher",
       'Pop_over_65',
       'over_65_HS_grad_or_higher',
       "over_65_bachelors_or_higher"]

# %%
education_age_real_nums=education_age_real_nums.drop(education_age_real_nums.index[0])
#education_age_real_nums['18_24_less_than_HS'].astype(int)

# %%
education_age_real_nums['Pop18_24']=education_age_real_nums['Pop18_24'].astype(int)
education_age_real_nums['18_24_less_than_HS']=education_age_real_nums['18_24_less_than_HS'].astype(int)
education_age_real_nums['18_24_HS_grad']=education_age_real_nums['18_24_HS_grad'].astype(int)
education_age_real_nums["18_24_associate"]=education_age_real_nums["18_24_associate"].astype(int)
education_age_real_nums["18_24_bachelor"]=education_age_real_nums["18_24_bachelor"].astype(int)
education_age_real_nums['Pop_over_25']=education_age_real_nums['Pop_over_25'].astype(int)
education_age_real_nums['over_25_less_9grade']=education_age_real_nums['over_25_less_9grade'].astype(int)
education_age_real_nums['over_25_9_12th grade_no_diploma']=education_age_real_nums['over_25_9_12th grade_no_diploma'].astype(int)
education_age_real_nums['over_25_HS_grad']=education_age_real_nums['over_25_HS_grad'].astype(int)
education_age_real_nums['over_25_some_college_no_degree']=education_age_real_nums['over_25_some_college_no_degree'].astype(int)
education_age_real_nums["over_25_associate"]=education_age_real_nums["over_25_associate"].astype(int)
education_age_real_nums["over_25_bachelors"]=education_age_real_nums["over_25_bachelors"].astype(int)
education_age_real_nums['over_25_graduate']=education_age_real_nums['over_25_graduate'].astype(int)
education_age_real_nums['over_25_HS_grad_or_higher']=education_age_real_nums['over_25_HS_grad_or_higher'].astype(int)
education_age_real_nums['over_25_bachelors_or_higher']=education_age_real_nums['over_25_bachelors_or_higher'].astype(int)
education_age_real_nums['Pop25_34']=education_age_real_nums['Pop25_34'].astype(int)
education_age_real_nums['25_34_HS_grad_or_higher']=education_age_real_nums['25_34_HS_grad_or_higher'].astype(int)
education_age_real_nums["25_34_bachelors_or_higher"]=education_age_real_nums["25_34_bachelors_or_higher"].astype(int)
education_age_real_nums['Pop35_44']=education_age_real_nums['Pop35_44'].astype(int)
education_age_real_nums['35_44_HS_grad_or_higher']= education_age_real_nums['35_44_HS_grad_or_higher'].astype(int)     
education_age_real_nums["35_44_bachelors_or_higher"]=education_age_real_nums["35_44_bachelors_or_higher"].astype(int)
education_age_real_nums['Pop45_64']=education_age_real_nums['Pop45_64'].astype(int)
education_age_real_nums['45_64_HS_grad_or_higher']=education_age_real_nums['45_64_HS_grad_or_higher'].astype(int)
education_age_real_nums["45_64_bachelors_or_higher"]=education_age_real_nums["45_64_bachelors_or_higher"].astype(int)
education_age_real_nums['Pop_over_65']=education_age_real_nums['Pop_over_65'].astype(int)
education_age_real_nums['over_65_HS_grad_or_higher']=education_age_real_nums['over_65_HS_grad_or_higher'].astype(int)
education_age_real_nums["over_65_bachelors_or_higher"]=education_age_real_nums["over_65_bachelors_or_higher"].astype(int)

# %%
# education_age_real_nums['HS_grad_or_higher'] = (education_age_real_nums['45_64_HS_grad_or_higher']).astype(int) + (education_age_real_nums['over_65_HS_grad_or_higher']).astype(int)
# #                                               (education_age_real_nums['35_44_HS_grad_or_higher']).astype(int) + (education_age_real_nums['25_34_HS_grad_or_higher']).astype(int)
# # education_age_real_nums['bachelors_or_higher'] = education_age_real_nums["45_64_bachelors_or_higher"] + \
# #                                                  education_age_real_nums["over_65_bachelors_or_higher"] + education_age_real_nums["35_44_bachelors_or_higher"] +\
# #                                                  education_age_real_nums["25_34_bachelors_or_higher"]
education_age_real_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 1 to 21
# Data columns (total 28 columns):
# name                               21 non-null object
# Pop18_24                           21 non-null int64
# 18_24_less_than_HS                 21 non-null int64
# 18_24_HS_grad                      21 non-null int64
# 18_24_associate                    21 non-null int64
# 18_24_bachelor                     21 non-null int64
# Pop_over_25                        21 non-null int64
# over_25_less_9grade                21 non-null int64
# over_25_9_12th grade_no_diploma    21 non-null int64
# over_25_HS_grad                    21 non-null int64
# over_25_some_college_no_degree     21 non-null int64
# over_25_associate                  21 non-null int64
# over_25_bachelors                  21 non-null int64
# over_25_graduate                   21 non-null int64
# over_25_HS_grad_or_higher          21 non-null int64
# over_25_bachelors_or_higher        21 non-null int64
# ...

# %%
# education_age_real_nums['Pop18_24','18_24_less_than_HS','18_24_HS_grad',"18_24_associate","18_24_bachelor",\
#                          'Pop_over_25','over_25_less_9grade','over_25_9_12th grade_no_diploma','over_25_HS_grad',\
#                          'over_25_some_college_no_degree',"over_25_associate", "over_25_bachelors",'over_25_graduate',\
#                          'over_25_HS_grad_or_higher','over_25_bachelors_or_higher','Pop25_34',\
#                          '25_34_HS_grad_or_higher',"25_34_bachelors_or_higher",'Pop35_44','35_44_HS_grad_or_higher',\
#                          "35_44_bachelors_or_higher", 'Pop45_64','45_64_HS_grad_or_higher',"45_64_bachelors_or_higher",\
#                          'Pop_over_65','over_65_HS_grad_or_higher',"over_65_bachelors_or_higher"] = \
# education_age_real_nums['Pop18_24','18_24_less_than_HS','18_24_HS_grad',"18_24_associate","18_24_bachelor",\
#                          'Pop_over_25','over_25_less_9grade','over_25_9_12th grade_no_diploma','over_25_HS_grad',\
#                          'over_25_some_college_no_degree',"over_25_associate", "over_25_bachelors",'over_25_graduate',\
#                          'over_25_HS_grad_or_higher','over_25_bachelors_or_higher','Pop25_34',\
#                          '25_34_HS_grad_or_higher',"25_34_bachelors_or_higher",'Pop35_44','35_44_HS_grad_or_higher',\
#                          "35_44_bachelors_or_higher", 'Pop45_64','45_64_HS_grad_or_higher',"45_64_bachelors_or_higher",\
#                          'Pop_over_65','over_65_HS_grad_or_higher',"over_65_bachelors_or_higher"].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
# education_age_real_nums['HS_grad_or_higher'] = education_age_real_nums['45_64_HS_grad_or_higher'] +\
# education_age_real_nums['over_65_HS_grad_or_higher']+education_age_real_nums['35_44_HS_grad_or_higher'] +\
# education_age_real_nums['25_34_HS_grad_or_higher']

# education_age_real_nums['bachelors_or_higher'] = education_age_real_nums["45_64_bachelors_or_higher"] + \
# education_age_real_nums["over_65_bachelors_or_higher"] + education_age_real_nums["35_44_bachelors_or_higher"] +\
# education_age_real_nums["25_34_bachelors_or_higher"]

# %%
education_age_real_nums['less_than_HS_diploma'] = education_age_real_nums['18_24_less_than_HS']+\
education_age_real_nums['over_25_less_9grade'] +education_age_real_nums['over_25_9_12th grade_no_diploma']+\

# %%
education_age_real_nums.drop(['45_64_HS_grad_or_higher','over_65_HS_grad_or_higher','35_44_HS_grad_or_higher','25_34_HS_grad_or_higher',\
                             "45_64_bachelors_or_higher","over_65_bachelors_or_higher","35_44_bachelors_or_higher",\
                              "25_34_bachelors_or_higher"],axis=1)
# Out:
#                              name  Pop18_24  18_24_less_than_HS  \
# 1     Atlantic County, New Jersey     24683                2688
# 2       Bergen County, New Jersey     74163                6043
# 3   Burlington County, New Jersey     36899                3374
# 4       Camden County, New Jersey     41040                5189
# 5     Cape May County, New Jersey      6132                 498
# 6   Cumberland County, New Jersey     11270                1929
# 7        Essex County, New Jersey     69333                8075
# 8   Gloucester County, New Jersey     25981                 948
# 9       Hudson County, New Jersey     52068                4955
# 10   Hunterdon County, New Jersey      9882                1007
# 11      Mercer County, New Jersey     41153                3526
# 12   Middlesex County, New Jersey     76973                6604
# 13    Monmouth County, New Jersey     49925                3997
# 14      Morris County, New Jersey     41892                3950
# ...

# %%
education_age_real_nums
# Out:
#                              name  Pop18_24  18_24_less_than_HS  \
# 1     Atlantic County, New Jersey     24683                2688
# 2       Bergen County, New Jersey     74163                6043
# 3   Burlington County, New Jersey     36899                3374
# 4       Camden County, New Jersey     41040                5189
# 5     Cape May County, New Jersey      6132                 498
# 6   Cumberland County, New Jersey     11270                1929
# 7        Essex County, New Jersey     69333                8075
# 8   Gloucester County, New Jersey     25981                 948
# 9       Hudson County, New Jersey     52068                4955
# 10   Hunterdon County, New Jersey      9882                1007
# 11      Mercer County, New Jersey     41153                3526
# 12   Middlesex County, New Jersey     76973                6604
# 13    Monmouth County, New Jersey     49925                3997
# 14      Morris County, New Jersey     41892                3950
# ...

# %%
ed_real_nums_total = education[['NAME', 'S1501_C01_001E','S1501_C01_006E','S1501_C01_016E', 'S1501_C01_022E',\
'S1501_C01_025E']]

# %%
ed_real_nums_total.columns = ['name','18_24_years','over_25','25_34_years','45_64_years','over_65']

# %%
ed_real_nums_total=ed_real_nums_total.drop(ed_real_nums_total.index[0])

# %%
ed_real_nums_total
# Out:
#                              name 18_24_years over_25 25_34_years 45_64_years  \
# 1     Atlantic County, New Jersey       24683  183492       30123       72771
# 2       Bergen County, New Jersey       74163  661729      108207      265097
# 3   Burlington County, New Jersey       36899  316291       56063      127552
# 4       Camden County, New Jersey       41040  351426       70845      134264
# 5     Cape May County, New Jersey        6132   69957        9238       27053
# 6   Cumberland County, New Jersey       11270  102701       22023       37399
# 7        Essex County, New Jersey       69333  540264      110494      207875
# 8   Gloucester County, New Jersey       25981  202556       34872       83191
# 9       Hudson County, New Jersey       52068  483796      141570      152380
# 10   Hunterdon County, New Jersey        9882   90777       12105       40195
# 11      Mercer County, New Jersey       41153  248215       45746       98624
# ...

# %%
ed_real_nums_total.to_csv('ed_age_real_nums.csv')
