# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\aidan\\downloads\\yeet'

# %%
cd C:\\Users\\aidan\\downloads\yeet
# Out:
# C:\Users\aidan\downloads\yeet

# %%
income = pd.read_csv('ACSST1Y2019.S1901_data_with_overlays_2020-12-19T210454.csv')

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
income.head()
# Out:
#            GEO_ID                           NAME               S1901_C01_001E  \
# 0              id           Geographic Area Name  Estimate!!Households!!Total
# 1  0500000US34001    Atlantic County, New Jersey                       101975
# 2  0500000US34003      Bergen County, New Jersey                       343733
# 3  0500000US34005  Burlington County, New Jersey                       170074
# 4  0500000US34007      Camden County, New Jersey                       187780
#
#                        S1901_C01_001M  \
# 0  Margin of Error!!Households!!Total
# 1                                2606
# 2                                2437
# 3                                2140
# 4                                2647
#
#                                    S1901_C01_002E  \
# 0  Estimate!!Households!!Total!!Less than $10,000
# 1                                             6.5
# 2                                             3.4
# 3                                             2.5
# ...

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Columns: 130 entries, GEO_ID to S1901_C04_016M
# dtypes: object(130)
# memory usage: 22.5+ KB

# %%
# Filtering dataset to the following columns:


income = income[['S1901_C01_002E',
                 'S1901_C01_003E',
                 'S1901_C01_004E',
                 'S1901_C01_005E',
                 'S1901_C01_006E',
                 'S1901_C01_007E',
                 'S1901_C01_008E',
                 'S1901_C01_009E',
                 'S1901_C01_010E',
                 'S1901_C01_011E']]

# %%
new_header = income.iloc[0] #grab the first row for the header
income = income[1:] #take the data less the header row
income.columns = new_header #set the header row as the df header

income
# Out:
# 0  Estimate!!Households!!Total!!Less than $10,000  \
# 1                                             6.5
# 2                                             3.4
# 3                                             2.5
# 4                                             6.2
# 5                                             4.2
# 6                                             7.5
# 7                                             8.4
# 8                                             3.8
# 9                                             6.2
# 10                                            1.8
# 11                                            8.2
# 12                                            4.2
# 13                                            4.4
# 14                                            2.5
# 15                                            3.1
# 16                                            4.9
# 17                                            2.9
# 18                                            2.6
# ...

# %%
income.columns = ['Percent Less than $10,000',
'Percent $10,000 to $14,999',
'Percent $15,000 to $24,999',
'Percent $25,000 to $34,999',
'Percent $35,000 to $49,999',
'Percent $50,000 to $74,999',
'Percent $75,000 to $99,999',
'Percent $100,000 to $149,999',
'Percent $150,000 to $199,999',
'Percent $200,000 or more']

# %%
income
# Out:
#    Percent Less than $10,000 Percent $10,000 to $14,999  \
# 1                        6.5                        3.7
# 2                        3.4                        1.9
# 3                        2.5                        1.5
# 4                        6.2                        3.4
# 5                        4.2                        3.3
# 6                        7.5                        4.9
# 7                        8.4                        4.3
# 8                        3.8                        2.6
# 9                        6.2                        4.7
# 10                       1.8                        1.4
# 11                       8.2                        3.6
# 12                       4.2                        2.4
# 13                       4.4                        2.4
# 14                       2.5                        1.6
# 15                       3.1                        2.4
# 16                       4.9                        4.1
# ...

# %%
cd C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan
# Out:
# C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Aidan

# %%
income.to_csv('income_clean.csv', index=False)
