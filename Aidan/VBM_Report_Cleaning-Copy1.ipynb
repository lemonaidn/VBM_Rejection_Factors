# %%
pwd
# Out:
# 'C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan'

# %%
cd C:\Users\Aidan\Documents\VBM_OPRA_Data\vbm_data
# Out:
# C:\Users\Aidan\Documents\VBM_OPRA_Data\vbm_data

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
raw_df = pd.read_csv('vbm12.6.20.csv')
# Out:
# C:\Users\Aidan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2,15,30,32,33,41,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
raw_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f57f71900747> in <module>
# ----> 1 raw_df
#
# NameError: name 'raw_df' is not defined

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6047966 entries, 0 to 6047965
# Data columns (total 44 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   current_county             object
#  1   current_municipality       object
#  2   current_ward               object
#  3   current_district           float64
#  4   ballot_requestType         object
#  5   voter_id                   object
#  6   voter_lastName             object
#  7   voter_firstName            object
#  8   voter_middleName           object
#  9   voter_suffix               object
#  10  voter_party                object
#  11  voter_status               object
#  12  ballot_type                object
#  13  ballot_county              object
#  14  ballot_municipality        object
#  15  ballot_ward                object
#  16  ballot_district            int64
#  17  ballot_vtr_party           object
#  18  ballot_addr_address1       object
#  19  ballot_addr_address2       object
#  20  ballot_addr_address3       object
#  21  ballot_addr_city           object
#  22  ballot_addr_state          object
#  23  ballot_addr_zipcode        object
#  24  ballot_addr_country        object
#  25  application_receivedDate   object
#  26  application_processedDate  object
#  27  application_status         object
#  28  ballot_mailedDate          object
#  29  ballot_receivedDate        object
#  30  ballot_countedDate         object
#  31  ballot_status              object
#  32  received_rejReason         object
#  33  voter_resAddr_num          object
#  34  voter_resAddr_street       object
#  35  voter_resAddr_address1     object
#  36  voter_resAddr_address2     object
#  37  voter_resAddr_address3     float64
#  38  voter_resAddr_city         object
#  39  voter_resAddr_state        object
#  40  voter_resAddr_zipcode      object
#  41  voter_phone                object
#  42  voter_email                object
#  43  received_bearer            object
# dtypes: float64(2), int64(1), object(41)
# memory usage: 2.0+ GB

# %%
#number of rejected ballots

raw_df['received_rejReason'].count()
# Out:
# 46998

# %%
#rejected ballots by reason for rejection

raw_df['received_rejReason'].value_counts()
# Out:
# Signature Does Not Match          15047
# Certificate Missing               11096
# Certificate Not Signed             8379
# Other                              6661
# Ballot Received After Deadline     2007
# Ballot Not Enclosed                1593
# Voter Registration ID Missing       953
# Bearer Exceeded Limit               751
# Incomplete Bearer Portion           200
# Moved Out of County                 200
# Incomplete Assistor Portion          54
# Power of Attorney                    36
# Ineligible Voter Status               6
# Both Envelopes Unsealed               5
# Primary-Voted Both Parties            3
# Bearer Book Not Signed In             3
# One Envelope Unsealed                 2
# Candidate Provided Assistance         2
# Name: received_rejReason, dtype: int64

# %%
#NA's in Rejection reason should represent accepted ballots AND people who did not vote

raw_df['received_rejReason'].isna().sum()
# Out:
# 6000968

# %%
print(raw_df['ballot_receivedDate'].unique())
# Out:
# ['10/23/2020' '10/21/2020' '10/18/2020' nan '10/28/2020' '10/19/2020'
#  '10/22/2020' '10/16/2020' '10/24/2020' '10/29/2020' '10/20/2020'
#  '11/03/2020' '10/26/2020' '10/15/2020' '10/17/2020' '10/27/2020'
#  '10/30/2020' '11/04/2020' '11/02/2020' '10/25/2020' '10/31/2020'
#  '11/01/2020' '11/12/2020' '11/10/2020' '10/05/2020' '11/05/2020'
#  '11/06/2020' '10/10/2020' '10/07/2020' '10/09/2020' '10/08/2020'
#  '10/06/2020' '10/14/2020' '10/13/2020' '10/12/2020' '10/03/2020'
#  '09/29/2020' '10/01/2020' '09/30/2020' '10/04/2020' '10/11/2020'
#  '10/02/2020' '11/07/2020' '11/09/2020' '09/22/2020' '11/16/2020'
#  '11/14/2020' '11/17/2020' '11/13/2020' '09/09/2020' '09/28/2020'
#  '09/02/2020' '11/11/2020' '11/23/2020' '11/20/2020' '09/21/2020'
#  '09/24/2020' '09/20/2020' '09/25/2020' '09/05/2020' '08/30/2020'
#  '09/14/2020' '09/18/2020' '09/27/2020' '09/04/2020' '09/17/2020'
#  '09/23/2020' '09/26/2020' '09/16/2020' '11/08/2020' '09/15/2020'
#  '09/12/2020' '09/06/2020' '11/19/2020' '11/18/2020' '12/01/2020'
#  '09/19/2020' '12/04/2020' '09/01/2020' '09/30/2019' '11/30/2020'
#  '11/15/2020' '07/07/2020' '12/03/2020' '11/24/2020' '11/22/2020'
#  '11/25/2020' '09/11/2020' '09/10/2020' '09/08/2020' '10/29/2019'
#  '08/29/2020']

# %%
#Some voters/voter ID's are duplicated in the report:

raw_df['voter_id'].value_counts()
# Out:
# E1576352907    7
# N4349817779    6
# O5235652789    4
# O2854653146    4
# B2974435149    4
#               ..
# M3535753105    1
# F2466352932    1
# J0689153021    1
# F3313351833    1
# P2743952427    1
# Name: voter_id, Length: 6032030, dtype: int64

# %%
#Let's take the most extreme example and see what's going on:

top_dup = raw_df.loc[raw_df['voter_id'] == 'E1576352907']
top_dup
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4978398        Passaic         Clifton City            2               8.0
# 4978399        Passaic         Clifton City            2               8.0
# 4978400        Passaic         Clifton City            2               8.0
# 4978401        Passaic         Clifton City            2               8.0
# 4978402        Passaic         Clifton City            2               8.0
# 4978403        Passaic         Clifton City            2               8.0
# 4978404        Passaic         Clifton City            2               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4978398    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978399    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978400    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978401    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978402    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978403    Single Election  E1576352907     BASHJAWISH            FUAD
# 4978404    Single Election  E1576352907     BASHJAWISH            FUAD
#
#         voter_middleName voter_suffix voter_party voter_status ballot_type  \
# 4978398                A          NaN  Republican       Active     Regular
# 4978399                A          NaN  Republican       Active     Regular
# 4978400                A          NaN  Republican       Active     Regular
# 4978401                A          NaN  Republican       Active     Regular
# 4978402                A          NaN  Republican       Active     Regular
# 4978403                A          NaN  Republican       Active     Regular
# 4978404                A          NaN  Republican       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 4978398       Passaic        Clifton City           2                8
# 4978399       Passaic        Clifton City           2                8
# 4978400       Passaic        Clifton City           2                8
# 4978401       Passaic        Clifton City           2                8
# 4978402       Passaic        Clifton City           2                8
# 4978403       Passaic        Clifton City           2                8
# 4978404       Passaic        Clifton City           2                8
#
#         ballot_vtr_party  ballot_addr_address1 ballot_addr_address2  \
# 4978398       Democratic  117 Mountainside Ter                  NaN
# 4978399       Republican  117 Mountainside Ter                  NaN
# 4978400       Republican  117 Mountainside Ter                  NaN
# 4978401       Republican  117 Mountainside Ter                  NaN
# 4978402       Republican  117 MOUNTAINSIDE TER                  NaN
# 4978403       Republican  117 Mountainside Ter                  NaN
# 4978404       Republican  117 MOUNTAINSIDE TER                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 4978398                  NaN          Clifton                NJ
# 4978399                  NaN          Clifton                NJ
# 4978400                  NaN          Clifton                NJ
# 4978401                  NaN          Clifton                NJ
# 4978402                  NaN          CLIFTON                NJ
# 4978403                  NaN          Clifton                NJ
# 4978404                  NaN          CLIFTON                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 4978398          07013-1178                 NaN               08/14/2020
# 4978399          07013-1178                 NaN               08/14/2020
# 4978400          07013-1178                 NaN               08/14/2020
# 4978401          07013-1178                 NaN               08/14/2020
# 4978402          07013-1178                  US               08/14/2020
# 4978403          07013-1178                 NaN               08/14/2020
# 4978404          07013-1178                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 4978398                08/31/2020           Accepted               NaN
# 4978399                08/31/2020           Accepted               NaN
# 4978400                08/31/2020           Accepted               NaN
# 4978401                08/31/2020           Accepted               NaN
# 4978402                08/31/2020           Accepted               NaN
# 4978403                08/31/2020           Accepted               NaN
# 4978404                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 4978398                 NaN                NaN           NaN
# 4978399                 NaN                NaN           NaN
# 4978400                 NaN                NaN           NaN
# 4978401                 NaN                NaN           NaN
# 4978402                 NaN                NaN           NaN
# 4978403                 NaN                NaN           NaN
# 4978404                 NaN                NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 4978398                NaN               117     MOUNTAINSIDE TER
# 4978399                NaN               117     MOUNTAINSIDE TER
# 4978400                NaN               117     MOUNTAINSIDE TER
# 4978401                NaN               117     MOUNTAINSIDE TER
# 4978402                NaN               117     MOUNTAINSIDE TER
# 4978403                NaN               117     MOUNTAINSIDE TER
# 4978404                NaN               117     MOUNTAINSIDE TER
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 4978398   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978399   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978400   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978401   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978402   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978403   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4978404   117 MOUNTAINSIDE TER                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 4978398            CLIFTON                  NJ            07013-1178
# 4978399            CLIFTON                  NJ            07013-1178
# 4978400            CLIFTON                  NJ            07013-1178
# 4978401            CLIFTON                  NJ            07013-1178
# 4978402            CLIFTON                  NJ            07013-1178
# 4978403            CLIFTON                  NJ            07013-1178
# 4978404            CLIFTON                  NJ            07013-1178
#
#         voter_phone voter_email received_bearer
# 4978398  9732472453         NaN             NaN
# 4978399  9732472453         NaN             NaN
# 4978400  9732472453         NaN             NaN
# 4978401  9732472453         NaN             NaN
# 4978402  9732472453         NaN             NaN
# 4978403  9732472453         NaN             NaN
# 4978404  9732472453         NaN             NaN

# %%
#It looks like they're identical records, some with lowercase cols and some with uppercase cols

#In this instace, it looks like the last row is the one we want to keep bc it contains the ballot mailed date

# %%
#let's see if that holds true for a few more examples

dup_2 = raw_df.loc[raw_df['voter_id'] == 'N4349817779']
dup_2

#Yes, want to keep the last row
# Out:
#         current_county   current_municipality current_ward  current_district  \
# 5014508        Passaic  Little Falls Township            0               8.0
# 5014509        Passaic  Little Falls Township            0               8.0
# 5014510        Passaic  Little Falls Township            0               8.0
# 5014511        Passaic  Little Falls Township            0               8.0
# 5014512        Passaic  Little Falls Township            0               8.0
# 5014513        Passaic  Little Falls Township            0               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 5014508    Single Election  N4349817779          DEFEO            EMMA
# 5014509    Single Election  N4349817779          DEFEO            EMMA
# 5014510    Single Election  N4349817779          DEFEO            EMMA
# 5014511    Single Election  N4349817779          DEFEO            EMMA
# 5014512    Single Election  N4349817779          DEFEO            EMMA
# 5014513    Single Election  N4349817779          DEFEO            EMMA
#
#         voter_middleName voter_suffix   voter_party voter_status ballot_type  \
# 5014508                L          NaN  Unaffiliated       Active     Regular
# 5014509                L          NaN  Unaffiliated       Active     Regular
# 5014510                L          NaN  Unaffiliated       Active     Regular
# 5014511                L          NaN  Unaffiliated       Active     Regular
# 5014512                L          NaN  Unaffiliated       Active     Regular
# 5014513                L          NaN  Unaffiliated       Active     Regular
#
#         ballot_county    ballot_municipality ballot_ward  ballot_district  \
# 5014508       Passaic  Little Falls Township           0                8
# 5014509       Passaic  Little Falls Township           0                8
# 5014510       Passaic  Little Falls Township           0                8
# 5014511       Passaic  Little Falls Township           0                8
# 5014512       Passaic  Little Falls Township           0                8
# 5014513       Passaic  Little Falls Township           0                8
#
#         ballot_vtr_party ballot_addr_address1 ballot_addr_address2  \
# 5014508     Unaffiliated         88 BERGEN DR                  NaN
# 5014509       Republican         88 Bergen Dr                  NaN
# 5014510       Republican         88 Bergen Dr                  NaN
# 5014511     Unaffiliated         88 BERGEN DR                  NaN
# 5014512       Republican         88 Bergen Dr                  NaN
# 5014513     Unaffiliated         88 BERGEN DR                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 5014508                  NaN     LITTLE FALLS                NJ
# 5014509                  NaN     Little Falls                NJ
# 5014510                  NaN     Little Falls                NJ
# 5014511                  NaN     LITTLE FALLS                NJ
# 5014512                  NaN     Little Falls                NJ
# 5014513                  NaN     LITTLE FALLS                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 5014508          07424-1342                  US               08/14/2020
# 5014509          07424-1342                 NaN               08/14/2020
# 5014510          07424-1342                 NaN               08/14/2020
# 5014511          07424-1342                  US               08/14/2020
# 5014512          07424-1342                 NaN               08/14/2020
# 5014513          07424-1342                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 5014508                08/31/2020           Accepted               NaN
# 5014509                08/31/2020           Accepted               NaN
# 5014510                08/31/2020           Accepted               NaN
# 5014511                08/31/2020           Accepted               NaN
# 5014512                08/31/2020           Accepted               NaN
# 5014513                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 5014508                 NaN                NaN           NaN
# 5014509                 NaN                NaN           NaN
# 5014510                 NaN                NaN           NaN
# 5014511                 NaN                NaN           NaN
# 5014512                 NaN                NaN           NaN
# 5014513          11/02/2020         11/24/2020      Accepted
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 5014508                NaN                88            BERGEN DR
# 5014509                NaN                88            BERGEN DR
# 5014510                NaN                88            BERGEN DR
# 5014511                NaN                88            BERGEN DR
# 5014512                NaN                88            BERGEN DR
# 5014513                NaN                88            BERGEN DR
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 5014508           88 BERGEN DR                    NaN                     NaN
# 5014509           88 BERGEN DR                    NaN                     NaN
# 5014510           88 BERGEN DR                    NaN                     NaN
# 5014511           88 BERGEN DR                    NaN                     NaN
# 5014512           88 BERGEN DR                    NaN                     NaN
# 5014513           88 BERGEN DR                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 5014508       LITTLE FALLS                  NJ            07424-1342
# 5014509       LITTLE FALLS                  NJ            07424-1342
# 5014510       LITTLE FALLS                  NJ            07424-1342
# 5014511       LITTLE FALLS                  NJ            07424-1342
# 5014512       LITTLE FALLS                  NJ            07424-1342
# 5014513       LITTLE FALLS                  NJ            07424-1342
#
#         voter_phone voter_email received_bearer
# 5014508         NaN         NaN             NaN
# 5014509         NaN         NaN             NaN
# 5014510         NaN         NaN             NaN
# 5014511         NaN         NaN             NaN
# 5014512         NaN         NaN             NaN
# 5014513         NaN         NaN             NaN

# %%
dup_3 = raw_df.loc[raw_df['voter_id'] == 'C2833253992']
dup_3

#Same again

#IMPORTANT: the ballot types differ -- top = regular, the rest are "Presidential / Removed Resident"
# Out:
#        current_county current_municipality current_ward  current_district  \
# 185339         Bergen    Allendale Borough            0               1.0
# 185340         Bergen    Allendale Borough            0               1.0
# 185341         Bergen    Allendale Borough            0               1.0
# 185342         Bergen    Allendale Borough            0               1.0
#
#               ballot_requestType     voter_id voter_lastName voter_firstName  \
# 185339           Single Election  C2833253992      CALIANESE          JOSEPH
# 185340  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
# 185341  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
# 185342  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
#
#        voter_middleName voter_suffix voter_party voter_status  \
# 185339                T          NaN  Republican       Active
# 185340                T          NaN  Republican       Active
# 185341                T          NaN  Republican       Active
# 185342                T          NaN  Republican       Active
#
#                             ballot_type ballot_county ballot_municipality  \
# 185339                          Regular        Bergen   Allendale Borough
# 185340  Presidential / Removed Resident        Bergen   Allendale Borough
# 185341  Presidential / Removed Resident        Bergen   Allendale Borough
# 185342  Presidential / Removed Resident        Bergen   Allendale Borough
#
#        ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 185339           0                1       Republican         68 Canaan Pl
# 185340           0                1       Republican         68 CANAAN PL
# 185341           0                1       Republican         68 CANAAN PL
# 185342           0                1       Republican         68 CANAAN PL
#
#        ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 185339                  NaN                  NaN        Allendale
# 185340                  NaN                  NaN        ALLENDALE
# 185341                  NaN                  NaN        ALLENDALE
# 185342                  NaN                  NaN        ALLENDALE
#
#        ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 185339                NJ          07401-1820                 NaN
# 185340                NJ          07401-1820                  US
# 185341                NJ          07401-1820                  US
# 185342                NJ          07401-1820                  US
#
#        application_receivedDate application_processedDate application_status  \
# 185339               08/14/2020                08/31/2020           Accepted
# 185340               09/04/2020                09/04/2020           Accepted
# 185341               09/04/2020                09/04/2020           Accepted
# 185342               09/04/2020                09/04/2020           Accepted
#
#        ballot_mailedDate ballot_receivedDate ballot_countedDate ballot_status  \
# 185339               NaN                 NaN                NaN           NaN
# 185340               NaN                 NaN                NaN           NaN
# 185341               NaN                 NaN                NaN           NaN
# 185342        09/21/2020          10/31/2020         12/02/2020      Accepted
#
#        received_rejReason voter_resAddr_num voter_resAddr_street  \
# 185339                NaN                68            Canaan Pl
# 185340                NaN                68            Canaan Pl
# 185341                NaN                68            Canaan Pl
# 185342                NaN                68            Canaan Pl
#
#        voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 185339           68 Canaan Pl                    NaN                     NaN
# 185340           68 Canaan Pl                    NaN                     NaN
# 185341           68 Canaan Pl                    NaN                     NaN
# 185342           68 Canaan Pl                    NaN                     NaN
#
#        voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 185339          Allendale                  NJ            07401-1820
# 185340          Allendale                  NJ            07401-1820
# 185341          Allendale                  NJ            07401-1820
# 185342          Allendale                  NJ            07401-1820
#
#        voter_phone voter_email received_bearer
# 185339         NaN         NaN             NaN
# 185340         NaN         NaN             NaN
# 185341         NaN         NaN             NaN
# 185342         NaN         NaN             NaN

# %%
dup_4 = raw_df.loc[raw_df['voter_id'] == 'P3690153923']
dup_4

# Same as above -- last row has dates, but rows have different ballot types AND addresses
# It looks like this one is because they got an overseas ballot
# Out:
#         current_county current_municipality current_ward  current_district  \
# 1171547         Camden       Berlin Borough            0               3.0
# 1171548         Camden       Berlin Borough            0               3.0
# 1171549         Camden       Berlin Borough            0               3.0
# 1171550         Camden       Berlin Borough            0               3.0
#
#                       ballot_requestType     voter_id voter_lastName  \
# 1171547                  Single Election  P3690153923          SCOTT
# 1171548  UOCAVA Annual Mail-In Elections  P3690153923          SCOTT
# 1171549         Annual Mail-In Elections  P3690153923          SCOTT
# 1171550  UOCAVA Annual Mail-In Elections  P3690153923          SCOTT
#
#         voter_firstName voter_middleName voter_suffix   voter_party  \
# 1171547           SUSAN                L          NaN  Unaffiliated
# 1171548           SUSAN                L          NaN  Unaffiliated
# 1171549           SUSAN                L          NaN  Unaffiliated
# 1171550           SUSAN                L          NaN  Unaffiliated
#
#         voter_status                      ballot_type ballot_county  \
# 1171547       Active                          Regular        Camden
# 1171548       Active                             Full        Camden
# 1171549       Active  Presidential / Removed Resident        Camden
# 1171550       Active                             Full        Camden
#
#         ballot_municipality ballot_ward  ballot_district ballot_vtr_party  \
# 1171547      Berlin Borough           0                3     Unaffiliated
# 1171548      Berlin Borough           0                3     Unaffiliated
# 1171549      Berlin Borough           0                3     Unaffiliated
# 1171550      Berlin Borough           0                3     Unaffiliated
#
#                         ballot_addr_address1 ballot_addr_address2  \
# 1171547                          32 Mason Dr                  NaN
# 1171548  HORIZON TOWER - 214 TRAN QUANG KHAI   APT 23.03 TAN DINH
# 1171549                          32 Mason Dr                  NaN
# 1171550  HORIZON TOWER - 214 TRAN QUANG KHAI   APT 23.03 TAN DINH
#
#         ballot_addr_address3  ballot_addr_city ballot_addr_state  \
# 1171547                  NaN            Berlin                NJ
# 1171548                  NaN  HO CHI MINH CITY               NaN
# 1171549                  NaN            Berlin                NJ
# 1171550                  NaN  HO CHI MINH CITY               NaN
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 1171547          08009-7116                 NaN               08/14/2020
# 1171548          70000-7400                  VN               09/08/2020
# 1171549          08009-7116                 NaN               09/09/2020
# 1171550          70000-7400                  VN               09/19/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 1171547                08/31/2020           Accepted               NaN
# 1171548                09/08/2020           Accepted               NaN
# 1171549                09/09/2020           Accepted               NaN
# 1171550                09/19/2020           Accepted        09/19/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 1171547                 NaN                NaN           NaN
# 1171548                 NaN                NaN           NaN
# 1171549                 NaN                NaN           NaN
# 1171550          11/01/2020         11/19/2020      Accepted
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 1171547                NaN                32             Mason Dr
# 1171548                NaN                32             Mason Dr
# 1171549                NaN                32             Mason Dr
# 1171550                NaN                32             Mason Dr
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 1171547            32 Mason Dr                    NaN                     NaN
# 1171548            32 Mason Dr                    NaN                     NaN
# 1171549            32 Mason Dr                    NaN                     NaN
# 1171550            32 Mason Dr                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 1171547             Berlin                  NJ            08009-7116
# 1171548             Berlin                  NJ            08009-7116
# 1171549             Berlin                  NJ            08009-7116
# 1171550             Berlin                  NJ            08009-7116
#
#         voter_phone                 voter_email received_bearer
# 1171547         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171548         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171549         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171550         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN

# %%
dup_5 = raw_df.loc[raw_df['voter_id'] == 'P3101208027']
dup_5

#Same as before -- some inconsistencies across duplicates but keep the bottom row
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4694862          Ocean    Lakehurst Borough            0               1.0
# 4694863          Ocean    Lakehurst Borough            0               1.0
# 4694864          Ocean    Lakehurst Borough            0               1.0
# 4694865          Ocean    Lakehurst Borough            0               1.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4694862           Single Election  P3101208027          NAGLE          SPRING
# 4694863  Annual Mail-In Elections  P3101208027          NAGLE          SPRING
# 4694864           Single Election  P3101208027          NAGLE          SPRING
# 4694865  Annual Mail-In Elections  P3101208027          NAGLE          SPRING
#
#         voter_middleName voter_suffix voter_party voter_status  \
# 4694862                A          NaN  Republican       Active
# 4694863                A          NaN  Republican       Active
# 4694864                A          NaN  Republican       Active
# 4694865                A          NaN  Republican       Active
#
#                              ballot_type ballot_county ballot_municipality  \
# 4694862                          Regular         Ocean   Lakehurst Borough
# 4694863  Presidential / Removed Resident         Ocean   Lakehurst Borough
# 4694864                          Regular         Ocean   Lakehurst Borough
# 4694865  Presidential / Removed Resident         Ocean   Lakehurst Borough
#
#         ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 4694862           0                1       Republican        121 BROWN AVE
# 4694863           0                1       Republican        121 BROWN AVE
# 4694864           0                1       Republican        P.O. BOX 1104
# 4694865           0                1       Republican        P.O. BOX 1104
#
#         ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 4694862                  NaN                  NaN        LAKEHURST
# 4694863                  NaN                  NaN        LAKEHURST
# 4694864                  NaN                  NaN            BRICK
# 4694865                  NaN                  NaN            BRICK
#
#         ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 4694862                NJ          08733-3032                  US
# 4694863                NJ          08733-3032                  US
# 4694864                NJ               08723                  US
# 4694865                NJ               08723                  US
#
#         application_receivedDate application_processedDate application_status  \
# 4694862               08/14/2020                08/31/2020           Accepted
# 4694863               09/02/2020                09/02/2020           Accepted
# 4694864               09/04/2020                09/04/2020           Accepted
# 4694865               09/11/2020                09/11/2020           Accepted
#
#         ballot_mailedDate ballot_receivedDate ballot_countedDate  \
# 4694862               NaN                 NaN                NaN
# 4694863               NaN                 NaN                NaN
# 4694864               NaN                 NaN                NaN
# 4694865        09/19/2020          10/05/2020                NaN
#
#         ballot_status received_rejReason voter_resAddr_num  \
# 4694862           NaN                NaN               121
# 4694863           NaN                NaN               121
# 4694864           NaN                NaN               121
# 4694865      Received                NaN               121
#
#         voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 4694862            BROWN AVE          121 BROWN AVE                    NaN
# 4694863            BROWN AVE          121 BROWN AVE                    NaN
# 4694864            BROWN AVE          121 BROWN AVE                    NaN
# 4694865            BROWN AVE          121 BROWN AVE                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 4694862                     NaN          LAKEHURST                  NJ
# 4694863                     NaN          LAKEHURST                  NJ
# 4694864                     NaN          LAKEHURST                  NJ
# 4694865                     NaN          LAKEHURST                  NJ
#
#         voter_resAddr_zipcode voter_phone voter_email received_bearer
# 4694862            08733-3032         NaN         NaN             NaN
# 4694863            08733-3032         NaN         NaN             NaN
# 4694864            08733-3032         NaN         NaN             NaN
# 4694865            08733-3032         NaN         NaN             NaN

# %%
#testing drop_duplicates to make sure it keps the right row

top_dup_no_dups = top_dup.drop_duplicates(subset=['voter_id'], keep='last')
top_dup_no_dups
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4978404        Passaic         Clifton City            2               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4978404    Single Election  E1576352907     BASHJAWISH            FUAD
#
#         voter_middleName voter_suffix voter_party voter_status ballot_type  \
# 4978404                A          NaN  Republican       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 4978404       Passaic        Clifton City           2                8
#
#         ballot_vtr_party  ballot_addr_address1 ballot_addr_address2  \
# 4978404       Republican  117 MOUNTAINSIDE TER                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 4978404                  NaN          CLIFTON                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 4978404          07013-1178                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 4978404                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 4978404                 NaN                NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 4978404                NaN               117     MOUNTAINSIDE TER
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 4978404   117 MOUNTAINSIDE TER                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 4978404            CLIFTON                  NJ            07013-1178
#
#         voter_phone voter_email received_bearer
# 4978404  9732472453         NaN             NaN

# %%
#That worked. Let's apply this to the full dataset now 


df = raw_df.drop_duplicates(subset=['voter_id'], keep='last')

# %%
df
# Out:
#         current_county current_municipality current_ward  current_district  \
# 0             Atlantic         Absecon City            1               1.0
# 1             Atlantic         Absecon City            1               1.0
# 2             Atlantic         Absecon City            1               1.0
# 3             Atlantic         Absecon City            1               1.0
# 4             Atlantic         Absecon City            1               1.0
# ...                ...                  ...          ...               ...
# 6047961         Warren       White Township            0               6.0
# 6047962         Warren       White Township            0               6.0
# 6047963         Warren       White Township            0               6.0
# 6047964         Warren       White Township            0               6.0
# 6047965         Warren       White Township            0               6.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 0                 Single Election  P2763351335     LINGELBACH         CAROLYN
# 1        Annual Mail-In Elections  P3919851339          TIMMS           BRIAN
# 2                 Single Election  P6095651352      CUSHLANIS           ROBIN
# 3                 Single Election  A1425851358       DILLHOFF           KEVIN
# 4                 Single Election  A1783751359          JETER            PAUL
# ...                           ...          ...            ...             ...
# 6047961           Single Election  L1061243339         COWLEY           JARED
# 6047962           Single Election  C2754450078     WELENOFSKY            LISA
# 6047963           Single Election  H4507252594       MCGINLEY          MEGHAN
# 6047964           Single Election  N4444001342         CARMEN             KOI
# 6047965           Single Election  P2819114049         ALESSI       KATHERINE
#
#         voter_middleName voter_suffix   voter_party voter_status  \
# 0                      R          NaN  Unaffiliated       Active
# 1                      D          NaN    Democratic       Active
# 2                      A          NaN    Republican       Active
# 3                      T          NaN    Democratic       Active
# 4                      D          NaN    Democratic       Active
# ...                  ...          ...           ...          ...
# 6047961            DUANE          Jr.    Democratic       Active
# 6047962             JEAN          NaN  Unaffiliated       Active
# 6047963              NaN          NaN  Unaffiliated       Active
# 6047964              LEA          NaN  Unaffiliated       Active
# 6047965             ROSE          NaN  Unaffiliated       Active
#
#                              ballot_type ballot_county ballot_municipality  \
# 0                                Regular      Atlantic        Absecon City
# 1        Presidential / Removed Resident      Atlantic        Absecon City
# 2                                Regular      Atlantic        Absecon City
# 3                                Regular      Atlantic        Absecon City
# 4                                Regular      Atlantic        Absecon City
# ...                                  ...           ...                 ...
# 6047961                          Regular        Warren      White Township
# 6047962                          Regular        Warren      White Township
# 6047963                          Regular        Warren      White Township
# 6047964                          Regular        Warren      White Township
# 6047965                          Regular        Warren      White Township
#
#         ballot_ward  ballot_district ballot_vtr_party  \
# 0                 1                1     Unaffiliated
# 1                 1                1       Democratic
# 2                 1                1       Republican
# 3                 1                1       Democratic
# 4                 1                1       Democratic
# ...             ...              ...              ...
# 6047961           0                6       Democratic
# 6047962           0                6     Unaffiliated
# 6047963           0                6     Unaffiliated
# 6047964           0                6     Unaffiliated
# 6047965           0                6     Unaffiliated
#
#             ballot_addr_address1 ballot_addr_address2 ballot_addr_address3  \
# 0        122 E Faunce Landing Rd                  NaN                  NaN
# 1                    506 Lazy Ln                  NaN                  NaN
# 2                 645 Weilers Ln                  NaN                  NaN
# 3                     635 4th St                  NaN                  NaN
# 4                    511 LAZY LN                  NaN                  NaN
# ...                          ...                  ...                  ...
# 6047961           96 BUCKHORN DR                  NaN                  NaN
# 6047962              25 COLBY CT                  NaN                  NaN
# 6047963              23 COLBY CT                  NaN                  NaN
# 6047964      835 BRASS CASTLE RD                  NaN                  NaN
# 6047965              15 COLBY CT                  NaN                  NaN
#
#         ballot_addr_city ballot_addr_state ballot_addr_zipcode  \
# 0                Absecon                NJ          08201-1808
# 1                Absecon                NJ          08201-1337
# 2                Absecon                NJ          08201-1326
# 3                Absecon                NJ          08201-1304
# 4                ABSECON                NJ          08201-1338
# ...                  ...               ...                 ...
# 6047961       WASHINGTON                NJ          07882-3805
# 6047962        BELVIDERE                NJ          07823-2755
# 6047963        BELVIDERE                NJ          07823-2755
# 6047964        BELVIDERE                NJ          07823-2724
# 6047965        BELVIDERE                NJ          07823-2754
#
#         ballot_addr_country application_receivedDate  \
# 0                       NaN               08/14/2020
# 1                        US               08/26/2020
# 2                       NaN               08/14/2020
# 3                       NaN               08/14/2020
# 4                        US               08/14/2020
# ...                     ...                      ...
# 6047961                  US               08/14/2020
# 6047962                  US               08/14/2020
# 6047963                  US               08/14/2020
# 6047964                  US               08/14/2020
# 6047965                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 0                      08/31/2020           Accepted        09/21/2020
# 1                      08/26/2020           Accepted        09/21/2020
# 2                      08/31/2020           Accepted        09/21/2020
# 3                      08/31/2020           Accepted        09/21/2020
# 4                      08/31/2020           Accepted        09/21/2020
# ...                           ...                ...               ...
# 6047961                10/19/2020           Accepted        10/21/2020
# 6047962                10/19/2020           Accepted        10/21/2020
# 6047963                10/19/2020           Accepted        10/21/2020
# 6047964                10/19/2020           Accepted        10/21/2020
# 6047965                10/19/2020           Accepted        10/21/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 0                10/23/2020         11/20/2020      Accepted
# 1                10/21/2020         11/20/2020      Accepted
# 2                10/18/2020         11/20/2020      Accepted
# 3                       NaN         11/20/2020      Accepted
# 4                       NaN         11/20/2020      Accepted
# ...                     ...                ...           ...
# 6047961          11/03/2020         11/23/2020      Accepted
# 6047962          10/28/2020         11/23/2020      Accepted
# 6047963          10/27/2020         11/23/2020      Accepted
# 6047964          11/04/2020         11/23/2020      Accepted
# 6047965                 NaN                NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 0                      NaN               122  E Faunce Landing Rd
# 1                      NaN               506              Lazy Ln
# 2                      NaN               645           Weilers Ln
# 3                      NaN               635               4th St
# 4                      NaN               511              LAZY LN
# ...                    ...               ...                  ...
# 6047961                NaN                96          BUCKHORN DR
# 6047962                NaN                25             COLBY CT
# 6047963                NaN                23             COLBY CT
# 6047964                NaN               835      BRASS CASTLE RD
# 6047965                NaN                15             COLBY CT
#
#           voter_resAddr_address1 voter_resAddr_address2  \
# 0        122 E Faunce Landing Rd                    NaN
# 1                    506 Lazy Ln                    NaN
# 2                 645 Weilers Ln                    NaN
# 3                     635 4th St                    NaN
# 4                    511 LAZY LN                    NaN
# ...                          ...                    ...
# 6047961           96 BUCKHORN DR                    NaN
# 6047962              25 COLBY CT                    NaN
# 6047963              23 COLBY CT                    NaN
# 6047964      835 BRASS CASTLE RD                    NaN
# 6047965              15 COLBY CT                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 0                           NaN            Absecon                  NJ
# 1                           NaN            Absecon                  NJ
# 2                           NaN            Absecon                  NJ
# 3                           NaN            Absecon                  NJ
# 4                           NaN            ABSECON                  NJ
# ...                         ...                ...                 ...
# 6047961                     NaN         WASHINGTON                  NJ
# 6047962                     NaN          BELVIDERE                  NJ
# 6047963                     NaN          BELVIDERE                  NJ
# 6047964                     NaN          BELVIDERE                  NJ
# 6047965                     NaN          BELVIDERE                  NJ
#
#         voter_resAddr_zipcode voter_phone              voter_email  \
# 0                  08201-1808         NaN                      NaN
# 1                  08201-1337  8609447558   BIBLIOMANE74@GMAIL.COM
# 2                  08201-1326  6093284677                      NaN
# 3                  08201-1304         NaN  KEVINDILLHOFF@GMAIL.COM
# 4                  08201-1338         NaN                      NaN
# ...                       ...         ...                      ...
# 6047961            07882-3805         NaN                      NaN
# 6047962            07823-2755         NaN                      NaN
# 6047963            07823-2755         NaN                      NaN
# 6047964            07823-2724         NaN                      NaN
# 6047965            07823-2754         NaN                      NaN
#
#         received_bearer
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 6047961             NaN
# 6047962             NaN
# 6047963             NaN
# 6047964             NaN
# 6047965             NaN
#
# [6032030 rows x 44 columns]

# %%
#Amount of duplicate records removed:

6047966 - 6032030
# Out:
# 15936

# %%
# Now let's look at the (hopefully more accurate) numbers we calculated earlier:

df['received_rejReason'].count()
# Out:
# 46988

# %%
# Number of rejected ballots only changed by ten. 
# This tracks with what we saw above:
#    most duplicate rows appeared not to be associated with a sent/returned ballot

# %%
#rejected ballots by reason for rejection

df['received_rejReason'].value_counts()
# Out:
# Signature Does Not Match          15046
# Certificate Missing               11096
# Certificate Not Signed             8375
# Other                              6659
# Ballot Received After Deadline     2005
# Ballot Not Enclosed                1592
# Voter Registration ID Missing       953
# Bearer Exceeded Limit               751
# Incomplete Bearer Portion           200
# Moved Out of County                 200
# Incomplete Assistor Portion          54
# Power of Attorney                    36
# Ineligible Voter Status               6
# Both Envelopes Unsealed               5
# Primary-Voted Both Parties            3
# Bearer Book Not Signed In             3
# One Envelope Unsealed                 2
# Candidate Provided Assistance         2
# Name: received_rejReason, dtype: int64

# %%
# NA's in Rejection reason *should* represent accepted ballots AND people who did not vote

df['received_rejReason'].isna().sum()
# Out:
# 5985042

# %%
df['ballot_status'].value_counts()
# Out:
# Accepted    3433879
# Received     889766
# Rejected      46833
# Name: ballot_status, dtype: int64

# %%
# Something isn't right here. Why are we getting more results for *reasons* the ballot was rejected...
# than the number of ballots actually *listed* as rejected??

# Maybe some ballots have two rejection reasons? But if that were the case, shouldn't we still have only wound up
# with of them when we eliminated duplicate rows?

# Maybe some ballots that were initially rejected were later "cured" by the voter...
# and therefore status = accepted, even though rejection reason is still there?
# No way to test this specific hypothesis since there's no direct info on cured ballots in dataset.

# Less specific version: some ballots likely have a rejection reason...
# but are still listed as "received" or even "accepted."

# %%
# Let's test out that last idea.

# First, filter the df to only include ballots with a rejection reason.

test_df = df.dropna(subset=['received_rejReason'])
test_df
# Out:
#         current_county current_municipality current_ward  current_district  \
# 105           Atlantic         Absecon City            1               1.0
# 345           Atlantic         Absecon City            1               1.0
# 379           Atlantic         Absecon City            1               1.0
# 477           Atlantic    Galloway Township            0               8.0
# 568           Atlantic         Absecon City            1               1.0
# ...                ...                  ...          ...               ...
# 6047561         Warren       White Township            0               6.0
# 6047675         Warren       White Township            0               6.0
# 6047690         Warren       White Township            0               6.0
# 6047882         Warren       White Township            0               6.0
# 6047891         Warren       White Township            0               6.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 105        Single Election  D2726451787          FROMM           DIANA
# 345        Single Election  E2481651808         MORGAN           JAMES
# 379        Single Election  E3249551811    MAISANO-MAY           JAMIE
# 477        Single Election  F0365451823       GUENTHER         CHARLES
# 568        Single Election  B0672452839      MACKENZIE         STEPHEN
# ...                    ...          ...            ...             ...
# 6047561    Single Election  A6060952460          LUCAS        LEOKADIA
# 6047675    Single Election  B1654652468           SHAH        RAJSHREE
# 6047690    Single Election  B1874552469        MARIANI           DAVID
# 6047882    Single Election  L1350653819       BAROFSKI         MADISON
# 6047891    Single Election  N3190953869        OKEEFFE            PAUL
#
#         voter_middleName voter_suffix   voter_party voter_status ballot_type  \
# 105                    D          NaN    Republican       Active     Regular
# 345                    A          NaN    Republican       Active     Regular
# 379                    L          NaN   Libertarian       Active     Regular
# 477               JOSEPH          Jr.  Unaffiliated       Active     Regular
# 568                    E          NaN  Unaffiliated       Active     Regular
# ...                  ...          ...           ...          ...         ...
# 6047561              NaN          NaN    Republican       Active     Regular
# 6047675                S          NaN    Democratic       Active     Regular
# 6047690                M          NaN    Republican       Active     Regular
# 6047882                J          NaN    Republican       Active     Regular
# 6047891                D          NaN    Democratic       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 105          Atlantic        Absecon City           1                1
# 345          Atlantic        Absecon City           1                1
# 379          Atlantic        Absecon City           1                1
# 477          Atlantic        Absecon City           1                1
# 568          Atlantic        Absecon City           1                1
# ...               ...                 ...         ...              ...
# 6047561        Warren      White Township           0                6
# 6047675        Warren      White Township           0                6
# 6047690        Warren      White Township           0                6
# 6047882        Warren      White Township           0                6
# 6047891        Warren      White Township           0                6
#
#         ballot_vtr_party ballot_addr_address1 ballot_addr_address2  \
# 105           Democratic       533 N Shore Rd                  NaN
# 345           Republican          45 Shady Ln                  NaN
# 379          Libertarian        312 Spruce St                  NaN
# 477           Republican       640 Weilers Ln                  NaN
# 568         Unaffiliated    243 E Wyoming Ave                  NaN
# ...                  ...                  ...                  ...
# 6047561       Republican    86 Summerfield Rd                  NaN
# 6047675       Democratic          44 Colby Ct                  NaN
# 6047690     Unaffiliated       60 Castners Rd                  NaN
# 6047882       Republican         63 Spring Ln                  NaN
# 6047891       Democratic          12 Colby Ct                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 105                      NaN          Absecon                NJ
# 345                      NaN          Absecon                NJ
# 379                      NaN          Absecon                NJ
# 477                      NaN          Absecon                NJ
# 568                      NaN          Absecon                NJ
# ...                      ...              ...               ...
# 6047561                  NaN        Belvidere                NJ
# 6047675                  NaN        Belvidere                NJ
# 6047690                  NaN        Belvidere                NJ
# 6047882                  NaN       Washington                NJ
# 6047891                  NaN        Belvidere                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 105              08201-1821                 NaN               08/14/2020
# 345              08201-1723                 NaN               08/14/2020
# 379              08201-1726                 NaN               08/14/2020
# 477              08201-1327                 NaN               08/14/2020
# 568              08201-1709                 NaN               08/14/2020
# ...                     ...                 ...                      ...
# 6047561          07823-2713                 NaN               08/14/2020
# 6047675          07823-2756                 NaN               08/14/2020
# 6047690          07823-2802                 NaN               08/14/2020
# 6047882          07882-3800                 NaN               08/14/2020
# 6047891          07823-2754                 NaN               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 105                    08/31/2020           Accepted        09/21/2020
# 345                    08/31/2020           Accepted        09/21/2020
# 379                    08/31/2020           Accepted        09/21/2020
# 477                    08/31/2020           Accepted        09/21/2020
# 568                    08/31/2020           Accepted        09/21/2020
# ...                           ...                ...               ...
# 6047561                08/31/2020           Accepted        09/28/2020
# 6047675                08/31/2020           Accepted        09/28/2020
# 6047690                08/31/2020           Accepted        09/28/2020
# 6047882                08/31/2020           Accepted        09/28/2020
# 6047891                08/31/2020           Accepted        09/28/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status  \
# 105                     NaN         2020-11-19      Rejected
# 345              11/12/2020         2020-11-12      Rejected
# 379              11/12/2020         2020-11-12      Rejected
# 477              10/27/2020         2020-11-19      Rejected
# 568              10/28/2020         2020-11-19      Rejected
# ...                     ...                ...           ...
# 6047561          10/17/2020         2020-11-19      Rejected
# 6047675          10/07/2020         2020-11-19      Rejected
# 6047690          11/05/2020         2020-11-19      Rejected
# 6047882          10/12/2020         2020-11-23      Rejected
# 6047891          10/20/2020         2020-11-23      Rejected
#
#                      received_rejReason voter_resAddr_num  \
# 105            Signature Does Not Match               533
# 345      Ballot Received After Deadline                45
# 379      Ballot Received After Deadline               312
# 477            Signature Does Not Match               718
# 568            Signature Does Not Match               243
# ...                                 ...               ...
# 6047561          Certificate Not Signed                86
# 6047675             Certificate Missing                44
# 6047690             Certificate Missing                60
# 6047882        Signature Does Not Match                63
# 6047891        Signature Does Not Match                12
#
#         voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 105               N Shore Rd         533 N Shore Rd                    NaN
# 345                 Shady Ln            45 Shady Ln                    NaN
# 379                Spruce St          312 Spruce St                    NaN
# 477             RAVENWOOD DR       718 RAVENWOOD DR                    NaN
# 568            E Wyoming Ave      243 E Wyoming Ave                    NaN
# ...                      ...                    ...                    ...
# 6047561       Summerfield Rd      86 Summerfield Rd                    NaN
# 6047675             Colby Ct            44 Colby Ct                    NaN
# 6047690          Castners Rd         60 Castners Rd                    NaN
# 6047882            Spring Ln           63 Spring Ln                    NaN
# 6047891             Colby Ct            12 Colby Ct                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 105                         NaN            Absecon                  NJ
# 345                         NaN            Absecon                  NJ
# 379                         NaN            Absecon                  NJ
# 477                         NaN           GALLOWAY                  NJ
# 568                         NaN            Absecon                  NJ
# ...                         ...                ...                 ...
# 6047561                     NaN          Belvidere                  NJ
# 6047675                     NaN          Belvidere                  NJ
# 6047690                     NaN          Belvidere                  NJ
# 6047882                     NaN         Washington                  NJ
# 6047891                     NaN          Belvidere                  NJ
#
#         voter_resAddr_zipcode voter_phone voter_email received_bearer
# 105                08201-1821         NaN         NaN             NaN
# 345                08201-1723         NaN         NaN             NaN
# 379                08201-1726         NaN         NaN             NaN
# 477                08205-3116  6096468812         NaN             NaN
# 568                08201-1709  6096464232         NaN             NaN
# ...                       ...         ...         ...             ...
# 6047561            07823-2713         NaN         NaN             NaN
# 6047675            07823-2756         NaN         NaN             NaN
# 6047690            07823-2802         908         NaN             NaN
# 6047882            07882-3800         NaN         NaN             NaN
# 6047891            07823-2754         NaN         NaN             NaN
#
# [46988 rows x 44 columns]

# %%
# Next, does status = "accepted"?
# is_accepted is a boolean variable with True or False in it
is_accepted =  test_df['ballot_status']=='Accepted'
print(is_accepted.head())
# Out:
# 105    False
# 345    False
# 379    False
# 477    False
# 568    False
# Name: ballot_status, dtype: bool

# %%
# now, filter the df to include only ballots with a rejection reason but still listed as accepted

rejected_accepted = test_df[is_accepted]
print(rejected_accepted.shape)
# Out:
# (153, 44)

# %%
# looks like there are 153 instances where there's a rejection reason but still accepted
rejected_accepted
# Out:
#         current_county  current_municipality current_ward  current_district  \
# 1149476         Camden       Audubon Borough            0               3.0
# 1158085         Camden    Barrington Borough            0               3.0
# 1158789         Camden    Barrington Borough            0               4.0
# 1184602         Camden           Camden City            1               6.0
# 1235976         Camden  Cherry Hill Township            0              15.0
# ...                ...                   ...          ...               ...
# 5593233         Sussex       Sparta Township            0               8.0
# 5673668          Union        Elizabeth City            1               2.0
# 5673805          Union        Elizabeth City            1               2.0
# 5859322          Union  Roselle Park Borough            4               2.0
# 5936618          Union        Union Township            0              37.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 1149476  Annual Mail-In Elections  A4936552084      MARTORANO         THERESA
# 1158085           Single Election  B6363753982        GABRIEL          LAUREN
# 1158789           Single Election  B1113352093         HOWARD         RICHARD
# 1184602           Single Election  J1612453773        MORALES          CARLOS
# 1235976           Single Election  F5090236288         MIZELL          GEORGE
# ...                           ...          ...            ...             ...
# 5593233           Single Election  D6205054025       MCNAMARA            GLEN
# 5673668           Single Election  I0711753748          ROJAS           JESUS
# 5673805  Annual Mail-In Elections  A1905253939          ROJAS           JESUS
# 5859322  Annual Mail-In Elections  B1847352843           VYAS       VRUTTESHA
# 5936618           Single Election  K6445653424           LAGE          LEONEL
#
#         voter_middleName voter_suffix   voter_party voter_status  \
# 1149476                S          NaN    Democratic       Active
# 1158085                A          NaN    Democratic       Active
# 1158789              NaN          NaN    Democratic       Active
# 1184602                J          NaN    Democratic       Active
# 1235976            DAVID          NaN  Unaffiliated       Active
# ...                  ...          ...           ...          ...
# 5593233                P          NaN  Unaffiliated       Active
# 5673668                A          NaN  Unaffiliated       Active
# 5673805                A          NaN  Unaffiliated       Active
# 5859322                M          NaN    Democratic       Active
# 5936618                A          NaN  Unaffiliated       Active
#
#                              ballot_type ballot_county   ballot_municipality  \
# 1149476  Presidential / Removed Resident        Camden       Audubon Borough
# 1158085                          Regular        Camden    Barrington Borough
# 1158789                          Regular        Camden    Barrington Borough
# 1184602                          Regular        Camden           Camden City
# 1235976                          Regular        Camden  Cherry Hill Township
# ...                                  ...           ...                   ...
# 5593233                          Regular        Sussex       Sparta Township
# 5673668                          Regular         Union        Elizabeth City
# 5673805  Presidential / Removed Resident         Union        Elizabeth City
# 5859322  Presidential / Removed Resident         Union  Roselle Park Borough
# 5936618                          Regular         Union        Union Township
#
#         ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 1149476           0                3       Democratic    540 W MERCHANT ST
# 1158085           0                3       Democratic          18 Page Ave
# 1158789           0                4       Democratic       4404 Reamer Dr
# 1184602           1                6       Democratic    1132 W AMERICA RD
# 1235976           0               15     Unaffiliated       1 SILVERTOP LN
# ...             ...              ...              ...                  ...
# 5593233           0                8     Unaffiliated       30 S Shore Trl
# 5673668           1                2     Unaffiliated         112 Broadway
# 5673805           1                2     Unaffiliated         112 BROADWAY
# 5859322           4                2       Democratic        131 JEROME ST
# 5936618           0               37     Unaffiliated     2065 Emerson Ave
#
#         ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 1149476                  NaN                  NaN          AUDUBON
# 1158085                  NaN                  NaN       Barrington
# 1158789                  NaN                  NaN       Barrington
# 1184602                  NaN                  NaN           CAMDEN
# 1235976                  NaN                  NaN      CHERRY HILL
# ...                      ...                  ...              ...
# 5593233                  NaN                  NaN           Sparta
# 5673668                  NaN                  NaN        Elizabeth
# 5673805                  NaN                  NaN        ELIZABETH
# 5859322                APT K                  NaN     ROSELLE PARK
# 5936618                  # 1                  NaN            Union
#
#         ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 1149476                NJ          08106-1910                  US
# 1158085                NJ          08007-1122                 NaN
# 1158789                NJ          08007-1724                 NaN
# 1184602                NJ          08104-2807                  US
# 1235976                NJ          08002-1538                  US
# ...                   ...                 ...                 ...
# 5593233                NJ          07871-1611                 NaN
# 5673668                NJ          07206-1856                 NaN
# 5673805                NJ               07206       UNITED STATES
# 5859322                NJ               07204       UNITED STATES
# 5936618                NJ          07083-3627       UNITED STATES
#
#         application_receivedDate application_processedDate application_status  \
# 1149476               12/22/2019                12/22/2019           Accepted
# 1158085               08/14/2020                08/31/2020           Accepted
# 1158789               08/14/2020                08/31/2020           Accepted
# 1184602               08/14/2020                08/31/2020           Accepted
# 1235976               10/15/2020                10/15/2020           Accepted
# ...                          ...                       ...                ...
# 5593233               08/14/2020                08/31/2020           Accepted
# 5673668               08/14/2020                08/31/2020           Accepted
# 5673805               12/22/2019                12/22/2019           Accepted
# 5859322               12/22/2019                12/22/2019           Accepted
# 5936618               08/14/2020                08/31/2020           Accepted
#
#         ballot_mailedDate ballot_receivedDate ballot_countedDate  \
# 1149476        09/29/2020          10/20/2020         11/20/2020
# 1158085        09/29/2020          10/15/2020         11/20/2020
# 1158789        09/29/2020          10/14/2020         11/20/2020
# 1184602        09/28/2020          10/16/2020         11/20/2020
# 1235976        10/16/2020          10/21/2020         11/20/2020
# ...                   ...                 ...                ...
# 5593233        09/15/2020          11/05/2020         11/23/2020
# 5673668        09/17/2020          10/29/2020         11/20/2020
# 5673805        09/17/2020          10/29/2020         11/20/2020
# 5859322        09/24/2020          10/23/2020         11/03/2020
# 5936618        10/01/2020          10/09/2020         11/20/2020
#
#         ballot_status        received_rejReason voter_resAddr_num  \
# 1149476      Accepted    Certificate Not Signed               540
# 1158085      Accepted  Signature Does Not Match                18
# 1158789      Accepted    Certificate Not Signed              4404
# 1184602      Accepted    Certificate Not Signed              1132
# 1235976      Accepted  Signature Does Not Match                 1
# ...               ...                       ...               ...
# 5593233      Accepted  Signature Does Not Match                30
# 5673668      Accepted  Signature Does Not Match               112
# 5673805      Accepted  Signature Does Not Match               112
# 5859322      Accepted     Bearer Exceeded Limit               131
# 5936618      Accepted       Certificate Missing              2065
#
#         voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 1149476        W MERCHANT ST      540 W MERCHANT ST                    NaN
# 1158085             Page Ave            18 Page Ave                    NaN
# 1158789            Reamer Dr         4404 Reamer Dr                    NaN
# 1184602         W AMERICA RD      1132 W AMERICA RD                    NaN
# 1235976         SILVERTOP LN         1 SILVERTOP LN                    NaN
# ...                      ...                    ...                    ...
# 5593233          S Shore Trl         30 S Shore Trl                    NaN
# 5673668             Broadway           112 Broadway                    NaN
# 5673805             Broadway           112 Broadway                    NaN
# 5859322            JEROME ST          131 JEROME ST                  APT K
# 5936618          Emerson Ave       2065 Emerson Ave                    # 1
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 1149476                     NaN            AUDUBON                  NJ
# 1158085                     NaN         Barrington                  NJ
# 1158789                     NaN         Barrington                  NJ
# 1184602                     NaN             CAMDEN                  NJ
# 1235976                     NaN        CHERRY HILL                  NJ
# ...                         ...                ...                 ...
# 5593233                     NaN             Sparta                  NJ
# 5673668                     NaN          Elizabeth                  NJ
# 5673805                     NaN          Elizabeth                  NJ
# 5859322                     NaN       ROSELLE PARK                  NJ
# 5936618                     NaN              Union                  NJ
#
#         voter_resAddr_zipcode voter_phone                  voter_email  \
# 1149476            08106-1910         NaN                          NaN
# 1158085            08007-1122         NaN                          NaN
# 1158789            08007-1724         NaN                          NaN
# 1184602            08104-2807         NaN                          NaN
# 1235976            08002-1538         NaN                          NaN
# ...                       ...         ...                          ...
# 5593233            07871-1611         NaN                          NaN
# 5673668            07206-1856         NaN                          NaN
# 5673805            07206-1856  9089065852  JESUS.A.ROJAS1962@GMAIL.COM
# 5859322            07204-1453  9082450794                          NaN
# 5936618            07083-3627         NaN                          NaN
#
#         received_bearer
# 1149476             NaN
# 1158085             NaN
# 1158789             NaN
# 1184602             NaN
# 1235976             NaN
# ...                 ...
# 5593233             NaN
# 5673668    ANDREW ROJAS
# 5673805    ANDREW ROJAS
# 5859322             NaN
# 5936618             NaN
#
# [153 rows x 44 columns]

# %%
# My best GUESS is that these are "cured" ballots -- ballots that were initially rejected, but...
# the voter was able to resolve whatever the issue was and get their vote counted

# %%
# Now let's check if any ballots have a rejection reason but status = "received" still.

# Does status = "received"?
# is_received is a boolean variable with True or False in it
is_received =  test_df['ballot_status']=='Received'
print(is_received.head())
# Out:
# 105    False
# 345    False
# 379    False
# 477    False
# 568    False
# Name: ballot_status, dtype: bool

# %%
# now, filter the df to include only ballots with a rejection reason but still listed as received

rejected_received = test_df[is_received]
print(rejected_received.shape)
# Out:
# (2, 44)

# %%
# Only two, thankfully.

# So, while this can't be demonstrated in the dataset itself, it seems likely...
# that the cause of the discrepancy is ballots that were initially rejected, then cured later on.

# %%
#Let's whittle this down to only the cols we want to keep

small_df = df[['voter_id', 'ballot_county', 'ballot_vtr_party', 'ballot_receivedDate', 'ballot_status', 'received_rejReason']]

# %%
small_df
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6047961  L1061243339        Warren       Democratic          11/03/2020
# 6047962  C2754450078        Warren     Unaffiliated          10/28/2020
# 6047963  H4507252594        Warren     Unaffiliated          10/27/2020
# 6047964  N4444001342        Warren     Unaffiliated          11/04/2020
# 6047965  P2819114049        Warren     Unaffiliated                 NaN
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6047961      Accepted                NaN
# 6047962      Accepted                NaN
# 6047963      Accepted                NaN
# 6047964      Accepted                NaN
# 6047965           NaN                NaN
#
# [6032030 rows x 6 columns]

# %%
# Wait -- why do we seem to have some ballots that were accepted but have no received date?

# Lets's filter our df to only rows that have a ballot status, and check how many have no received date.

test_df2 = small_df.dropna(subset=['ballot_status'])
test_df2
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6047960  B6174726327        Warren     Unaffiliated          11/04/2020
# 6047961  L1061243339        Warren       Democratic          11/03/2020
# 6047962  C2754450078        Warren     Unaffiliated          10/28/2020
# 6047963  H4507252594        Warren     Unaffiliated          10/27/2020
# 6047964  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6047960      Accepted                NaN
# 6047961      Accepted                NaN
# 6047962      Accepted                NaN
# 6047963      Accepted                NaN
# 6047964      Accepted                NaN
#
# [4370478 rows x 6 columns]

# %%
# Now check how many rows have no received date:

test_df2['ballot_receivedDate'].isna().sum()
# Out:
# 123483

# %%
# that's... a lot.

# Let's do it in the opposite order now. How many have received date but no ballot status?

test_df3 = small_df.dropna(subset=['ballot_receivedDate'])
test_df3
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 5        A4660351369      Atlantic     Unaffiliated          10/21/2020
# 6        K0876551578      Atlantic     Unaffiliated          10/28/2020
# ...              ...           ...              ...                 ...
# 6047960  B6174726327        Warren     Unaffiliated          11/04/2020
# 6047961  L1061243339        Warren       Democratic          11/03/2020
# 6047962  C2754450078        Warren     Unaffiliated          10/28/2020
# 6047963  H4507252594        Warren     Unaffiliated          10/27/2020
# 6047964  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 5            Accepted                NaN
# 6            Accepted                NaN
# ...               ...                ...
# 6047960      Accepted                NaN
# 6047961      Accepted                NaN
# 6047962      Accepted                NaN
# 6047963      Accepted                NaN
# 6047964      Accepted                NaN
#
# [4246996 rows x 6 columns]

# %%
test_df3['ballot_status'].isna().sum()
# Out:
# 1

# %%
# that, thankfully, is much much smaller.

# not sure why so many seemingly-returned ballots have no received date...
# but that's beyond the scope of our project right now.

# %%
# Let's finally fliter this down to only people who at least attempted to return their ballots.
# It seems like the best assumption we can make to do this is that NA's in ballot status = didn't vote.

# %%
clean_VBM = small_df.dropna(subset=['ballot_status'])
clean_VBM
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6047960  B6174726327        Warren     Unaffiliated          11/04/2020
# 6047961  L1061243339        Warren       Democratic          11/03/2020
# 6047962  C2754450078        Warren     Unaffiliated          10/28/2020
# 6047963  H4507252594        Warren     Unaffiliated          10/27/2020
# 6047964  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6047960      Accepted                NaN
# 6047961      Accepted                NaN
# 6047962      Accepted                NaN
# 6047963      Accepted                NaN
# 6047964      Accepted                NaN
#
# [4370478 rows x 6 columns]

# %%
#... suggesting 4,370,478 people at least tried to vote (regardless of whether ballot was rejected)

# %%
# Let's write this to csv

clean_VBM.to_csv('clean_VBM.csv', index=False)

# %%
# Now let's create another dataframe grouped by county

grouped_VBM = clean_VBM.groupby(['ballot_county'])

# %%
votes_cast = grouped_VBM.size()
votes_cast
# Out:
# ballot_county
# Atlantic      135532
# Bergen        476971
# Burlington    253356
# Camden        246597
# Cape May       56585
# Cumberland     60052
# Essex         307647
# Gloucester    171097
# Hudson        224391
# Hunterdon      84278
# Mercer        170059
# Middlesex     356444
# Monmouth      377276
# Morris        293241
# Ocean         338770
# Passaic       210864
# Salem          33016
# Somerset      183276
# Sussex         87345
# Union         243612
# Warren         60069
# dtype: int64

# %%
# note : these numbers do not all match with official turnout results.
#  (example: Warren county)

# Not much that can be done about that at this point until...
#  we hear back from KnowInk about our assumptions while cleaning.

# %%
# Let's go ahead and calculate ballot status by county.

# %%
number_rejected = grouped_VBM['ballot_status'].apply(lambda x: x.str.contains('Rejected').sum())
number_rejected
# Out:
# ballot_county
# Atlantic       911
# Bergen        5991
# Burlington    1911
# Camden         705
# Cape May       368
# Cumberland     761
# Essex         2185
# Gloucester     100
# Hudson        5607
# Hunterdon      621
# Mercer        1308
# Middlesex     6844
# Monmouth      5407
# Morris        1122
# Ocean            0
# Passaic       1798
# Salem          572
# Somerset      2373
# Sussex         993
# Union         6286
# Warren         970
# Name: ballot_status, dtype: int64

# %%
county_df = pd.concat([votes_cast, number_rejected], axis = 'columns', sort=False)

# %%
county_df
# Out:
#                     0  ballot_status
# ballot_county
# Atlantic       135532            911
# Bergen         476971           5991
# Burlington     253356           1911
# Camden         246597            705
# Cape May        56585            368
# Cumberland      60052            761
# Essex          307647           2185
# Gloucester     171097            100
# Hudson         224391           5607
# Hunterdon       84278            621
# Mercer         170059           1308
# Middlesex      356444           6844
# Monmouth       377276           5407
# Morris         293241           1122
# Ocean          338770              0
# Passaic        210864           1798
# Salem           33016            572
# Somerset       183276           2373
# Sussex          87345            993
# Union          243612           6286
# Warren          60069            970

# %%
county_df.rename(columns={0:'ballots_cast', 'ballot_status':'ballots_rejected'}, inplace=True)

# %%
county_df
# Out:
#                ballots_cast  ballots_rejected
# ballot_county
# Atlantic             135532               911
# Bergen               476971              5991
# Burlington           253356              1911
# Camden               246597               705
# Cape May              56585               368
# Cumberland            60052               761
# Essex                307647              2185
# Gloucester           171097               100
# Hudson               224391              5607
# Hunterdon             84278               621
# Mercer               170059              1308
# Middlesex            356444              6844
# Monmouth             377276              5407
# Morris               293241              1122
# Ocean                338770                 0
# Passaic              210864              1798
# Salem                 33016               572
# Somerset             183276              2373
# Sussex                87345               993
# Union                243612              6286
# Warren                60069               970

# %%
county_df['percent_rejected'] = (county_df['ballots_rejected']/county_df['ballots_cast']) * 100

# %%
county_df
# Out:
#                ballots_cast  ballots_rejected  percent_rejected
# ballot_county
# Atlantic             135532               911          0.672166
# Bergen               476971              5991          1.256051
# Burlington           253356              1911          0.754275
# Camden               246597               705          0.285892
# Cape May              56585               368          0.650349
# Cumberland            60052               761          1.267235
# Essex                307647              2185          0.710230
# Gloucester           171097               100          0.058446
# Hudson               224391              5607          2.498763
# Hunterdon             84278               621          0.736847
# Mercer               170059              1308          0.769145
# Middlesex            356444              6844          1.920077
# Monmouth             377276              5407          1.433168
# Morris               293241              1122          0.382620
# Ocean                338770                 0          0.000000
# Passaic              210864              1798          0.852682
# Salem                 33016               572          1.732493
# Somerset             183276              2373          1.294769
# Sussex                87345               993          1.136871
# Union                243612              6286          2.580333
# Warren                60069               970          1.614810

# %%
#need to check Ocean County, does not make sense they'd have zero rej's

# %%
#in the meantime, write to csv

# %%
#switch index to column

# %%
county_df.to_csv('county_df.csv', index=)
