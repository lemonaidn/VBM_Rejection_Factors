# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Aidan'

# %%
cd Documents/github/VBM_Rejection_Factors/final code
# Out:
# C:\Users\Aidan\Documents\github\VBM_Rejection_Factors\final code

# %%
merged_df = pd.read_csv('merged_df.csv')
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135484               910          0.671666
# 1       Bergen        476733              5986          1.255629
# 2   Burlington        253339              1911          0.754325
# 3       Camden        246440               703          0.285262
# 4     Cape May         56565               367          0.648811
# 5   Cumberland         60047               761          1.267341
# 6        Essex        307537              2184          0.710158
# 7   Gloucester        170985               100          0.058485
# 8       Hudson        224243              5605          2.499521
# 9    Hunterdon         84247               618          0.733557
# 10      Mercer        169955              1314          0.773146
# 11   Middlesex        355993              6837          1.920543
# 12    Monmouth        377148              5403          1.432594
# ...

# %%
cd C:\Users\Aidan\Documents\github\VBM_Rejection_Factors\Aidan
# Out:
# C:\Users\Aidan\Documents\github\VBM_Rejection_Factors\Aidan

# %%
age_df = pd.read_csv('age_clean.csv')
age_df['County']=merged_df['County']
age_df
# Out:
#     Percent 15 to 19 years  Percent 20 to 24 years  Percent 25 to 34 years  \
# 0                      6.2                     6.7                    11.4
# 1                      6.1                     5.8                    11.6
# 2                      6.0                     6.1                    12.6
# 3                      6.4                     5.6                    14.0
# 4                      4.3                     5.3                    10.0
# 5                      6.5                     4.8                    14.7
# 6                      6.3                     6.2                    13.8
# 7                      6.4                     6.5                    12.0
# 8                      4.8                     5.8                    21.1
# 9                      6.4                     5.8                     9.7
# 10                     7.9                     7.1                    12.5
# ...

# %%
merged_df = pd.merge(merged_df, age_df)
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135484               910          0.671666
# 1       Bergen        476733              5986          1.255629
# 2   Burlington        253339              1911          0.754325
# 3       Camden        246440               703          0.285262
# 4     Cape May         56565               367          0.648811
# 5   Cumberland         60047               761          1.267341
# 6        Essex        307537              2184          0.710158
# 7   Gloucester        170985               100          0.058485
# 8       Hudson        224243              5605          2.499521
# 9    Hunterdon         84247               618          0.733557
# 10      Mercer        169955              1314          0.773146
# 11   Middlesex        355993              6837          1.920543
# 12    Monmouth        377148              5403          1.432594
# ...

# %%
income_df = pd.read_csv('income_clean.csv')
income_df['County']=merged_df['County']
income_df
# Out:
#     Percent Less than $10,000  Percent $10,000 to $14,999  \
# 0                         6.5                         3.7
# 1                         3.4                         1.9
# 2                         2.5                         1.5
# 3                         6.2                         3.4
# 4                         4.2                         3.3
# 5                         7.5                         4.9
# 6                         8.4                         4.3
# 7                         3.8                         2.6
# 8                         6.2                         4.7
# 9                         1.8                         1.4
# 10                        8.2                         3.6
# 11                        4.2                         2.4
# 12                        4.4                         2.4
# 13                        2.5                         1.6
# 14                        3.1                         2.4
# ...

# %%
merged_df = pd.merge(merged_df, income_df)
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135484               910          0.671666
# 1       Bergen        476733              5986          1.255629
# 2   Burlington        253339              1911          0.754325
# 3       Camden        246440               703          0.285262
# 4     Cape May         56565               367          0.648811
# 5   Cumberland         60047               761          1.267341
# 6        Essex        307537              2184          0.710158
# 7   Gloucester        170985               100          0.058485
# 8       Hudson        224243              5605          2.499521
# 9    Hunterdon         84247               618          0.733557
# 10      Mercer        169955              1314          0.773146
# 11   Middlesex        355993              6837          1.920543
# 12    Monmouth        377148              5403          1.432594
# ...

# %%
poverty_df = pd.read_csv('poverty_clean.csv')
poverty_df['County']=merged_df['County']
poverty_df
# Out:
#     Percent below poverty level      County
# 0                          11.1    Atlantic
# 1                           5.6      Bergen
# 2                           5.5  Burlington
# 3                          10.7      Camden
# 4                           8.8    Cape May
# 5                          13.2  Cumberland
# 6                          13.9       Essex
# 7                           7.7  Gloucester
# 8                          13.9      Hudson
# 9                           3.6   Hunterdon
# 10                         12.8      Mercer
# 11                          8.8   Middlesex
# 12                          6.0    Monmouth
# 13                          5.5      Morris
# 14                          9.0       Ocean
# 15                         13.4     Passaic
# 16                         12.4       Salem
# 17                          5.7    Somerset
# 18                          4.7      Sussex
# 19                          9.1       Union
# ...

# %%
merged_df = pd.merge(merged_df, poverty_df)
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135484               910          0.671666
# 1       Bergen        476733              5986          1.255629
# 2   Burlington        253339              1911          0.754325
# 3       Camden        246440               703          0.285262
# 4     Cape May         56565               367          0.648811
# 5   Cumberland         60047               761          1.267341
# 6        Essex        307537              2184          0.710158
# 7   Gloucester        170985               100          0.058485
# 8       Hudson        224243              5605          2.499521
# 9    Hunterdon         84247               618          0.733557
# 10      Mercer        169955              1314          0.773146
# 11   Middlesex        355993              6837          1.920543
# 12    Monmouth        377148              5403          1.432594
# ...

# %%
cd C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Final Code
# Out:
# C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Final Code

# %%
merged_df.to_csv('merged_df.csv', index=False)
