# %%
pwd
# Out:
# 'C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan'

# %%
cd C:\Users\Aidan\Downloads\Updated_VBM_Report\vbm12.13.20.csv
# Out:
# C:\Users\Aidan\Downloads\Updated_VBM_Report\vbm12.13.20.csv

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
raw_df = pd.read_csv('Updated_VBM_Report.csv')
# Out:
# C:\Users\Aidan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2,15,42,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
raw_df
# Out:
#         current_county current_municipality current_ward  current_district  \
# 0             Atlantic         Absecon City            1               1.0
# 1             Atlantic         Absecon City            1               1.0
# 2             Atlantic         Absecon City            1               1.0
# 3             Atlantic         Absecon City            1               1.0
# 4             Atlantic         Absecon City            1               1.0
# ...                ...                  ...          ...               ...
# 6044852         Warren       White Township            0               6.0
# 6044853         Warren       White Township            0               6.0
# 6044854         Warren       White Township            0               6.0
# 6044855         Warren       White Township            0               6.0
# 6044856         Warren       White Township            0               6.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 0                 Single Election  P2763351335     LINGELBACH         CAROLYN
# 1        Annual Mail-In Elections  P3919851339          TIMMS           BRIAN
# 2                 Single Election  P6095651352      CUSHLANIS           ROBIN
# 3                 Single Election  A1425851358       DILLHOFF           KEVIN
# 4                 Single Election  A1783751359          JETER            PAUL
# ...                           ...          ...            ...             ...
# 6044852           Single Election  L1061243339         COWLEY           JARED
# 6044853           Single Election  C2754450078     WELENOFSKY            LISA
# 6044854           Single Election  H4507252594       MCGINLEY          MEGHAN
# 6044855           Single Election  N4444001342         CARMEN             KOI
# 6044856           Single Election  P2819114049         ALESSI       KATHERINE
#
#         voter_middleName voter_suffix   voter_party voter_status  \
# 0                      R          NaN  Unaffiliated       Active
# 1                      D          NaN    Democratic       Active
# 2                      A          NaN    Republican       Active
# 3                      T          NaN    Democratic       Active
# 4                      D          NaN    Democratic       Active
# ...                  ...          ...           ...          ...
# 6044852            DUANE          Jr.    Democratic       Active
# 6044853             JEAN          NaN  Unaffiliated       Active
# 6044854              NaN          NaN  Unaffiliated       Active
# 6044855              LEA          NaN  Unaffiliated       Active
# 6044856             ROSE          NaN  Unaffiliated       Active
#
#                              ballot_type ballot_county ballot_municipality  \
# 0                                Regular      Atlantic        Absecon City
# 1        Presidential / Removed Resident      Atlantic        Absecon City
# 2                                Regular      Atlantic        Absecon City
# 3                                Regular      Atlantic        Absecon City
# 4                                Regular      Atlantic        Absecon City
# ...                                  ...           ...                 ...
# 6044852                          Regular        Warren      White Township
# 6044853                          Regular        Warren      White Township
# 6044854                          Regular        Warren      White Township
# 6044855                          Regular        Warren      White Township
# 6044856                          Regular        Warren      White Township
#
#         ballot_ward  ballot_district ballot_vtr_party  \
# 0                 1                1     Unaffiliated
# 1                 1                1       Democratic
# 2                 1                1       Republican
# 3                 1                1       Democratic
# 4                 1                1       Democratic
# ...             ...              ...              ...
# 6044852           0                6       Democratic
# 6044853           0                6     Unaffiliated
# 6044854           0                6     Unaffiliated
# 6044855           0                6     Unaffiliated
# 6044856           0                6     Unaffiliated
#
#             ballot_addr_address1 ballot_addr_address2 ballot_addr_address3  \
# 0        122 E Faunce Landing Rd                  NaN                  NaN
# 1                    506 Lazy Ln                  NaN                  NaN
# 2                 645 Weilers Ln                  NaN                  NaN
# 3                     635 4th St                  NaN                  NaN
# 4                    511 LAZY LN                  NaN                  NaN
# ...                          ...                  ...                  ...
# 6044852           96 BUCKHORN DR                  NaN                  NaN
# 6044853              25 COLBY CT                  NaN                  NaN
# 6044854              23 COLBY CT                  NaN                  NaN
# 6044855      835 BRASS CASTLE RD                  NaN                  NaN
# 6044856              15 COLBY CT                  NaN                  NaN
#
#         ballot_addr_city ballot_addr_state ballot_addr_zipcode  \
# 0                Absecon                NJ          08201-1808
# 1                Absecon                NJ          08201-1337
# 2                Absecon                NJ          08201-1326
# 3                Absecon                NJ          08201-1304
# 4                ABSECON                NJ          08201-1338
# ...                  ...               ...                 ...
# 6044852       WASHINGTON                NJ          07882-3805
# 6044853        BELVIDERE                NJ          07823-2755
# 6044854        BELVIDERE                NJ          07823-2755
# 6044855        BELVIDERE                NJ          07823-2724
# 6044856        BELVIDERE                NJ          07823-2754
#
#         ballot_addr_country application_receivedDate  \
# 0                       NaN               08/14/2020
# 1                        US               08/26/2020
# 2                       NaN               08/14/2020
# 3                       NaN               08/14/2020
# 4                        US               08/14/2020
# ...                     ...                      ...
# 6044852                  US               08/14/2020
# 6044853                  US               08/14/2020
# 6044854                  US               08/14/2020
# 6044855                  US               08/14/2020
# 6044856                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 0                      08/31/2020           Accepted        09/21/2020
# 1                      08/26/2020           Accepted        09/21/2020
# 2                      08/31/2020           Accepted        09/21/2020
# 3                      08/31/2020           Accepted        09/21/2020
# 4                      08/31/2020           Accepted        09/21/2020
# ...                           ...                ...               ...
# 6044852                10/19/2020           Accepted        10/21/2020
# 6044853                10/19/2020           Accepted        10/21/2020
# 6044854                10/19/2020           Accepted        10/21/2020
# 6044855                10/19/2020           Accepted        10/21/2020
# 6044856                10/19/2020           Accepted        10/21/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 0                10/23/2020         11/20/2020      Accepted      Drop Box
# 1                10/21/2020         11/20/2020      Accepted      Drop Box
# 2                10/18/2020         11/20/2020      Accepted      Drop Box
# 3                       NaN         11/20/2020      Accepted      Drop Box
# 4                       NaN         11/20/2020      Accepted      Drop Box
# ...                     ...                ...           ...           ...
# 6044852          11/03/2020         11/23/2020      Accepted     In Person
# 6044853          10/28/2020         11/23/2020      Accepted      Drop Box
# 6044854          10/27/2020         11/23/2020      Accepted      Drop Box
# 6044855          11/04/2020         11/23/2020      Accepted     In Person
# 6044856                 NaN                NaN           NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 0                      NaN               122  E Faunce Landing Rd
# 1                      NaN               506              Lazy Ln
# 2                      NaN               645           Weilers Ln
# 3                      NaN               635               4th St
# 4                      NaN               511              LAZY LN
# ...                    ...               ...                  ...
# 6044852                NaN                96          BUCKHORN DR
# 6044853                NaN                25             COLBY CT
# 6044854                NaN                23             COLBY CT
# 6044855                NaN               835      BRASS CASTLE RD
# 6044856                NaN                15             COLBY CT
#
#           voter_resAddr_address1 voter_resAddr_address2  \
# 0        122 E Faunce Landing Rd                    NaN
# 1                    506 Lazy Ln                    NaN
# 2                 645 Weilers Ln                    NaN
# 3                     635 4th St                    NaN
# 4                    511 LAZY LN                    NaN
# ...                          ...                    ...
# 6044852           96 BUCKHORN DR                    NaN
# 6044853              25 COLBY CT                    NaN
# 6044854              23 COLBY CT                    NaN
# 6044855      835 BRASS CASTLE RD                    NaN
# 6044856              15 COLBY CT                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 0                           NaN            Absecon                  NJ
# 1                           NaN            Absecon                  NJ
# 2                           NaN            Absecon                  NJ
# 3                           NaN            Absecon                  NJ
# 4                           NaN            ABSECON                  NJ
# ...                         ...                ...                 ...
# 6044852                     NaN         WASHINGTON                  NJ
# 6044853                     NaN          BELVIDERE                  NJ
# 6044854                     NaN          BELVIDERE                  NJ
# 6044855                     NaN          BELVIDERE                  NJ
# 6044856                     NaN          BELVIDERE                  NJ
#
#         voter_resAddr_zipcode voter_phone              voter_email  \
# 0                  08201-1808         NaN                      NaN
# 1                  08201-1337  8609447558   BIBLIOMANE74@GMAIL.COM
# 2                  08201-1326  6093284677                      NaN
# 3                  08201-1304         NaN  KEVINDILLHOFF@GMAIL.COM
# 4                  08201-1338         NaN                      NaN
# ...                       ...         ...                      ...
# 6044852            07882-3805         NaN                      NaN
# 6044853            07823-2755         NaN                      NaN
# 6044854            07823-2755         NaN                      NaN
# 6044855            07823-2724         NaN                      NaN
# 6044856            07823-2754         NaN                      NaN
#
#         received_bearer
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 6044852             NaN
# 6044853             NaN
# 6044854             NaN
# 6044855             NaN
# 6044856             NaN
#
# [6044857 rows x 45 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6044857 entries, 0 to 6044856
# Data columns (total 45 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   current_county             object
#  1   current_municipality       object
#  2   current_ward               object
#  3   current_district           float64
#  4   ballot_requestType         object
#  5   voter_id                   object
#  6   voter_lastName             object
#  7   voter_firstName            object
#  8   voter_middleName           object
#  9   voter_suffix               object
#  10  voter_party                object
#  11  voter_status               object
#  12  ballot_type                object
#  13  ballot_county              object
#  14  ballot_municipality        object
#  15  ballot_ward                object
#  16  ballot_district            int64
#  17  ballot_vtr_party           object
#  18  ballot_addr_address1       object
#  19  ballot_addr_address2       object
#  20  ballot_addr_address3       object
#  21  ballot_addr_city           object
#  22  ballot_addr_state          object
#  23  ballot_addr_zipcode        object
#  24  ballot_addr_country        object
#  25  application_receivedDate   object
#  26  application_processedDate  object
#  27  application_status         object
#  28  ballot_mailedDate          object
#  29  ballot_receivedDate        object
#  30  ballot_countedDate         object
#  31  ballot_status              object
#  32  received_type              object
#  33  received_rejReason         object
#  34  voter_resAddr_num          object
#  35  voter_resAddr_street       object
#  36  voter_resAddr_address1     object
#  37  voter_resAddr_address2     object
#  38  voter_resAddr_address3     float64
#  39  voter_resAddr_city         object
#  40  voter_resAddr_state        object
#  41  voter_resAddr_zipcode      object
#  42  voter_phone                object
#  43  voter_email                object
#  44  received_bearer            object
# dtypes: float64(2), int64(1), object(42)
# memory usage: 2.0+ GB

# %%
#number of ballots with rejection reasons

raw_df['received_rejReason'].count()
# Out:
# 50704

# %%
#compare that to number of ballots with status = rejected

status_is_rejected = raw_df['ballot_status']=='Rejected'
print(status_is_rejected.head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: ballot_status, dtype: bool

# %%
status_is_rejected.value_counts()
# Out:
# False    5994308
# True       50549
# Name: ballot_status, dtype: int64

# %%
#rejected ballots by reason for rejection

raw_df['received_rejReason'].value_counts()
# Out:
# Signature Does Not Match          16824
# Certificate Missing               11760
# Certificate Not Signed             8880
# Other                              7042
# Ballot Received After Deadline     2008
# Ballot Not Enclosed                1590
# Voter Registration ID Missing       953
# Bearer Exceeded Limit               910
# Incomplete Bearer Portion           403
# Moved Out of County                 199
# Power of Attorney                    60
# Incomplete Assistor Portion          54
# Ineligible Voter Status               6
# Both Envelopes Unsealed               5
# Bearer Book Not Signed In             3
# Primary-Voted Both Parties            3
# Candidate Provided Assistance         2
# One Envelope Unsealed                 2
# Name: received_rejReason, dtype: int64

# %%
#NA's in Rejection reason should represent accepted ballots AND people who did not vote

raw_df['received_rejReason'].isna().sum()
# Out:
# 5994153

# %%
print(raw_df['ballot_receivedDate'].unique())
# Out:
# ['10/23/2020' '10/21/2020' '10/18/2020' nan '10/28/2020' '10/19/2020'
#  '10/22/2020' '10/16/2020' '10/24/2020' '10/29/2020' '10/20/2020'
#  '11/03/2020' '10/26/2020' '10/15/2020' '10/17/2020' '10/27/2020'
#  '10/30/2020' '11/04/2020' '11/02/2020' '10/25/2020' '10/31/2020'
#  '11/01/2020' '11/12/2020' '11/10/2020' '10/05/2020' '11/05/2020'
#  '11/06/2020' '10/10/2020' '10/07/2020' '10/09/2020' '10/08/2020'
#  '10/06/2020' '10/14/2020' '10/13/2020' '10/12/2020' '10/03/2020'
#  '09/29/2020' '10/01/2020' '09/30/2020' '10/04/2020' '10/11/2020'
#  '10/02/2020' '11/07/2020' '11/09/2020' '09/22/2020' '11/16/2020'
#  '11/14/2020' '11/17/2020' '11/13/2020' '09/09/2020' '09/28/2020'
#  '09/02/2020' '11/11/2020' '11/23/2020' '11/20/2020' '09/21/2020'
#  '09/24/2020' '09/20/2020' '09/25/2020' '09/05/2020' '08/30/2020'
#  '09/14/2020' '09/18/2020' '09/27/2020' '09/04/2020' '09/17/2020'
#  '09/23/2020' '09/26/2020' '09/16/2020' '11/08/2020' '09/15/2020'
#  '09/12/2020' '09/06/2020' '11/19/2020' '11/18/2020' '12/01/2020'
#  '09/19/2020' '12/08/2020' '12/04/2020' '09/01/2020' '12/10/2020'
#  '09/30/2019' '11/30/2020' '11/15/2020' '07/07/2020' '12/03/2020'
#  '11/24/2020' '11/22/2020' '11/25/2020' '09/11/2020' '09/10/2020'
#  '09/08/2020' '10/29/2019' '08/29/2020']

# %%
#Some voters/voter ID's are duplicated in the report:

raw_df['voter_id'].value_counts()
# Out:
# E1576352907    7
# N4349817779    6
# C3205153239    5
# C5931054002    4
# D3143354014    4
#               ..
# M1269351624    1
# G0131954069    1
# L1062753427    1
# K2202853049    1
# P2115952424    1
# Name: voter_id, Length: 6028484, dtype: int64

# %%
#Let's take the most extreme example and see what's going on:

top_dup = raw_df.loc[raw_df['voter_id'] == 'E1576352907']
top_dup
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4975832        Passaic         Clifton City            2               8.0
# 4975833        Passaic         Clifton City            2               8.0
# 4975834        Passaic         Clifton City            2               8.0
# 4975835        Passaic         Clifton City            2               8.0
# 4975836        Passaic         Clifton City            2               8.0
# 4975837        Passaic         Clifton City            2               8.0
# 4975838        Passaic         Clifton City            2               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4975832    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975833    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975834    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975835    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975836    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975837    Single Election  E1576352907     BASHJAWISH            FUAD
# 4975838    Single Election  E1576352907     BASHJAWISH            FUAD
#
#         voter_middleName voter_suffix voter_party voter_status ballot_type  \
# 4975832                A          NaN  Republican       Active     Regular
# 4975833                A          NaN  Republican       Active     Regular
# 4975834                A          NaN  Republican       Active     Regular
# 4975835                A          NaN  Republican       Active     Regular
# 4975836                A          NaN  Republican       Active     Regular
# 4975837                A          NaN  Republican       Active     Regular
# 4975838                A          NaN  Republican       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 4975832       Passaic        Clifton City           2                8
# 4975833       Passaic        Clifton City           2                8
# 4975834       Passaic        Clifton City           2                8
# 4975835       Passaic        Clifton City           2                8
# 4975836       Passaic        Clifton City           2                8
# 4975837       Passaic        Clifton City           2                8
# 4975838       Passaic        Clifton City           2                8
#
#         ballot_vtr_party  ballot_addr_address1 ballot_addr_address2  \
# 4975832       Democratic  117 Mountainside Ter                  NaN
# 4975833       Republican  117 Mountainside Ter                  NaN
# 4975834       Republican  117 Mountainside Ter                  NaN
# 4975835       Republican  117 Mountainside Ter                  NaN
# 4975836       Republican  117 MOUNTAINSIDE TER                  NaN
# 4975837       Republican  117 Mountainside Ter                  NaN
# 4975838       Republican  117 MOUNTAINSIDE TER                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 4975832                  NaN          Clifton                NJ
# 4975833                  NaN          Clifton                NJ
# 4975834                  NaN          Clifton                NJ
# 4975835                  NaN          Clifton                NJ
# 4975836                  NaN          CLIFTON                NJ
# 4975837                  NaN          Clifton                NJ
# 4975838                  NaN          CLIFTON                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 4975832          07013-1178                 NaN               08/14/2020
# 4975833          07013-1178                 NaN               08/14/2020
# 4975834          07013-1178                 NaN               08/14/2020
# 4975835          07013-1178                 NaN               08/14/2020
# 4975836          07013-1178                  US               08/14/2020
# 4975837          07013-1178                 NaN               08/14/2020
# 4975838          07013-1178                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 4975832                08/31/2020           Accepted               NaN
# 4975833                08/31/2020           Accepted               NaN
# 4975834                08/31/2020           Accepted               NaN
# 4975835                08/31/2020           Accepted               NaN
# 4975836                08/31/2020           Accepted               NaN
# 4975837                08/31/2020           Accepted               NaN
# 4975838                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 4975832                 NaN                NaN           NaN           NaN
# 4975833                 NaN                NaN           NaN           NaN
# 4975834                 NaN                NaN           NaN           NaN
# 4975835                 NaN                NaN           NaN           NaN
# 4975836                 NaN                NaN           NaN           NaN
# 4975837                 NaN                NaN           NaN           NaN
# 4975838                 NaN                NaN           NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 4975832                NaN               117     MOUNTAINSIDE TER
# 4975833                NaN               117     MOUNTAINSIDE TER
# 4975834                NaN               117     MOUNTAINSIDE TER
# 4975835                NaN               117     MOUNTAINSIDE TER
# 4975836                NaN               117     MOUNTAINSIDE TER
# 4975837                NaN               117     MOUNTAINSIDE TER
# 4975838                NaN               117     MOUNTAINSIDE TER
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 4975832   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975833   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975834   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975835   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975836   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975837   117 MOUNTAINSIDE TER                    NaN                     NaN
# 4975838   117 MOUNTAINSIDE TER                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 4975832            CLIFTON                  NJ            07013-1178
# 4975833            CLIFTON                  NJ            07013-1178
# 4975834            CLIFTON                  NJ            07013-1178
# 4975835            CLIFTON                  NJ            07013-1178
# 4975836            CLIFTON                  NJ            07013-1178
# 4975837            CLIFTON                  NJ            07013-1178
# 4975838            CLIFTON                  NJ            07013-1178
#
#         voter_phone voter_email received_bearer
# 4975832  9732472453         NaN             NaN
# 4975833  9732472453         NaN             NaN
# 4975834  9732472453         NaN             NaN
# 4975835  9732472453         NaN             NaN
# 4975836  9732472453         NaN             NaN
# 4975837  9732472453         NaN             NaN
# 4975838  9732472453         NaN             NaN

# %%
#It looks like they're identical records, some with lowercase cols and some with uppercase cols

#In this instace, it looks like the last row is the one we want to keep bc it contains the ballot mailed date

# %%
#let's see if that holds true for a few more examples

dup_2 = raw_df.loc[raw_df['voter_id'] == 'N4349817779']
dup_2

#Yes, want to keep the last row
# Out:
#         current_county   current_municipality current_ward  current_district  \
# 5023619        Passaic  Little Falls Township            0               8.0
# 5023620        Passaic  Little Falls Township            0               8.0
# 5023621        Passaic  Little Falls Township            0               8.0
# 5023622        Passaic  Little Falls Township            0               8.0
# 5023623        Passaic  Little Falls Township            0               8.0
# 5023624        Passaic  Little Falls Township            0               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 5023619    Single Election  N4349817779          DEFEO            EMMA
# 5023620    Single Election  N4349817779          DEFEO            EMMA
# 5023621    Single Election  N4349817779          DEFEO            EMMA
# 5023622    Single Election  N4349817779          DEFEO            EMMA
# 5023623    Single Election  N4349817779          DEFEO            EMMA
# 5023624    Single Election  N4349817779          DEFEO            EMMA
#
#         voter_middleName voter_suffix   voter_party voter_status ballot_type  \
# 5023619                L          NaN  Unaffiliated       Active     Regular
# 5023620                L          NaN  Unaffiliated       Active     Regular
# 5023621                L          NaN  Unaffiliated       Active     Regular
# 5023622                L          NaN  Unaffiliated       Active     Regular
# 5023623                L          NaN  Unaffiliated       Active     Regular
# 5023624                L          NaN  Unaffiliated       Active     Regular
#
#         ballot_county    ballot_municipality ballot_ward  ballot_district  \
# 5023619       Passaic  Little Falls Township           0                8
# 5023620       Passaic  Little Falls Township           0                8
# 5023621       Passaic  Little Falls Township           0                8
# 5023622       Passaic  Little Falls Township           0                8
# 5023623       Passaic  Little Falls Township           0                8
# 5023624       Passaic  Little Falls Township           0                8
#
#         ballot_vtr_party ballot_addr_address1 ballot_addr_address2  \
# 5023619     Unaffiliated         88 BERGEN DR                  NaN
# 5023620       Republican         88 Bergen Dr                  NaN
# 5023621       Republican         88 Bergen Dr                  NaN
# 5023622     Unaffiliated         88 BERGEN DR                  NaN
# 5023623       Republican         88 Bergen Dr                  NaN
# 5023624     Unaffiliated         88 BERGEN DR                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 5023619                  NaN     LITTLE FALLS                NJ
# 5023620                  NaN     Little Falls                NJ
# 5023621                  NaN     Little Falls                NJ
# 5023622                  NaN     LITTLE FALLS                NJ
# 5023623                  NaN     Little Falls                NJ
# 5023624                  NaN     LITTLE FALLS                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 5023619          07424-1342                  US               08/14/2020
# 5023620          07424-1342                 NaN               08/14/2020
# 5023621          07424-1342                 NaN               08/14/2020
# 5023622          07424-1342                  US               08/14/2020
# 5023623          07424-1342                 NaN               08/14/2020
# 5023624          07424-1342                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 5023619                08/31/2020           Accepted               NaN
# 5023620                08/31/2020           Accepted               NaN
# 5023621                08/31/2020           Accepted               NaN
# 5023622                08/31/2020           Accepted               NaN
# 5023623                08/31/2020           Accepted               NaN
# 5023624                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 5023619                 NaN                NaN           NaN           NaN
# 5023620                 NaN                NaN           NaN           NaN
# 5023621                 NaN                NaN           NaN           NaN
# 5023622                 NaN                NaN           NaN           NaN
# 5023623                 NaN                NaN           NaN           NaN
# 5023624          11/02/2020         11/24/2020      Accepted      Drop Box
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 5023619                NaN                88            BERGEN DR
# 5023620                NaN                88            BERGEN DR
# 5023621                NaN                88            BERGEN DR
# 5023622                NaN                88            BERGEN DR
# 5023623                NaN                88            BERGEN DR
# 5023624                NaN                88            BERGEN DR
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 5023619           88 BERGEN DR                    NaN                     NaN
# 5023620           88 BERGEN DR                    NaN                     NaN
# 5023621           88 BERGEN DR                    NaN                     NaN
# 5023622           88 BERGEN DR                    NaN                     NaN
# 5023623           88 BERGEN DR                    NaN                     NaN
# 5023624           88 BERGEN DR                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 5023619       LITTLE FALLS                  NJ            07424-1342
# 5023620       LITTLE FALLS                  NJ            07424-1342
# 5023621       LITTLE FALLS                  NJ            07424-1342
# 5023622       LITTLE FALLS                  NJ            07424-1342
# 5023623       LITTLE FALLS                  NJ            07424-1342
# 5023624       LITTLE FALLS                  NJ            07424-1342
#
#         voter_phone voter_email received_bearer
# 5023619         NaN         NaN             NaN
# 5023620         NaN         NaN             NaN
# 5023621         NaN         NaN             NaN
# 5023622         NaN         NaN             NaN
# 5023623         NaN         NaN             NaN
# 5023624         NaN         NaN             NaN

# %%
dup_3 = raw_df.loc[raw_df['voter_id'] == 'C2833253992']
dup_3

#Same again

#IMPORTANT: the ballot types differ -- top = regular, the rest are "Presidential / Removed Resident"
# Out:
#        current_county current_municipality current_ward  current_district  \
# 185265         Bergen    Allendale Borough            0               1.0
# 185266         Bergen    Allendale Borough            0               1.0
# 185267         Bergen    Allendale Borough            0               1.0
# 185268         Bergen    Allendale Borough            0               1.0
#
#               ballot_requestType     voter_id voter_lastName voter_firstName  \
# 185265           Single Election  C2833253992      CALIANESE          JOSEPH
# 185266  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
# 185267  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
# 185268  Annual Mail-In Elections  C2833253992      CALIANESE          JOSEPH
#
#        voter_middleName voter_suffix voter_party voter_status  \
# 185265                T          NaN  Republican       Active
# 185266                T          NaN  Republican       Active
# 185267                T          NaN  Republican       Active
# 185268                T          NaN  Republican       Active
#
#                             ballot_type ballot_county ballot_municipality  \
# 185265                          Regular        Bergen   Allendale Borough
# 185266  Presidential / Removed Resident        Bergen   Allendale Borough
# 185267  Presidential / Removed Resident        Bergen   Allendale Borough
# 185268  Presidential / Removed Resident        Bergen   Allendale Borough
#
#        ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 185265           0                1       Republican         68 Canaan Pl
# 185266           0                1       Republican         68 CANAAN PL
# 185267           0                1       Republican         68 CANAAN PL
# 185268           0                1       Republican         68 CANAAN PL
#
#        ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 185265                  NaN                  NaN        Allendale
# 185266                  NaN                  NaN        ALLENDALE
# 185267                  NaN                  NaN        ALLENDALE
# 185268                  NaN                  NaN        ALLENDALE
#
#        ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 185265                NJ          07401-1820                 NaN
# 185266                NJ          07401-1820                  US
# 185267                NJ          07401-1820                  US
# 185268                NJ          07401-1820                  US
#
#        application_receivedDate application_processedDate application_status  \
# 185265               08/14/2020                08/31/2020           Accepted
# 185266               09/04/2020                09/04/2020           Accepted
# 185267               09/04/2020                09/04/2020           Accepted
# 185268               09/04/2020                09/04/2020           Accepted
#
#        ballot_mailedDate ballot_receivedDate ballot_countedDate ballot_status  \
# 185265               NaN                 NaN                NaN           NaN
# 185266               NaN                 NaN                NaN           NaN
# 185267               NaN                 NaN                NaN           NaN
# 185268        09/21/2020          10/31/2020         12/02/2020      Accepted
#
#        received_type received_rejReason voter_resAddr_num  \
# 185265           NaN                NaN                68
# 185266           NaN                NaN                68
# 185267           NaN                NaN                68
# 185268          Mail                NaN                68
#
#        voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 185265            Canaan Pl           68 Canaan Pl                    NaN
# 185266            Canaan Pl           68 Canaan Pl                    NaN
# 185267            Canaan Pl           68 Canaan Pl                    NaN
# 185268            Canaan Pl           68 Canaan Pl                    NaN
#
#         voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 185265                     NaN          Allendale                  NJ
# 185266                     NaN          Allendale                  NJ
# 185267                     NaN          Allendale                  NJ
# 185268                     NaN          Allendale                  NJ
#
#        voter_resAddr_zipcode voter_phone voter_email received_bearer
# 185265            07401-1820         NaN         NaN             NaN
# 185266            07401-1820         NaN         NaN             NaN
# 185267            07401-1820         NaN         NaN             NaN
# 185268            07401-1820         NaN         NaN             NaN

# %%
dup_4 = raw_df.loc[raw_df['voter_id'] == 'P3690153923']
dup_4

# Same as above -- last row has dates, but rows have different ballot types AND addresses
# It looks like this one is because they got an overseas ballot
# Out:
#         current_county current_municipality current_ward  current_district  \
# 1171072         Camden       Berlin Borough            0               3.0
# 1171073         Camden       Berlin Borough            0               3.0
# 1171074         Camden       Berlin Borough            0               3.0
# 1171075         Camden       Berlin Borough            0               3.0
#
#                       ballot_requestType     voter_id voter_lastName  \
# 1171072                  Single Election  P3690153923          SCOTT
# 1171073  UOCAVA Annual Mail-In Elections  P3690153923          SCOTT
# 1171074         Annual Mail-In Elections  P3690153923          SCOTT
# 1171075  UOCAVA Annual Mail-In Elections  P3690153923          SCOTT
#
#         voter_firstName voter_middleName voter_suffix   voter_party  \
# 1171072           SUSAN                L          NaN  Unaffiliated
# 1171073           SUSAN                L          NaN  Unaffiliated
# 1171074           SUSAN                L          NaN  Unaffiliated
# 1171075           SUSAN                L          NaN  Unaffiliated
#
#         voter_status                      ballot_type ballot_county  \
# 1171072       Active                          Regular        Camden
# 1171073       Active                             Full        Camden
# 1171074       Active  Presidential / Removed Resident        Camden
# 1171075       Active                             Full        Camden
#
#         ballot_municipality ballot_ward  ballot_district ballot_vtr_party  \
# 1171072      Berlin Borough           0                3     Unaffiliated
# 1171073      Berlin Borough           0                3     Unaffiliated
# 1171074      Berlin Borough           0                3     Unaffiliated
# 1171075      Berlin Borough           0                3     Unaffiliated
#
#                         ballot_addr_address1 ballot_addr_address2  \
# 1171072                          32 Mason Dr                  NaN
# 1171073  HORIZON TOWER - 214 TRAN QUANG KHAI   APT 23.03 TAN DINH
# 1171074                          32 Mason Dr                  NaN
# 1171075  HORIZON TOWER - 214 TRAN QUANG KHAI   APT 23.03 TAN DINH
#
#         ballot_addr_address3  ballot_addr_city ballot_addr_state  \
# 1171072                  NaN            Berlin                NJ
# 1171073                  NaN  HO CHI MINH CITY               NaN
# 1171074                  NaN            Berlin                NJ
# 1171075                  NaN  HO CHI MINH CITY               NaN
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 1171072          08009-7116                 NaN               08/14/2020
# 1171073          70000-7400                  VN               09/08/2020
# 1171074          08009-7116                 NaN               09/09/2020
# 1171075          70000-7400                  VN               09/19/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 1171072                08/31/2020           Accepted               NaN
# 1171073                09/08/2020           Accepted               NaN
# 1171074                09/09/2020           Accepted               NaN
# 1171075                09/19/2020           Accepted        09/19/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 1171072                 NaN                NaN           NaN           NaN
# 1171073                 NaN                NaN           NaN           NaN
# 1171074                 NaN                NaN           NaN           NaN
# 1171075          11/01/2020         11/19/2020      Accepted          Mail
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 1171072                NaN                32             Mason Dr
# 1171073                NaN                32             Mason Dr
# 1171074                NaN                32             Mason Dr
# 1171075                NaN                32             Mason Dr
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 1171072            32 Mason Dr                    NaN                     NaN
# 1171073            32 Mason Dr                    NaN                     NaN
# 1171074            32 Mason Dr                    NaN                     NaN
# 1171075            32 Mason Dr                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 1171072             Berlin                  NJ            08009-7116
# 1171073             Berlin                  NJ            08009-7116
# 1171074             Berlin                  NJ            08009-7116
# 1171075             Berlin                  NJ            08009-7116
#
#         voter_phone                 voter_email received_bearer
# 1171072         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171073         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171074         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN
# 1171075         NaN  SUSANLEESCOTTNYC@GMAIL.COM             NaN

# %%
dup_5 = raw_df.loc[raw_df['voter_id'] == 'P3101208027']
dup_5

#Same as before -- some inconsistencies across duplicates but keep the bottom row
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4692407          Ocean    Lakehurst Borough            0               1.0
# 4692408          Ocean    Lakehurst Borough            0               1.0
# 4692409          Ocean    Lakehurst Borough            0               1.0
# 4692410          Ocean    Lakehurst Borough            0               1.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4692407           Single Election  P3101208027          NAGLE          SPRING
# 4692408  Annual Mail-In Elections  P3101208027          NAGLE          SPRING
# 4692409           Single Election  P3101208027          NAGLE          SPRING
# 4692410  Annual Mail-In Elections  P3101208027          NAGLE          SPRING
#
#         voter_middleName voter_suffix voter_party voter_status  \
# 4692407                A          NaN  Republican       Active
# 4692408                A          NaN  Republican       Active
# 4692409                A          NaN  Republican       Active
# 4692410                A          NaN  Republican       Active
#
#                              ballot_type ballot_county ballot_municipality  \
# 4692407                          Regular         Ocean   Lakehurst Borough
# 4692408  Presidential / Removed Resident         Ocean   Lakehurst Borough
# 4692409                          Regular         Ocean   Lakehurst Borough
# 4692410  Presidential / Removed Resident         Ocean   Lakehurst Borough
#
#         ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 4692407           0                1       Republican        121 BROWN AVE
# 4692408           0                1       Republican        121 BROWN AVE
# 4692409           0                1       Republican        P.O. BOX 1104
# 4692410           0                1       Republican        P.O. BOX 1104
#
#         ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 4692407                  NaN                  NaN        LAKEHURST
# 4692408                  NaN                  NaN        LAKEHURST
# 4692409                  NaN                  NaN            BRICK
# 4692410                  NaN                  NaN            BRICK
#
#         ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 4692407                NJ          08733-3032                  US
# 4692408                NJ          08733-3032                  US
# 4692409                NJ               08723                  US
# 4692410                NJ               08723                  US
#
#         application_receivedDate application_processedDate application_status  \
# 4692407               08/14/2020                08/31/2020           Accepted
# 4692408               09/02/2020                09/02/2020           Accepted
# 4692409               09/04/2020                09/04/2020           Accepted
# 4692410               09/11/2020                09/11/2020           Accepted
#
#         ballot_mailedDate ballot_receivedDate ballot_countedDate  \
# 4692407               NaN                 NaN                NaN
# 4692408               NaN                 NaN                NaN
# 4692409               NaN                 NaN                NaN
# 4692410        09/19/2020          10/05/2020                NaN
#
#         ballot_status received_type received_rejReason voter_resAddr_num  \
# 4692407           NaN           NaN                NaN               121
# 4692408           NaN           NaN                NaN               121
# 4692409           NaN           NaN                NaN               121
# 4692410      Received          Mail                NaN               121
#
#         voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 4692407            BROWN AVE          121 BROWN AVE                    NaN
# 4692408            BROWN AVE          121 BROWN AVE                    NaN
# 4692409            BROWN AVE          121 BROWN AVE                    NaN
# 4692410            BROWN AVE          121 BROWN AVE                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 4692407                     NaN          LAKEHURST                  NJ
# 4692408                     NaN          LAKEHURST                  NJ
# 4692409                     NaN          LAKEHURST                  NJ
# 4692410                     NaN          LAKEHURST                  NJ
#
#         voter_resAddr_zipcode voter_phone voter_email received_bearer
# 4692407            08733-3032         NaN         NaN             NaN
# 4692408            08733-3032         NaN         NaN             NaN
# 4692409            08733-3032         NaN         NaN             NaN
# 4692410            08733-3032         NaN         NaN             NaN

# %%
#testing drop_duplicates to make sure it keps the right row

top_dup_no_dups = top_dup.drop_duplicates(subset=['voter_id'], keep='last')
top_dup_no_dups
# Out:
#         current_county current_municipality current_ward  current_district  \
# 4975838        Passaic         Clifton City            2               8.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 4975838    Single Election  E1576352907     BASHJAWISH            FUAD
#
#         voter_middleName voter_suffix voter_party voter_status ballot_type  \
# 4975838                A          NaN  Republican       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 4975838       Passaic        Clifton City           2                8
#
#         ballot_vtr_party  ballot_addr_address1 ballot_addr_address2  \
# 4975838       Republican  117 MOUNTAINSIDE TER                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 4975838                  NaN          CLIFTON                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 4975838          07013-1178                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 4975838                08/31/2020           Accepted        10/06/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 4975838                 NaN                NaN           NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 4975838                NaN               117     MOUNTAINSIDE TER
#
#         voter_resAddr_address1 voter_resAddr_address2  voter_resAddr_address3  \
# 4975838   117 MOUNTAINSIDE TER                    NaN                     NaN
#
#         voter_resAddr_city voter_resAddr_state voter_resAddr_zipcode  \
# 4975838            CLIFTON                  NJ            07013-1178
#
#         voter_phone voter_email received_bearer
# 4975838  9732472453         NaN             NaN

# %%
#That worked. Let's apply this to the full dataset now 


df = raw_df.drop_duplicates(subset=['voter_id'], keep='last')

# %%
df
# Out:
#         current_county current_municipality current_ward  current_district  \
# 0             Atlantic         Absecon City            1               1.0
# 1             Atlantic         Absecon City            1               1.0
# 2             Atlantic         Absecon City            1               1.0
# 3             Atlantic         Absecon City            1               1.0
# 4             Atlantic         Absecon City            1               1.0
# ...                ...                  ...          ...               ...
# 6044852         Warren       White Township            0               6.0
# 6044853         Warren       White Township            0               6.0
# 6044854         Warren       White Township            0               6.0
# 6044855         Warren       White Township            0               6.0
# 6044856         Warren       White Township            0               6.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 0                 Single Election  P2763351335     LINGELBACH         CAROLYN
# 1        Annual Mail-In Elections  P3919851339          TIMMS           BRIAN
# 2                 Single Election  P6095651352      CUSHLANIS           ROBIN
# 3                 Single Election  A1425851358       DILLHOFF           KEVIN
# 4                 Single Election  A1783751359          JETER            PAUL
# ...                           ...          ...            ...             ...
# 6044852           Single Election  L1061243339         COWLEY           JARED
# 6044853           Single Election  C2754450078     WELENOFSKY            LISA
# 6044854           Single Election  H4507252594       MCGINLEY          MEGHAN
# 6044855           Single Election  N4444001342         CARMEN             KOI
# 6044856           Single Election  P2819114049         ALESSI       KATHERINE
#
#         voter_middleName voter_suffix   voter_party voter_status  \
# 0                      R          NaN  Unaffiliated       Active
# 1                      D          NaN    Democratic       Active
# 2                      A          NaN    Republican       Active
# 3                      T          NaN    Democratic       Active
# 4                      D          NaN    Democratic       Active
# ...                  ...          ...           ...          ...
# 6044852            DUANE          Jr.    Democratic       Active
# 6044853             JEAN          NaN  Unaffiliated       Active
# 6044854              NaN          NaN  Unaffiliated       Active
# 6044855              LEA          NaN  Unaffiliated       Active
# 6044856             ROSE          NaN  Unaffiliated       Active
#
#                              ballot_type ballot_county ballot_municipality  \
# 0                                Regular      Atlantic        Absecon City
# 1        Presidential / Removed Resident      Atlantic        Absecon City
# 2                                Regular      Atlantic        Absecon City
# 3                                Regular      Atlantic        Absecon City
# 4                                Regular      Atlantic        Absecon City
# ...                                  ...           ...                 ...
# 6044852                          Regular        Warren      White Township
# 6044853                          Regular        Warren      White Township
# 6044854                          Regular        Warren      White Township
# 6044855                          Regular        Warren      White Township
# 6044856                          Regular        Warren      White Township
#
#         ballot_ward  ballot_district ballot_vtr_party  \
# 0                 1                1     Unaffiliated
# 1                 1                1       Democratic
# 2                 1                1       Republican
# 3                 1                1       Democratic
# 4                 1                1       Democratic
# ...             ...              ...              ...
# 6044852           0                6       Democratic
# 6044853           0                6     Unaffiliated
# 6044854           0                6     Unaffiliated
# 6044855           0                6     Unaffiliated
# 6044856           0                6     Unaffiliated
#
#             ballot_addr_address1 ballot_addr_address2 ballot_addr_address3  \
# 0        122 E Faunce Landing Rd                  NaN                  NaN
# 1                    506 Lazy Ln                  NaN                  NaN
# 2                 645 Weilers Ln                  NaN                  NaN
# 3                     635 4th St                  NaN                  NaN
# 4                    511 LAZY LN                  NaN                  NaN
# ...                          ...                  ...                  ...
# 6044852           96 BUCKHORN DR                  NaN                  NaN
# 6044853              25 COLBY CT                  NaN                  NaN
# 6044854              23 COLBY CT                  NaN                  NaN
# 6044855      835 BRASS CASTLE RD                  NaN                  NaN
# 6044856              15 COLBY CT                  NaN                  NaN
#
#         ballot_addr_city ballot_addr_state ballot_addr_zipcode  \
# 0                Absecon                NJ          08201-1808
# 1                Absecon                NJ          08201-1337
# 2                Absecon                NJ          08201-1326
# 3                Absecon                NJ          08201-1304
# 4                ABSECON                NJ          08201-1338
# ...                  ...               ...                 ...
# 6044852       WASHINGTON                NJ          07882-3805
# 6044853        BELVIDERE                NJ          07823-2755
# 6044854        BELVIDERE                NJ          07823-2755
# 6044855        BELVIDERE                NJ          07823-2724
# 6044856        BELVIDERE                NJ          07823-2754
#
#         ballot_addr_country application_receivedDate  \
# 0                       NaN               08/14/2020
# 1                        US               08/26/2020
# 2                       NaN               08/14/2020
# 3                       NaN               08/14/2020
# 4                        US               08/14/2020
# ...                     ...                      ...
# 6044852                  US               08/14/2020
# 6044853                  US               08/14/2020
# 6044854                  US               08/14/2020
# 6044855                  US               08/14/2020
# 6044856                  US               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 0                      08/31/2020           Accepted        09/21/2020
# 1                      08/26/2020           Accepted        09/21/2020
# 2                      08/31/2020           Accepted        09/21/2020
# 3                      08/31/2020           Accepted        09/21/2020
# 4                      08/31/2020           Accepted        09/21/2020
# ...                           ...                ...               ...
# 6044852                10/19/2020           Accepted        10/21/2020
# 6044853                10/19/2020           Accepted        10/21/2020
# 6044854                10/19/2020           Accepted        10/21/2020
# 6044855                10/19/2020           Accepted        10/21/2020
# 6044856                10/19/2020           Accepted        10/21/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 0                10/23/2020         11/20/2020      Accepted      Drop Box
# 1                10/21/2020         11/20/2020      Accepted      Drop Box
# 2                10/18/2020         11/20/2020      Accepted      Drop Box
# 3                       NaN         11/20/2020      Accepted      Drop Box
# 4                       NaN         11/20/2020      Accepted      Drop Box
# ...                     ...                ...           ...           ...
# 6044852          11/03/2020         11/23/2020      Accepted     In Person
# 6044853          10/28/2020         11/23/2020      Accepted      Drop Box
# 6044854          10/27/2020         11/23/2020      Accepted      Drop Box
# 6044855          11/04/2020         11/23/2020      Accepted     In Person
# 6044856                 NaN                NaN           NaN           NaN
#
#         received_rejReason voter_resAddr_num voter_resAddr_street  \
# 0                      NaN               122  E Faunce Landing Rd
# 1                      NaN               506              Lazy Ln
# 2                      NaN               645           Weilers Ln
# 3                      NaN               635               4th St
# 4                      NaN               511              LAZY LN
# ...                    ...               ...                  ...
# 6044852                NaN                96          BUCKHORN DR
# 6044853                NaN                25             COLBY CT
# 6044854                NaN                23             COLBY CT
# 6044855                NaN               835      BRASS CASTLE RD
# 6044856                NaN                15             COLBY CT
#
#           voter_resAddr_address1 voter_resAddr_address2  \
# 0        122 E Faunce Landing Rd                    NaN
# 1                    506 Lazy Ln                    NaN
# 2                 645 Weilers Ln                    NaN
# 3                     635 4th St                    NaN
# 4                    511 LAZY LN                    NaN
# ...                          ...                    ...
# 6044852           96 BUCKHORN DR                    NaN
# 6044853              25 COLBY CT                    NaN
# 6044854              23 COLBY CT                    NaN
# 6044855      835 BRASS CASTLE RD                    NaN
# 6044856              15 COLBY CT                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 0                           NaN            Absecon                  NJ
# 1                           NaN            Absecon                  NJ
# 2                           NaN            Absecon                  NJ
# 3                           NaN            Absecon                  NJ
# 4                           NaN            ABSECON                  NJ
# ...                         ...                ...                 ...
# 6044852                     NaN         WASHINGTON                  NJ
# 6044853                     NaN          BELVIDERE                  NJ
# 6044854                     NaN          BELVIDERE                  NJ
# 6044855                     NaN          BELVIDERE                  NJ
# 6044856                     NaN          BELVIDERE                  NJ
#
#         voter_resAddr_zipcode voter_phone              voter_email  \
# 0                  08201-1808         NaN                      NaN
# 1                  08201-1337  8609447558   BIBLIOMANE74@GMAIL.COM
# 2                  08201-1326  6093284677                      NaN
# 3                  08201-1304         NaN  KEVINDILLHOFF@GMAIL.COM
# 4                  08201-1338         NaN                      NaN
# ...                       ...         ...                      ...
# 6044852            07882-3805         NaN                      NaN
# 6044853            07823-2755         NaN                      NaN
# 6044854            07823-2755         NaN                      NaN
# 6044855            07823-2724         NaN                      NaN
# 6044856            07823-2754         NaN                      NaN
#
#         received_bearer
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 6044852             NaN
# 6044853             NaN
# 6044854             NaN
# 6044855             NaN
# 6044856             NaN
#
# [6028484 rows x 45 columns]

# %%
#Amount of duplicate records removed:

6044857 - 6028484
# Out:
# 16373

# %%
# Now let's look at the (hopefully more accurate) numbers we calculated earlier:

df['received_rejReason'].count()
# Out:
# 50687

# %%
# Number of rejected ballots only changed by ten. 
# This tracks with what we saw above:
#    most duplicate rows appeared not to be associated with a sent/returned ballot

# %%
#rejected ballots by reason for rejection

df['received_rejReason'].value_counts()
# Out:
# Signature Does Not Match          16820
# Certificate Missing               11760
# Certificate Not Signed             8874
# Other                              7039
# Ballot Received After Deadline     2006
# Ballot Not Enclosed                1589
# Voter Registration ID Missing       953
# Bearer Exceeded Limit               910
# Incomplete Bearer Portion           403
# Moved Out of County                 198
# Power of Attorney                    60
# Incomplete Assistor Portion          54
# Ineligible Voter Status               6
# Both Envelopes Unsealed               5
# Bearer Book Not Signed In             3
# Primary-Voted Both Parties            3
# Candidate Provided Assistance         2
# One Envelope Unsealed                 2
# Name: received_rejReason, dtype: int64

# %%
# NA's in Rejection reason *should* represent accepted ballots AND people who did not vote

df['received_rejReason'].isna().sum()
# Out:
# 5977797

# %%
df['ballot_status'].value_counts()
# Out:
# Accepted    3982740
# Received     335064
# Rejected      50532
# Name: ballot_status, dtype: int64

# %%
# Something isn't right here. Why are we getting more results for *reasons* the ballot was rejected...
# than the number of ballots actually *listed* as rejected??

# Maybe some ballots have two rejection reasons? But if that were the case, shouldn't we still have only wound up
# with of them when we eliminated duplicate rows?

# Maybe some ballots that were initially rejected were later "cured" by the voter...
# and therefore status = accepted, even though rejection reason is still there?
# No way to test this specific hypothesis since there's no direct info on cured ballots in dataset.

# Less specific version: some ballots likely have a rejection reason...
# but are still listed as "received" or even "accepted."

# %%
# Let's test out that last idea.

# First, filter the df to only include ballots with a rejection reason.

test_df = df.dropna(subset=['received_rejReason'])
test_df
# Out:
#         current_county current_municipality current_ward  current_district  \
# 105           Atlantic         Absecon City            1               1.0
# 345           Atlantic         Absecon City            1               1.0
# 379           Atlantic         Absecon City            1               1.0
# 477           Atlantic    Galloway Township            0               8.0
# 568           Atlantic         Absecon City            1               1.0
# ...                ...                  ...          ...               ...
# 6044452         Warren       White Township            0               6.0
# 6044566         Warren       White Township            0               6.0
# 6044581         Warren       White Township            0               6.0
# 6044773         Warren       White Township            0               6.0
# 6044782         Warren       White Township            0               6.0
#
#         ballot_requestType     voter_id voter_lastName voter_firstName  \
# 105        Single Election  D2726451787          FROMM           DIANA
# 345        Single Election  E2481651808         MORGAN           JAMES
# 379        Single Election  E3249551811    MAISANO-MAY           JAMIE
# 477        Single Election  F0365451823       GUENTHER         CHARLES
# 568        Single Election  B0672452839      MACKENZIE         STEPHEN
# ...                    ...          ...            ...             ...
# 6044452    Single Election  A6060952460          LUCAS        LEOKADIA
# 6044566    Single Election  B1654652468           SHAH        RAJSHREE
# 6044581    Single Election  B1874552469        MARIANI           DAVID
# 6044773    Single Election  L1350653819       BAROFSKI         MADISON
# 6044782    Single Election  N3190953869        OKEEFFE            PAUL
#
#         voter_middleName voter_suffix   voter_party voter_status ballot_type  \
# 105                    D          NaN    Republican       Active     Regular
# 345                    A          NaN    Republican       Active     Regular
# 379                    L          NaN   Libertarian       Active     Regular
# 477               JOSEPH          Jr.  Unaffiliated       Active     Regular
# 568                    E          NaN  Unaffiliated       Active     Regular
# ...                  ...          ...           ...          ...         ...
# 6044452              NaN          NaN    Republican       Active     Regular
# 6044566                S          NaN    Democratic       Active     Regular
# 6044581                M          NaN    Republican       Active     Regular
# 6044773                J          NaN    Republican       Active     Regular
# 6044782                D          NaN    Democratic       Active     Regular
#
#         ballot_county ballot_municipality ballot_ward  ballot_district  \
# 105          Atlantic        Absecon City           1                1
# 345          Atlantic        Absecon City           1                1
# 379          Atlantic        Absecon City           1                1
# 477          Atlantic        Absecon City           1                1
# 568          Atlantic        Absecon City           1                1
# ...               ...                 ...         ...              ...
# 6044452        Warren      White Township           0                6
# 6044566        Warren      White Township           0                6
# 6044581        Warren      White Township           0                6
# 6044773        Warren      White Township           0                6
# 6044782        Warren      White Township           0                6
#
#         ballot_vtr_party ballot_addr_address1 ballot_addr_address2  \
# 105           Democratic       533 N Shore Rd                  NaN
# 345           Republican          45 Shady Ln                  NaN
# 379          Libertarian        312 Spruce St                  NaN
# 477           Republican       640 Weilers Ln                  NaN
# 568         Unaffiliated    243 E Wyoming Ave                  NaN
# ...                  ...                  ...                  ...
# 6044452       Republican    86 Summerfield Rd                  NaN
# 6044566       Democratic          44 Colby Ct                  NaN
# 6044581     Unaffiliated       60 Castners Rd                  NaN
# 6044773       Republican         63 Spring Ln                  NaN
# 6044782       Democratic          12 Colby Ct                  NaN
#
#         ballot_addr_address3 ballot_addr_city ballot_addr_state  \
# 105                      NaN          Absecon                NJ
# 345                      NaN          Absecon                NJ
# 379                      NaN          Absecon                NJ
# 477                      NaN          Absecon                NJ
# 568                      NaN          Absecon                NJ
# ...                      ...              ...               ...
# 6044452                  NaN        Belvidere                NJ
# 6044566                  NaN        Belvidere                NJ
# 6044581                  NaN        Belvidere                NJ
# 6044773                  NaN       Washington                NJ
# 6044782                  NaN        Belvidere                NJ
#
#         ballot_addr_zipcode ballot_addr_country application_receivedDate  \
# 105              08201-1821                 NaN               08/14/2020
# 345              08201-1723                 NaN               08/14/2020
# 379              08201-1726                 NaN               08/14/2020
# 477              08201-1327                 NaN               08/14/2020
# 568              08201-1709                 NaN               08/14/2020
# ...                     ...                 ...                      ...
# 6044452          07823-2713                 NaN               08/14/2020
# 6044566          07823-2756                 NaN               08/14/2020
# 6044581          07823-2802                 NaN               08/14/2020
# 6044773          07882-3800                 NaN               08/14/2020
# 6044782          07823-2754                 NaN               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 105                    08/31/2020           Accepted        09/21/2020
# 345                    08/31/2020           Accepted        09/21/2020
# 379                    08/31/2020           Accepted        09/21/2020
# 477                    08/31/2020           Accepted        09/21/2020
# 568                    08/31/2020           Accepted        09/21/2020
# ...                           ...                ...               ...
# 6044452                08/31/2020           Accepted        09/28/2020
# 6044566                08/31/2020           Accepted        09/28/2020
# 6044581                08/31/2020           Accepted        09/28/2020
# 6044773                08/31/2020           Accepted        09/28/2020
# 6044782                08/31/2020           Accepted        09/28/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 105                     NaN         2020-11-19      Rejected      Drop Box
# 345              11/12/2020         2020-11-12      Rejected          Mail
# 379              11/12/2020         2020-11-12      Rejected          Mail
# 477              10/27/2020         2020-11-19      Rejected      Drop Box
# 568              10/28/2020         2020-11-19      Rejected      Drop Box
# ...                     ...                ...           ...           ...
# 6044452          10/17/2020         2020-11-19      Rejected     In Person
# 6044566          10/07/2020         2020-11-19      Rejected          Mail
# 6044581          11/05/2020         2020-11-19      Rejected      Drop Box
# 6044773          10/12/2020         2020-11-23      Rejected      Drop Box
# 6044782          10/20/2020         2020-11-23      Rejected          Mail
#
#                      received_rejReason voter_resAddr_num  \
# 105            Signature Does Not Match               533
# 345      Ballot Received After Deadline                45
# 379      Ballot Received After Deadline               312
# 477            Signature Does Not Match               718
# 568            Signature Does Not Match               243
# ...                                 ...               ...
# 6044452          Certificate Not Signed                86
# 6044566             Certificate Missing                44
# 6044581             Certificate Missing                60
# 6044773        Signature Does Not Match                63
# 6044782        Signature Does Not Match                12
#
#         voter_resAddr_street voter_resAddr_address1 voter_resAddr_address2  \
# 105               N Shore Rd         533 N Shore Rd                    NaN
# 345                 Shady Ln            45 Shady Ln                    NaN
# 379                Spruce St          312 Spruce St                    NaN
# 477             RAVENWOOD DR       718 RAVENWOOD DR                    NaN
# 568            E Wyoming Ave      243 E Wyoming Ave                    NaN
# ...                      ...                    ...                    ...
# 6044452       Summerfield Rd      86 Summerfield Rd                    NaN
# 6044566             Colby Ct            44 Colby Ct                    NaN
# 6044581          Castners Rd         60 Castners Rd                    NaN
# 6044773            Spring Ln           63 Spring Ln                    NaN
# 6044782             Colby Ct            12 Colby Ct                    NaN
#
#          voter_resAddr_address3 voter_resAddr_city voter_resAddr_state  \
# 105                         NaN            Absecon                  NJ
# 345                         NaN            Absecon                  NJ
# 379                         NaN            Absecon                  NJ
# 477                         NaN           GALLOWAY                  NJ
# 568                         NaN            Absecon                  NJ
# ...                         ...                ...                 ...
# 6044452                     NaN          Belvidere                  NJ
# 6044566                     NaN          Belvidere                  NJ
# 6044581                     NaN          Belvidere                  NJ
# 6044773                     NaN         Washington                  NJ
# 6044782                     NaN          Belvidere                  NJ
#
#         voter_resAddr_zipcode voter_phone voter_email received_bearer
# 105                08201-1821         NaN         NaN             NaN
# 345                08201-1723         NaN         NaN             NaN
# 379                08201-1726         NaN         NaN             NaN
# 477                08205-3116  6096468812         NaN             NaN
# 568                08201-1709  6096464232         NaN             NaN
# ...                       ...         ...         ...             ...
# 6044452            07823-2713         NaN         NaN             NaN
# 6044566            07823-2756         NaN         NaN             NaN
# 6044581            07823-2802         908         NaN             NaN
# 6044773            07882-3800         NaN         NaN             NaN
# 6044782            07823-2754         NaN         NaN             NaN
#
# [50687 rows x 45 columns]

# %%
# Next, does status = "accepted"?
# is_accepted is a boolean variable with True or False in it
is_accepted =  test_df['ballot_status']=='Accepted'
print(is_accepted.head())
# Out:
# 105    False
# 345    False
# 379    False
# 477    False
# 568    False
# Name: ballot_status, dtype: bool

# %%
# now, filter the df to include only ballots with a rejection reason but still listed as accepted

rejected_accepted = test_df[is_accepted]
print(rejected_accepted.shape)
# Out:
# (155, 45)

# %%
# looks like there are 155 instances where there's a rejection reason but still accepted
rejected_accepted
# Out:
#         current_county  current_municipality current_ward  current_district  \
# 1149010         Camden       Audubon Borough            0               3.0
# 1157612         Camden    Barrington Borough            0               3.0
# 1158316         Camden    Barrington Borough            0               4.0
# 1184123         Camden           Camden City            1               6.0
# 1235489         Camden  Cherry Hill Township            0              15.0
# ...                ...                   ...          ...               ...
# 5590310         Sussex       Sparta Township            0               8.0
# 5670712          Union        Elizabeth City            1               2.0
# 5670849          Union        Elizabeth City            1               2.0
# 5856296          Union  Roselle Park Borough            4               2.0
# 5933557          Union        Union Township            0              37.0
#
#                ballot_requestType     voter_id voter_lastName voter_firstName  \
# 1149010  Annual Mail-In Elections  A4936552084      MARTORANO         THERESA
# 1157612           Single Election  B6363753982        GABRIEL          LAUREN
# 1158316           Single Election  B1113352093         HOWARD         RICHARD
# 1184123           Single Election  J1612453773        MORALES          CARLOS
# 1235489           Single Election  F5090236288         MIZELL          GEORGE
# ...                           ...          ...            ...             ...
# 5590310           Single Election  D6205054025       MCNAMARA            GLEN
# 5670712           Single Election  I0711753748          ROJAS           JESUS
# 5670849  Annual Mail-In Elections  A1905253939          ROJAS           JESUS
# 5856296  Annual Mail-In Elections  B1847352843           VYAS       VRUTTESHA
# 5933557           Single Election  K6445653424           LAGE          LEONEL
#
#         voter_middleName voter_suffix   voter_party voter_status  \
# 1149010                S          NaN    Democratic       Active
# 1157612                A          NaN    Democratic       Active
# 1158316              NaN          NaN    Democratic       Active
# 1184123                J          NaN    Democratic       Active
# 1235489            DAVID          NaN  Unaffiliated       Active
# ...                  ...          ...           ...          ...
# 5590310                P          NaN  Unaffiliated       Active
# 5670712                A          NaN  Unaffiliated       Active
# 5670849                A          NaN  Unaffiliated       Active
# 5856296                M          NaN    Democratic       Active
# 5933557                A          NaN  Unaffiliated       Active
#
#                              ballot_type ballot_county   ballot_municipality  \
# 1149010  Presidential / Removed Resident        Camden       Audubon Borough
# 1157612                          Regular        Camden    Barrington Borough
# 1158316                          Regular        Camden    Barrington Borough
# 1184123                          Regular        Camden           Camden City
# 1235489                          Regular        Camden  Cherry Hill Township
# ...                                  ...           ...                   ...
# 5590310                          Regular        Sussex       Sparta Township
# 5670712                          Regular         Union        Elizabeth City
# 5670849  Presidential / Removed Resident         Union        Elizabeth City
# 5856296  Presidential / Removed Resident         Union  Roselle Park Borough
# 5933557                          Regular         Union        Union Township
#
#         ballot_ward  ballot_district ballot_vtr_party ballot_addr_address1  \
# 1149010           0                3       Democratic    540 W MERCHANT ST
# 1157612           0                3       Democratic          18 Page Ave
# 1158316           0                4       Democratic       4404 Reamer Dr
# 1184123           1                6       Democratic    1132 W AMERICA RD
# 1235489           0               15     Unaffiliated       1 SILVERTOP LN
# ...             ...              ...              ...                  ...
# 5590310           0                8     Unaffiliated       30 S Shore Trl
# 5670712           1                2     Unaffiliated         112 Broadway
# 5670849           1                2     Unaffiliated         112 BROADWAY
# 5856296           4                2       Democratic        131 JEROME ST
# 5933557           0               37     Unaffiliated     2065 Emerson Ave
#
#         ballot_addr_address2 ballot_addr_address3 ballot_addr_city  \
# 1149010                  NaN                  NaN          AUDUBON
# 1157612                  NaN                  NaN       Barrington
# 1158316                  NaN                  NaN       Barrington
# 1184123                  NaN                  NaN           CAMDEN
# 1235489                  NaN                  NaN      CHERRY HILL
# ...                      ...                  ...              ...
# 5590310                  NaN                  NaN           Sparta
# 5670712                  NaN                  NaN        Elizabeth
# 5670849                  NaN                  NaN        ELIZABETH
# 5856296                APT K                  NaN     ROSELLE PARK
# 5933557                  # 1                  NaN            Union
#
#         ballot_addr_state ballot_addr_zipcode ballot_addr_country  \
# 1149010                NJ          08106-1910                  US
# 1157612                NJ          08007-1122                 NaN
# 1158316                NJ          08007-1724                 NaN
# 1184123                NJ          08104-2807                  US
# 1235489                NJ          08002-1538                  US
# ...                   ...                 ...                 ...
# 5590310                NJ          07871-1611                 NaN
# 5670712                NJ          07206-1856                 NaN
# 5670849                NJ               07206       UNITED STATES
# 5856296                NJ               07204       UNITED STATES
# 5933557                NJ          07083-3627       UNITED STATES
#
#         application_receivedDate application_processedDate application_status  \
# 1149010               12/22/2019                12/22/2019           Accepted
# 1157612               08/14/2020                08/31/2020           Accepted
# 1158316               08/14/2020                08/31/2020           Accepted
# 1184123               08/14/2020                08/31/2020           Accepted
# 1235489               10/15/2020                10/15/2020           Accepted
# ...                          ...                       ...                ...
# 5590310               08/14/2020                08/31/2020           Accepted
# 5670712               08/14/2020                08/31/2020           Accepted
# 5670849               12/22/2019                12/22/2019           Accepted
# 5856296               12/22/2019                12/22/2019           Accepted
# 5933557               08/14/2020                08/31/2020           Accepted
#
#         ballot_mailedDate ballot_receivedDate ballot_countedDate  \
# 1149010        09/29/2020          10/20/2020         11/20/2020
# 1157612        09/29/2020          10/15/2020         11/20/2020
# 1158316        09/29/2020          10/14/2020         11/20/2020
# 1184123        09/28/2020          10/16/2020         11/20/2020
# 1235489        10/16/2020          10/21/2020         11/20/2020
# ...                   ...                 ...                ...
# 5590310        09/15/2020          11/05/2020         11/23/2020
# 5670712        09/17/2020          10/29/2020         11/20/2020
# 5670849        09/17/2020          10/29/2020         11/20/2020
# 5856296        09/24/2020          10/23/2020         11/03/2020
# 5933557        10/01/2020          10/09/2020         11/20/2020
#
#         ballot_status received_type        received_rejReason  \
# 1149010      Accepted      Drop Box    Certificate Not Signed
# 1157612      Accepted          Mail  Signature Does Not Match
# 1158316      Accepted          Mail    Certificate Not Signed
# 1184123      Accepted      Drop Box    Certificate Not Signed
# 1235489      Accepted      Drop Box  Signature Does Not Match
# ...               ...           ...                       ...
# 5590310      Accepted      Drop Box  Signature Does Not Match
# 5670712      Accepted        Bearer  Signature Does Not Match
# 5670849      Accepted        Bearer  Signature Does Not Match
# 5856296      Accepted      Drop Box     Bearer Exceeded Limit
# 5933557      Accepted          Mail       Certificate Missing
#
#         voter_resAddr_num voter_resAddr_street voter_resAddr_address1  \
# 1149010               540        W MERCHANT ST      540 W MERCHANT ST
# 1157612                18             Page Ave            18 Page Ave
# 1158316              4404            Reamer Dr         4404 Reamer Dr
# 1184123              1132         W AMERICA RD      1132 W AMERICA RD
# 1235489                 1         SILVERTOP LN         1 SILVERTOP LN
# ...                   ...                  ...                    ...
# 5590310                30          S Shore Trl         30 S Shore Trl
# 5670712               112             Broadway           112 Broadway
# 5670849               112             Broadway           112 Broadway
# 5856296               131            JEROME ST          131 JEROME ST
# 5933557              2065          Emerson Ave       2065 Emerson Ave
#
#         voter_resAddr_address2  voter_resAddr_address3 voter_resAddr_city  \
# 1149010                    NaN                     NaN            AUDUBON
# 1157612                    NaN                     NaN         Barrington
# 1158316                    NaN                     NaN         Barrington
# 1184123                    NaN                     NaN             CAMDEN
# 1235489                    NaN                     NaN        CHERRY HILL
# ...                        ...                     ...                ...
# 5590310                    NaN                     NaN             Sparta
# 5670712                    NaN                     NaN          Elizabeth
# 5670849                    NaN                     NaN          Elizabeth
# 5856296                  APT K                     NaN       ROSELLE PARK
# 5933557                    # 1                     NaN              Union
#
#         voter_resAddr_state voter_resAddr_zipcode voter_phone  \
# 1149010                  NJ            08106-1910         NaN
# 1157612                  NJ            08007-1122         NaN
# 1158316                  NJ            08007-1724         NaN
# 1184123                  NJ            08104-2807         NaN
# 1235489                  NJ            08002-1538         NaN
# ...                     ...                   ...         ...
# 5590310                  NJ            07871-1611         NaN
# 5670712                  NJ            07206-1856         NaN
# 5670849                  NJ            07206-1856  9089065852
# 5856296                  NJ            07204-1453  9082450794
# 5933557                  NJ            07083-3627         NaN
#
#                          voter_email received_bearer
# 1149010                          NaN             NaN
# 1157612                          NaN             NaN
# 1158316                          NaN             NaN
# 1184123                          NaN             NaN
# 1235489                          NaN             NaN
# ...                              ...             ...
# 5590310                          NaN             NaN
# 5670712                          NaN    ANDREW ROJAS
# 5670849  JESUS.A.ROJAS1962@GMAIL.COM    ANDREW ROJAS
# 5856296                          NaN             NaN
# 5933557                          NaN             NaN
#
# [155 rows x 45 columns]

# %%
# My best GUESS is that these are "cured" ballots -- ballots that were initially rejected, but...
# the voter was able to resolve whatever the issue was and get their vote counted

# %%
# Now let's check if any ballots have a rejection reason but status = "received" still.

# Does status = "received"?
# is_received is a boolean variable with True or False in it
is_received =  test_df['ballot_status']=='Received'
print(is_received.head())
# Out:
# 105    False
# 345    False
# 379    False
# 477    False
# 568    False
# Name: ballot_status, dtype: bool

# %%
# now, filter the df to include only ballots with a rejection reason but still listed as received

rejected_received = test_df[is_received]
print(rejected_received.shape)
# Out:
# (0, 45)

# %%
# None, thankfully.

# So, while this can't be demonstrated in the dataset itself, it seems likely...
# that the cause of the discrepancy is ballots that were initially rejected, then cured later on.

# %%
#Let's whittle this down to only the cols we want to keep

small_df = df[['voter_id', 'ballot_county', 'ballot_vtr_party', 'ballot_receivedDate', 'ballot_status', 'received_rejReason']]

# %%
small_df
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6044852  L1061243339        Warren       Democratic          11/03/2020
# 6044853  C2754450078        Warren     Unaffiliated          10/28/2020
# 6044854  H4507252594        Warren     Unaffiliated          10/27/2020
# 6044855  N4444001342        Warren     Unaffiliated          11/04/2020
# 6044856  P2819114049        Warren     Unaffiliated                 NaN
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6044852      Accepted                NaN
# 6044853      Accepted                NaN
# 6044854      Accepted                NaN
# 6044855      Accepted                NaN
# 6044856           NaN                NaN
#
# [6028484 rows x 6 columns]

# %%
# Wait -- why do we seem to have some ballots that were accepted but have no received date?

# Lets's filter our df to only rows that have a ballot status, and check how many have no received date.

test_df2 = small_df.dropna(subset=['ballot_status'])
test_df2
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6044851  B6174726327        Warren     Unaffiliated          11/04/2020
# 6044852  L1061243339        Warren       Democratic          11/03/2020
# 6044853  C2754450078        Warren     Unaffiliated          10/28/2020
# 6044854  H4507252594        Warren     Unaffiliated          10/27/2020
# 6044855  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6044851      Accepted                NaN
# 6044852      Accepted                NaN
# 6044853      Accepted                NaN
# 6044854      Accepted                NaN
# 6044855      Accepted                NaN
#
# [4368336 rows x 6 columns]

# %%
# Now check how many rows have no received date:

test_df2['ballot_receivedDate'].isna().sum()
# Out:
# 123446

# %%
# that's... a lot.

# Let's do it in the opposite order now. How many have received date but no ballot status?

test_df3 = small_df.dropna(subset=['ballot_receivedDate'])
test_df3
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 5        A4660351369      Atlantic     Unaffiliated          10/21/2020
# 6        K0876551578      Atlantic     Unaffiliated          10/28/2020
# ...              ...           ...              ...                 ...
# 6044851  B6174726327        Warren     Unaffiliated          11/04/2020
# 6044852  L1061243339        Warren       Democratic          11/03/2020
# 6044853  C2754450078        Warren     Unaffiliated          10/28/2020
# 6044854  H4507252594        Warren     Unaffiliated          10/27/2020
# 6044855  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 5            Accepted                NaN
# 6            Accepted                NaN
# ...               ...                ...
# 6044851      Accepted                NaN
# 6044852      Accepted                NaN
# 6044853      Accepted                NaN
# 6044854      Accepted                NaN
# 6044855      Accepted                NaN
#
# [4244891 rows x 6 columns]

# %%
test_df3['ballot_status'].isna().sum()
# Out:
# 1

# %%
# that, thankfully, is much much smaller.

# not sure why so many seemingly-returned ballots have no received date...
# but that's beyond the scope of our project right now.

# %%
# Let's finally fliter this down to only people who at least attempted to return their ballots.
# It seems like the best assumption we can make to do this is that NA's in ballot status = didn't vote.

# %%
clean_VBM = small_df.dropna(subset=['ballot_status'])
clean_VBM
# Out:
#             voter_id ballot_county ballot_vtr_party ballot_receivedDate  \
# 0        P2763351335      Atlantic     Unaffiliated          10/23/2020
# 1        P3919851339      Atlantic       Democratic          10/21/2020
# 2        P6095651352      Atlantic       Republican          10/18/2020
# 3        A1425851358      Atlantic       Democratic                 NaN
# 4        A1783751359      Atlantic       Democratic                 NaN
# ...              ...           ...              ...                 ...
# 6044851  B6174726327        Warren     Unaffiliated          11/04/2020
# 6044852  L1061243339        Warren       Democratic          11/03/2020
# 6044853  C2754450078        Warren     Unaffiliated          10/28/2020
# 6044854  H4507252594        Warren     Unaffiliated          10/27/2020
# 6044855  N4444001342        Warren     Unaffiliated          11/04/2020
#
#         ballot_status received_rejReason
# 0            Accepted                NaN
# 1            Accepted                NaN
# 2            Accepted                NaN
# 3            Accepted                NaN
# 4            Accepted                NaN
# ...               ...                ...
# 6044851      Accepted                NaN
# 6044852      Accepted                NaN
# 6044853      Accepted                NaN
# 6044854      Accepted                NaN
# 6044855      Accepted                NaN
#
# [4368336 rows x 6 columns]

# %%
# 1. Of all ballots cast, how many were Republican ballots?

# 2. Of the ballots that were rejected, how many belonged to Republicans?

# 3. number of rejected ballots that were cast by Republicans / Total # of Republican Ballots (regardless of whether they were rejected or not)
#    number of rejected ballots in a specific county (Atlantic county) / Total # of Republican ballots cast in the same county

    

# In other words: of all Republicans who cast ballots, how many had their ballots rejected?

republican_ballots_bool =  clean_VBM['ballot_vtr_party']=='Republican'
republican_df = clean_VBM[republican_ballots_bool]
republican_df

republican_rejected_bool = republican_df['ballot_status']=='Rejected'
republican_rejected_df = republican_df[republican_rejected_bool]
republican_rejected_df.shape

republican_ballots_num = republican_df['ballot_status'].count()
republican_rejected_num = republican_rejected_df['ballot_status'].count()
republican_rejected_num

per_rep_rej = (republican_ballots_num / republican_rejected_num)
# Out:
# 10178

# %%
#... suggesting 4,370,478 people at least tried to vote (regardless of whether ballot was rejected)

# %%
# Let's write this to csv

clean_VBM.to_csv('clean_VBM.csv', index=False)

# %%
# sanity check: ballot county and ballot status size should now be =

clean_VBM['ballot_county'].count()

# %%
clean_VBM['ballot_status'].count()

# %%
# Now let's create another dataframe grouped by county

grouped_VBM = clean_VBM.groupby(['ballot_county'])

# %%
votes_cast = grouped_VBM.size()
votes_cast

# %%
# check ballot status by county

grouped_received = grouped_VBM['ballot_status'].value_counts()
print(grouped_received)

# %%
# So, it looks like no ballots have been listed as "Accepted" in Ocean County.

# Remains to be seen if "rejected" numbers increase if/when that changes

# %%
# note : these numbers do not all match with official turnout results.
#  (example: Warren county)

# Not much that can be done about that at this point until...
#  we hear back from KnowInk about our assumptions while cleaning.

# %%
# Let's go ahead and calculate rejected ballots by county.

# %%
number_rejected = grouped_VBM['ballot_status'].apply(lambda x: x.str.contains('Rejected').sum())
number_rejected

# %%
county_df = pd.concat([votes_cast, number_rejected], axis = 'columns', sort=False)

# %%
county_df

# %%
county_df.rename(columns={0:'ballots_cast', 'ballot_status':'ballots_rejected'}, inplace=True)

# %%
county_df

# %%
county_df['percent_rejected'] = (county_df['ballots_rejected']/county_df['ballots_cast']) * 100

# %%
county_df.reset_index(level=0, inplace=True)
county_df.rename(columns = {'ballot_county':'County'}, inplace=True)
county_df

# %%
county_df['ballots_rejected'].sum()

# %%
county_df.to_csv('county_df.csv')
