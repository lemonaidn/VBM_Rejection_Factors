# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan'

# %%
cd
# Out:
# C:\Users\Aidan

# %%
cd C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Ariel
# Out:
# C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Ariel

# %%
demo_df = pd.read_csv('demographic_dataset.csv')

# %%
# demo_df.drop(demo_df.columns[[0]], axis=1, inplace = True)

demo_df
# Out:
#                            County  Percent Hispanic or Latino  Percent White  \
# 0     Atlantic County, New Jersey                        19.4           55.9
# 1       Bergen County, New Jersey                        21.0           55.0
# 2   Burlington County, New Jersey                         8.5           66.4
# 3       Camden County, New Jersey                        17.6           55.6
# 4     Cape May County, New Jersey                         8.1           85.0
# 5   Cumberland County, New Jersey                        31.8           45.4
# 6        Essex County, New Jersey                        23.8           29.8
# 7   Gloucester County, New Jersey                         6.7           77.7
# 8       Hudson County, New Jersey                        42.7           28.8
# 9    Hunterdon County, New Jersey                         7.0           84.3
# 10      Mercer County, New Jersey                        18.5           48.2
# ...

# %%
cd C:\\Users\\Aidan\\Documents\\GitHub\\VBM_Rejection_Factors\\Aidan
# Out:
# C:\Users\Aidan\Documents\GitHub\VBM_Rejection_Factors\Aidan

# %%
county_df = pd.read_csv('county_df.csv')

# %%
county_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected
# 0     Atlantic        135532               911          0.672166
# 1       Bergen        476971              5991          1.256051
# 2   Burlington        253356              1911          0.754275
# 3       Camden        246597               705          0.285892
# 4     Cape May         56585               368          0.650349
# 5   Cumberland         60052               761          1.267235
# 6        Essex        307647              2185          0.710230
# 7   Gloucester        171097               100          0.058446
# 8       Hudson        224391              5607          2.498763
# 9    Hunterdon         84278               621          0.736847
# 10      Mercer        170059              1308          0.769145
# 11   Middlesex        356444              6844          1.920077
# 12    Monmouth        377276              5407          1.433168
# ...

# %%
demo_df['County'] = county_df['County']

# %%
merged_df = pd.merge(county_df, demo_df)
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135532               911          0.672166
# 1       Bergen        476971              5991          1.256051
# 2   Burlington        253356              1911          0.754275
# 3       Camden        246597               705          0.285892
# 4     Cape May         56585               368          0.650349
# 5   Cumberland         60052               761          1.267235
# 6        Essex        307647              2185          0.710230
# 7   Gloucester        171097               100          0.058446
# 8       Hudson        224391              5607          2.498763
# 9    Hunterdon         84278               621          0.736847
# 10      Mercer        170059              1308          0.769145
# 11   Middlesex        356444              6844          1.920077
# 12    Monmouth        377276              5407          1.433168
# ...

# %%
merged_df.rename(columns={'%Hs_and_less':'%Hs_and_more'})
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135532               911          0.672166
# 1       Bergen        476971              5991          1.256051
# 2   Burlington        253356              1911          0.754275
# 3       Camden        246597               705          0.285892
# 4     Cape May         56585               368          0.650349
# 5   Cumberland         60052               761          1.267235
# 6        Essex        307647              2185          0.710230
# 7   Gloucester        171097               100          0.058446
# 8       Hudson        224391              5607          2.498763
# 9    Hunterdon         84278               621          0.736847
# 10      Mercer        170059              1308          0.769145
# 11   Middlesex        356444              6844          1.920077
# 12    Monmouth        377276              5407          1.433168
# ...

# %%
merged_df['%HS_and_less'] = (merged_df['Hs_and_less']/merged_df['Population'])*100

# %%
merged_df
# Out:
#         County  ballots_cast  ballots_rejected  percent_rejected  \
# 0     Atlantic        135532               911          0.672166
# 1       Bergen        476971              5991          1.256051
# 2   Burlington        253356              1911          0.754275
# 3       Camden        246597               705          0.285892
# 4     Cape May         56585               368          0.650349
# 5   Cumberland         60052               761          1.267235
# 6        Essex        307647              2185          0.710230
# 7   Gloucester        171097               100          0.058446
# 8       Hudson        224391              5607          2.498763
# 9    Hunterdon         84278               621          0.736847
# 10      Mercer        170059              1308          0.769145
# 11   Middlesex        356444              6844          1.920077
# 12    Monmouth        377276              5407          1.433168
# ...

# %%
merged_df.to_csv('merged_df.csv', index=False)
