# %% [markdown]
# # Exploratory Data Analysis Ballots Data

# %% [markdown]
# # Table of Contents
#
# * [Load Modules](#setup)
# * [Load Data](#loaddata)
# * [Data Cleaning](#datacleaning)
#  * [Remove Columns with Personal Identifying Information](#removepii)
#  * [Duplicate Rows](#duprows)
#  * [Remove Ballots With Status NaN](#ballotsstatusnan)
#  * [Duplicate Voter Id Records](#dupvoterid)
#  * [Final Ballots Dataset](#finaldataset)
#  * [Write Dataset to CSV File](#writecsv)

# %% [markdown]
# <hr>
#
# ## Load Modules<a class="anchor" id="setup"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy.stats import chi2_contingency

mpl.rcParams['font.size'] = 12.0
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# %% [markdown]
# <hr>
#
# ## Load Data<a  class="anchor" id="loaddata"></a>

# %%
ballots_dataset = pd.read_csv('../../../vbm12.13.20.csv')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (2,15,42,44) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# <hr>
#
# ## Data Cleaning<a class="anchor" id="datacleaning"></a>

# %% [markdown]
# ### Remove Columns with Personal Identifying Information<a class="anchor" id="removepii"></a>

# %%
ballots_dataset.drop(columns=['voter_lastName', 'voter_firstName', 'voter_middleName', 'voter_suffix',
'ballot_addr_address1', 'ballot_addr_address2', 'ballot_addr_address3','ballot_addr_zipcode',
'voter_resAddr_address1', 'voter_resAddr_address2','voter_resAddr_address3',
'voter_resAddr_zipcode', 'voter_phone', 'voter_email'], axis=1, inplace=True)

# %% [markdown]
# ### Remove Duplicate Rows<a class="anchor" id="duprows"></a>

# %%
# Remove Duplicate Rows
ballots_dataset.drop_duplicates(inplace=True)

# %% [markdown]
# ### Remove Ballots With Status NaN<a class="anchor" id="ballotsstatusnan"></a>

# %%
ballots_dataset = ballots_dataset[ballots_dataset['ballot_status'].notna()].reset_index(drop=True)

# %%
ballots_dataset.shape
# Out:
# (4368985, 31)

# %% [markdown]
# ### Voter Id Duplicate Records<a class="anchor" id="dupvoterid"></a>

# %%
ballots_dataset[ballots_dataset['voter_id'].duplicated(keep=False)]
# Out:
#         current_county  current_municipality current_ward  current_district  \
# 955199          Camden  Collingswood Borough            0               9.0
# 955200          Camden  Collingswood Borough            0               9.0
# 1027242         Camden    Lindenwold Borough            0               7.0
# 1027243         Camden    Lindenwold Borough            0               7.0
# 4078501          Union        Clark Township            2               4.0
# 4078502          Union        Clark Township            2               4.0
# 4158632          Union           Linden City            6               2.0
# 4158633          Union           Linden City            6               2.0
#
#                ballot_requestType     voter_id   voter_party voter_status  \
# 955199   Annual Mail-In Elections  N5918452380    Democratic       Active
# 955200   Annual Mail-In Elections  N5918452380    Democratic       Active
# 1027242           Single Election  O6429403939  Unaffiliated       Active
# 1027243           Single Election  O6429403939  Unaffiliated       Active
# 4078501           Single Election  B4484851749    Republican       Active
# 4078502           Single Election  B4484851749    Republican       Active
# 4158632           Single Election  A4579251725    Democratic       Active
# 4158633           Single Election  A4579251725    Democratic       Active
#
#                              ballot_type ballot_county   ballot_municipality  \
# 955199   Presidential / Removed Resident        Camden  Collingswood Borough
# 955200   Presidential / Removed Resident        Camden  Collingswood Borough
# 1027242                          Regular        Camden    Lindenwold Borough
# 1027243                          Regular        Camden    Lindenwold Borough
# 4078501                          Regular         Union        Clark Township
# 4078502                          Regular         Union        Clark Township
# 4158632                          Regular         Union           Linden City
# 4158633                          Regular         Union           Linden City
#
#         ballot_ward  ballot_district ballot_vtr_party ballot_addr_city  \
# 955199            0                9       Democratic     COLLINGSWOOD
# 955200            0                9       Democratic     COLLINGSWOOD
# 1027242           0                7     Unaffiliated       LINDENWOLD
# 1027243           0                7     Unaffiliated       LINDENWOLD
# 4078501           2                4       Republican            Clark
# 4078502           2                4       Republican            Clark
# 4158632           6                2       Democratic           Linden
# 4158633           6                2       Democratic           Linden
#
#         ballot_addr_state ballot_addr_country application_receivedDate  \
# 955199                 NJ       UNITED STATES               12/22/2019
# 955200                 NJ       UNITED STATES               12/22/2019
# 1027242                NJ                  US               09/23/2020
# 1027243                NJ                  US               09/23/2020
# 4078501                NJ                 NaN               08/14/2020
# 4078502                NJ                 NaN               08/14/2020
# 4158632                NJ                 NaN               08/14/2020
# 4158633                NJ                 NaN               08/14/2020
#
#         application_processedDate application_status ballot_mailedDate  \
# 955199                 12/22/2019           Accepted        10/01/2020
# 955200                 12/22/2019           Accepted        10/01/2020
# 1027242                09/23/2020           Accepted        09/28/2020
# 1027243                09/23/2020           Accepted        09/28/2020
# 4078501                08/31/2020           Accepted        09/15/2020
# 4078502                08/31/2020           Accepted        09/15/2020
# 4158632                08/31/2020           Accepted        09/22/2020
# 4158633                08/31/2020           Accepted        09/22/2020
#
#         ballot_receivedDate ballot_countedDate ballot_status received_type  \
# 955199           10/27/2020         11/19/2020      Accepted          Mail
# 955200           10/27/2020         11/19/2020      Accepted      Drop Box
# 1027242          10/17/2020         11/19/2020      Rejected      Drop Box
# 1027243          10/17/2020         11/19/2020      Accepted          Mail
# 4078501          10/27/2020         11/20/2020      Accepted        Bearer
# 4078502          10/27/2020         11/20/2020      Accepted      Drop Box
# 4158632          11/03/2020         11/20/2020      Rejected        Bearer
# 4158633          11/03/2020         11/20/2020      Accepted        Bearer
#
#              received_rejReason voter_resAddr_num voter_resAddr_street  \
# 955199                      NaN               109       E Franklin Ave
# 955200                      NaN               109       E Franklin Ave
# 1027242  Certificate Not Signed               101       E GIBBSBORO RD
# 1027243                     NaN               101       E GIBBSBORO RD
# 4078501                     NaN                75          Victoria Dr
# 4078502                     NaN                75          Victoria Dr
# 4158632  Certificate Not Signed               119            E 11th St
# 4158633                     NaN               119            E 11th St
#
#         voter_resAddr_city voter_resAddr_state       received_bearer
# 955199        Collingswood                  NJ                   NaN
# 955200        Collingswood                  NJ                   NaN
# 1027242         LINDENWOLD                  NJ                   NaN
# 1027243         LINDENWOLD                  NJ                   NaN
# 4078501              Clark                  NJ  CHRISTOPHER PANDOLFO
# 4078502              Clark                  NJ                   NaN
# 4158632             Linden                  NJ            ROY HERMAN
# 4158633             Linden                  NJ            ROY HERMAN

# %%
# Remove duplicate voter id rows (kept Accepted ballots)
ballots_dataset.drop(index=[955199,1027242,4078501,4158632], inplace=True)

# %% [markdown]
# ### Final Ballots Dataset<a class="anchor" id="finaldataset"></a>

# %%
ballots_dataset.shape
# Out:
# (4368981, 31)

# %% [markdown]
# ### Write Dataset to CSV File<a class="anchor" id="writecsv"></a>

# %%
ballots_dataset.to_csv('./ballots_dataset.csv', index=False)
